# %% [markdown]
# <a href="https://colab.research.google.com/github/romerocruzsa/cp-anemia-detection/blob/notebook-upload/Anemia_MobileNet_BaseVsQAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transfer Learning on MobileNetV2 for Anemia Detection and Hemoglobin Estimation
#
# **Author**: [Sebastián A. Cruz Romero](https://github.com/romerocruzsa/)
#
# **Reviewed by**:
#
# This tutorial builds on [CP-Anemic Paper]() paper. Transfer learning refers to methods that leverage pretrained models in different applications and datasets. This tutorial replicates the methodology for implementing Deep Learning architectures for Anemia Detection and Hemoglobin estimation through *Conjutiva pallor* analysis. Warning: we use a lot of boilerplate code from other PyTorch repos to, for example, define the [MobileNetV2](https://arxiv.org/abs/1801.04381) model architecture, define data loaders, and so on.

# %% [markdown]
# ## Installing Dependencies and Pre-Requisites

# %%
# !yes y | pip uninstall torch torchvision
# !yes y | pip install --pre torch torchvision -f https://download.pytorch.org/whl/nightly/cu101/torch_nightly.html
# # Install other dependencies
# !yes y | pip install torchinfo
# !yes y | pip install torchmetrics

# %%
# Import necessary libraries for file handling, data manipulation, and visualization
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Import libraries for working with images and transformations
from PIL import Image
import cv2 as cv

# Import PyTorch modules for model building, data handling, and evaluation
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.models as models
import torchvision.models.quantization as quant_models
from torch.utils.data import Dataset, DataLoader, Subset
from torchinfo import summary

# Import libraries for machine learning metrics and model evaluation
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve, mean_squared_error, mean_absolute_error, r2_score
import torchmetrics
from tqdm import tqdm

import warnings
warnings.filterwarnings('ignore')

# Set the seed.
seed = 42
torch.manual_seed(seed)

# %% [markdown]
# ## CP-AnemiC: A *conjunctival pallor* dataset and benchmark for anemia detection in children
#
# Anemia is a universal public health issue, which occurs as the result of a reduction in red blood cells. Early detection of anemia in children is highly desirable for effective treatment measures. We train and test our quantizable MobileNetV2 architecture to detect anemia on [CP-AnemiC](https://www.sciencedirect.com/science/article/pii/S2590093523000395), comprising 710 individuals (range of age, 6–59 months), gathered from several hospitals in Ghana. The conjunctiva image-based dataset is supported with Hb levels (g/dL) annotations for accurate diagnosis of anemia.

# %%
data_dir="/home/sebastian-cruz6/workspace/cp-anemia-detection/data/cp-anemia/"
weights_dir="/home/sebastian-cruz6/workspace/cp-anemia-detection/notebooks/weights"
anemic_dir=data_dir+"/Anemic"
non_anemic_dir=data_dir+"/Non-anemic"
signature = "11062024"

# %%
# data_dir = "/home/sebastian-cruz6/workspace/model-compression/data/cp-anemia/"
# weights_dir = "/home/sebastian-cruz6/workspace/model-compression/models/weights/"
# anemic_dir = data_dir+"Anemic/"
# non_anemic_dir = data_dir+"Non-anemic/"

data_sheet_path = data_dir+"Anemia_Data_Collection_Sheet.csv"
data_sheet = pd.read_csv(data_sheet_path)
display(data_sheet)
# Out:
#       IMAGE_ID  HB_LEVEL    Severity  Age(Months)  GENDER      REMARK  \
# 0    Image_001      9.80    Moderate            6  Female      Anemic
# 1    Image_002      9.90    Moderate           24    Male      Anemic
# 2    Image_003     11.10  Non-Anemic           24  Female  Non-anemic
# 3    Image_004     12.50  Non-Anemic           12    Male  Non-anemic
# 4    Image_005      9.90    Moderate           24    Male      Anemic
# ..         ...       ...         ...          ...     ...         ...
# 705  Image_706     12.80  Non-Anemic           48    Male  Non-anemic
# 706  Image_707     11.47  Non-Anemic           48  Female  Non-anemic
# 707  Image_708     11.60  Non-Anemic           60    Male  Non-anemic
# 708  Image_709     12.10  Non-Anemic           48    Male  Non-anemic
# 709  Image_710     11.70  Non-Anemic           24    Male  Non-anemic
#
#                              HOSPITAL     CITY/TOWN    MUNICIPALITY/DISTRICT  \
# 0    Nkawie-Toase Government Hospital  Nkawie-Toase   Atwima Nwabiagya South
# 1           Ejusu Government Hospital         Ejusu       Ejusu Municipality
# 2           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 3           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 4          Sunyani Municipal Hospital       Sunyani     Sunyani Municipality
# ..                                ...           ...                      ...
# 705      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 706         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 707   Komfo Anokye Teaching Hospital        Kumasi       Kumasi Metropolitan
# 708      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 709         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
#
#          REGION COUNTRY
# 0       Ashanti   Ghana
# 1       Ashanti   Ghana
# 2     Bono-East   Ghana
# 3     Bono-East   Ghana
# 4          Bono   Ghana
# ..          ...     ...
# 705  Upper East   Ghana
# 706   Bono-East   Ghana
# 707     Ashanti   Ghana
# 708  Upper East   Ghana
# 709   Bono-East   Ghana
#
# [710 rows x 11 columns]

# %%
# Mapping diagnosis to severity
severity_mapping = {
    "Non-Anemic": [1,0,0,0],
    "Mild": [0,1,0,0],
    "Moderate": [0,0,1,0],
    "Severe": [0,0,0,1],
}
# Mapping diagnosis to severity
remark_mapping = {
    "Non-anemic": 0,
    "Anemic": 1
}

data_sheet['SEVERITY_ONEHOT'] = data_sheet['Severity'].map(severity_mapping)
data_sheet['REMARK_ONEHOT'] = data_sheet['REMARK'].map(remark_mapping)
display(data_sheet)
# Out:
#       IMAGE_ID  HB_LEVEL    Severity  Age(Months)  GENDER      REMARK  \
# 0    Image_001      9.80    Moderate            6  Female      Anemic
# 1    Image_002      9.90    Moderate           24    Male      Anemic
# 2    Image_003     11.10  Non-Anemic           24  Female  Non-anemic
# 3    Image_004     12.50  Non-Anemic           12    Male  Non-anemic
# 4    Image_005      9.90    Moderate           24    Male      Anemic
# ..         ...       ...         ...          ...     ...         ...
# 705  Image_706     12.80  Non-Anemic           48    Male  Non-anemic
# 706  Image_707     11.47  Non-Anemic           48  Female  Non-anemic
# 707  Image_708     11.60  Non-Anemic           60    Male  Non-anemic
# 708  Image_709     12.10  Non-Anemic           48    Male  Non-anemic
# 709  Image_710     11.70  Non-Anemic           24    Male  Non-anemic
#
#                              HOSPITAL     CITY/TOWN    MUNICIPALITY/DISTRICT  \
# 0    Nkawie-Toase Government Hospital  Nkawie-Toase   Atwima Nwabiagya South
# 1           Ejusu Government Hospital         Ejusu       Ejusu Municipality
# 2           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 3           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 4          Sunyani Municipal Hospital       Sunyani     Sunyani Municipality
# ..                                ...           ...                      ...
# 705      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 706         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 707   Komfo Anokye Teaching Hospital        Kumasi       Kumasi Metropolitan
# 708      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 709         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
#
#          REGION COUNTRY SEVERITY_ONEHOT  REMARK_ONEHOT
# 0       Ashanti   Ghana    [0, 0, 1, 0]              1
# 1       Ashanti   Ghana    [0, 0, 1, 0]              1
# 2     Bono-East   Ghana    [1, 0, 0, 0]              0
# 3     Bono-East   Ghana    [1, 0, 0, 0]              0
# 4          Bono   Ghana    [0, 0, 1, 0]              1
# ..          ...     ...             ...            ...
# 705  Upper East   Ghana    [1, 0, 0, 0]              0
# 706   Bono-East   Ghana    [1, 0, 0, 0]              0
# 707     Ashanti   Ghana    [1, 0, 0, 0]              0
# 708  Upper East   Ghana    [1, 0, 0, 0]              0
# 709   Bono-East   Ghana    [1, 0, 0, 0]              0
#
# [710 rows x 13 columns]

# %% [markdown]
# ### Loading Data
#
# We will use `torchvision` and `torch.utils.data` packages to load the data. The problem we are trying to solve today is classifying images of the inner-part of the eyelid between Anemic and Non-anemic patients. The dataset contains about 710 images of which we will do an 80/20 split between training and testing subset. After that, we perform 5-fold cross-validation with our training set to avoid overfitting on smaller dataset. Since we are using transfer learning, we should be able to generalize reasonably well.

# %%
# # BATCH_SIZE = 4
# # test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# for img, binary_label, multiclass_label, hb_level, descriptor in test_loader:
#   print(binary_label, multiclass_label, hb_level, descriptor)
#   break

# %%
# Define data augmentations or transformations
transform = transforms.Compose([
    transforms.Resize((256, 192)),
    transforms.RandomHorizontalFlip(p=np.random.rand()),
    transforms.RandomVerticalFlip(p=np.random.rand()),
    transforms.RandomRotation(degrees=np.random.randint(0, 360)),
    transforms.RandomAffine(degrees=np.random.randint(0, 360)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Custom dataset class
class CPAnemiCDataset(Dataset):
    def __init__(self, dir, df, transform=None):
        self.dir = dir
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_id = row['IMAGE_ID']
        img_folder = row['REMARK']
        img_path = os.path.join(self.dir, img_folder, img_id + ".png")
        img = Image.open(img_path).convert('RGB')

        if self.transform:
            img = self.transform(img)

        binary_label = torch.tensor(row['REMARK_ONEHOT'], dtype=torch.float32)  # Adjusted for BCEWithLogitsLoss
        multiclass_label = torch.tensor(row['SEVERITY_ONEHOT'], dtype=torch.float32)
        hb_level = torch.tensor(row['HB_LEVEL'], dtype=torch.float32)
        descriptor = row['REMARK']+"/"+row['Severity']

        return img, binary_label, multiclass_label, hb_level, descriptor

    # Load the dataset
image_dataset = CPAnemiCDataset(data_dir, data_sheet, transform=transform)
train_dataset, test_dataset = train_test_split(image_dataset, test_size=0.20, shuffle=True)

print(f"Image Dataset Size (All): {len(image_dataset)}, \
        Train Size: {len(train_dataset)}, \
        Test Size: {len(test_dataset)}")

BATCH_SIZE = 32
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Image Dataset Size (All): 710,         Train Size: 568,         Test Size: 142

# %%
# Default device
device = torch.device('cpu')

# Check for CUDA availability
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    print("CUDA is not available, using CPU.")

print(f"Selected device: {device}")
# Out:
# Selected device: cuda

# %% [markdown]
# ## Helper functions
#
# We define several helper functions to help with model evaluation, understanding our predicitve performance, and visualizing our results.

# %% [markdown]
# ### Performance Metrics and Model Evalution

# %%
import torch
import torchmetrics
import numpy as np
from sklearn.metrics import roc_auc_score, mean_squared_error, mean_absolute_error, r2_score

class CumulativeMetrics:
    def __init__(self, model_type="binary", num_classes=1, device="cpu"):
        self.model_type = model_type
        self.num_classes = num_classes
        self.device = device
        self.reset()

        # Classification metrics initialization
        if model_type == "binary":
            self.accuracy = torchmetrics.Accuracy(task="binary").to(device)
            self.precision = torchmetrics.Precision(task="binary").to(device)
            self.recall = torchmetrics.Recall(task="binary").to(device)
            self.f1_score = torchmetrics.F1Score(task="binary").to(device)

    def reset(self):
        self.num_batches = 0
        # Cumulative sums for each metric
        self.cum_acc = 0.0
        self.cum_prec = 0.0
        self.cum_rec = 0.0
        self.cum_f1 = 0.0
        self.cum_mse = 0.0
        self.cum_mae = 0.0
        self.cum_r2 = 0.0
        # Storage for AUC
        self.y_true_all = []
        self.y_score_all = []

    def update(self, y_pred: torch.Tensor, y_true: torch.Tensor):
        if self.model_type == "binary":
            y_pred_class = torch.round(torch.sigmoid(y_pred)).int()
            self.y_true_all.extend(y_true.detach().cpu().numpy().tolist())
            self.y_score_all.extend(torch.sigmoid(y_pred).detach().cpu().numpy().tolist())

            # Update binary classification metrics
            self.cum_acc += self.accuracy(y_pred_class, y_true).item()
            self.cum_prec += self.precision(y_pred_class, y_true).item()
            self.cum_rec += self.recall(y_pred_class, y_true).item()
            self.cum_f1 += self.f1_score(y_pred_class, y_true).item()

        elif self.model_type == "regression":
            y_true_np = y_true.detach().cpu().numpy()
            y_pred_np = y_pred.detach().cpu().numpy()
            self.y_true_all.extend(y_true_np.tolist())
            self.y_score_all.extend(y_pred_np.tolist())

            # Compute per-batch regression metrics
            self.cum_mse += mean_squared_error(y_true_np, y_pred_np)
            self.cum_mae += mean_absolute_error(y_true_np, y_pred_np)
            self.cum_r2 += r2_score(y_true_np, y_pred_np)

        self.num_batches += 1

    def compute(self):
        if self.model_type == "binary":
            return {
                "Accuracy": self.cum_acc / self.num_batches,
                "Precision": self.cum_prec / self.num_batches,
                "Recall": self.cum_rec / self.num_batches,
                "F1 Score": self.cum_f1 / self.num_batches,
                "AUC Score": roc_auc_score(self.y_true_all, self.y_score_all)
            }

        elif self.model_type == "regression":
            return {
                "Mean Squared Error": self.cum_mse / self.num_batches,
                "Mean Absolute Error": self.cum_mae / self.num_batches,
                "R2 Score": self.cum_r2 / self.num_batches,
            }

# %% [markdown]
# ## Model Training and Evaluation
#
# Below is a generic function for model training. This function also
#
# * Calculates model performance metrics (Loss, Accuracy, Precision, F1 Score, etc.)
# * Saves the best model per highest F1 Score during the validation fold
# * Switches between `Validation` and `Test` phases

# %%
def train(dataloader, model, loss_fn, optimizer, cumulative_metrics, task_type="binary"):
    model.train()
    cumulative_metrics.reset()
    batch_losses = []

    for _, (img, binary, multiclass, hb_level, _) in enumerate(dataloader):
        img = img.to(device)
        binary = binary.to(device).unsqueeze(1).float()
        multiclass = multiclass.to(device)
        hb_level = hb_level.to(device).unsqueeze(1).float()

        optimizer.zero_grad()

        # Forward pass and loss calculation based on task type
        if task_type == "binary":
            pred = model(img)
            loss = loss_fn(pred, binary)  # Binary target
        elif task_type == "regression":
            pred = model(img)  # Direct prediction for regression
            loss = loss_fn(pred, hb_level)  # Regression target
        else:
            raise ValueError("Unsupported task type. Choose 'binary' or 'regression'.")
        
        # Backpropagation
        loss.backward()
        optimizer.step()

        batch_losses.append(loss.item())
        cumulative_metrics.update(pred, binary if task_type == "binary" else hb_level)

    avg_loss = sum(batch_losses) / len(batch_losses)
    performance_metrics = cumulative_metrics.compute()

    return avg_loss, performance_metrics


def eval(dataloader, model, loss_fn, mode, cumulative_metrics, task_type="binary"):
    model.eval()
    cumulative_metrics.reset()
    batch_losses = []

    with torch.no_grad():
        for _, (img, binary, multiclass, hb_level, _) in enumerate(dataloader):
            img = img.to(device)
            binary = binary.to(device).unsqueeze(1).float()
            multiclass = multiclass.to(device)
            hb_level = hb_level.to(device).unsqueeze(1).float()

            # Forward pass and loss calculation based on task type
            if task_type == "binary":
                pred = model(img)
                loss = loss_fn(pred, binary)  # Binary target
            elif task_type == "regression":
                pred = model(img)  # Direct prediction for regression
                loss = loss_fn(pred, hb_level)  # Regression target
            else:
                raise ValueError("Unsupported task type. Choose 'binary' or 'regression'.")

            batch_losses.append(loss.item())
            cumulative_metrics.update(pred, binary if task_type == "binary" else hb_level)

    avg_loss = sum(batch_losses) / len(batch_losses)
    performance_metrics = cumulative_metrics.compute()

    return avg_loss, performance_metrics

# %% [markdown]
# More support functions to:
#
# * Get model size in MB
# * Plot phase accuracy and loss
# * Visualize our model predictions
# * Load the `MobileNetV2` in its base and quantizable form
#
# *Note that we do modifications in the last sequential layer to adjust for the classes to be predicted.*

# %%
def get_model_size(mdl):
    torch.save(mdl.state_dict(), "tmp.pt")
    model_size = "Model Size: %.2f MB" %(os.path.getsize("tmp.pt")/1e6)
    os.remove('tmp.pt')
    return model_size

def plot_metrics(metrics_df, phase, model):
    # Create a figure with 2 subplots (1 row, 2 columns)
    fig, ax = plt.subplots(1, 2, figsize=(14, 5))

    # Plot Loss
    loss_df = metrics_df["Loss"]
    ax[0].plot(range(len(loss_df)), loss_df, linestyle='-', color='blue')
    ax[0].set_title(f"{phase} Loss with {model} on CP-AnemiC Dataset")
    ax[0].set_xlabel("Folds")
    ax[0].set_ylabel("Cross-Entropy Loss")
    ax[0].grid(True)

    # Plot Accuracy
    acc_df = metrics_df["Accuracy"]
    ax[1].plot(range(len(acc_df)), acc_df, linestyle='-', color='green')
    ax[1].set_title(f"{phase} Accuracy with {model} on CP-AnemiC Dataset")
    ax[1].set_xlabel("Folds")
    ax[1].set_ylabel("Accuracy")
    ax[1].grid(True)

    # Adjust layout to prevent overlap and display the plots
    plt.tight_layout()
    plt.show()

def visualize_predictions(model, dataloader, rows=5, cols=5, device='cpu'):
    # Set the model to evaluation mode
    model.eval()
    size = len(dataloader.dataset)

    # Get a batch of images from the dataloader
    X, y, descriptors = next(iter(dataloader))
    inputs = X.to(device)
    labels = y.to(device)

    # Run the inputs through the model
    with torch.no_grad():
        pred = (torch.sigmoid(model(X)) >= 0.5).float()
        pred = pred.to(device)

        # Create a grid of images with their predictions
        fig, axes = plt.subplots(rows, cols, figsize=(cols * 3, rows * 3))
        fig.suptitle('Model Predictions', fontsize=12)

        # Loop through the grid and plot images
        for i in range(rows * cols):
            if i >= len(inputs):
                break

            ax = axes[i // cols, i % cols] if rows > 1 else axes[i % cols]
            img = inputs[i].numpy().transpose((1, 2, 0))
            mean = np.array([0.485, 0.456, 0.406])
            std = np.array([0.229, 0.224, 0.225])
            img = std * img + mean  # Unnormalize the image
            img = np.clip(img, 0, 1)

            ax.imshow(img)
            ax.axis('off')
            pred_label = pred[i].item()
            true_label = labels[i].item()
            ax.set_title(f'Pred: {pred_label} | True: {true_label}', fontsize=10)

        plt.tight_layout()
        plt.show()

def load_mobilenet():
#     model_quantized = quant_models.mobilenet_v2(weights="MobileNet_V2_Weights.DEFAULT", quantize=False)
    model = models.mobilenet_v2(pretrained=True)
    num_ftrs = model.classifier[1].in_features
    model.classifier = nn.Sequential(
        nn.Dropout(p=0.2),
        nn.Linear(num_ftrs, 1)  # Adjust based on your number of classes
    )

    model = model.to(device)
    return model

# %% [markdown]
# ## Transfer Learning with MobileNetV2
#
# MobileNetV2 was trained on ImageNet and is optimized to run on mobile and other low-power applications. It's 155 layers deep and very efficient for object detection and image segmentation tasks, as well as classification tasks like this one. The architecture has three defining characteristics:
#
# * Depthwise separable convolutions
# * Thin input and output bottlenecks between layers
# * Shortcut connections between bottleneck layers

# %% [markdown]
# MobileNetV2 uses depthwise separable convolutions as efficient building blocks. Traditional convolutions are often very resource-intensive, and depthwise separable convolutions are able to reduce the number of trainable parameters and operations and also speed up convolutions in two steps:
#
# 1. The first step calculates an intermediate result by convolving on each of the channels independently. This is the depthwise convolution.
#
# 1. In the second step, another convolution merges the outputs of the previous step into one. This gets a single result from a single feature at a time, and then is applied to all the filters in the output layer. This is the pointwise convolution, or: Shape of the depthwise convolution X Number of filters.
#
# Each block consists of an inverted residual structure with a bottleneck at each end. These bottlenecks encode the intermediate inputs and outputs in a low dimensional space, and prevent non-linearities from destroying important information.
#
# The shortcut connections, which are similar to the ones in traditional residual networks, serve the same purpose of speeding up training and improving predictions. These connections skip over the intermediate convolutions and connect the bottleneck layers.

# %%
model = models.mobilenet_v2(weights="IMAGENET1K_V1")
model.classifier[1] = torch.nn.Linear(in_features=1280, out_features=1)
model = model.to(device)
print(summary(model))
# Out:
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# MobileNetV2                                        --
# ├─Sequential: 1-1                                  --
# │    └─Conv2dNormActivation: 2-1                   --
# │    │    └─Conv2d: 3-1                            864
# │    │    └─BatchNorm2d: 3-2                       64
# │    │    └─ReLU6: 3-3                             --
# │    └─InvertedResidual: 2-2                       --
# │    │    └─Sequential: 3-4                        896
# │    └─InvertedResidual: 2-3                       --
# │    │    └─Sequential: 3-5                        5,136
# │    └─InvertedResidual: 2-4                       --
# │    │    └─Sequential: 3-6                        8,832
# │    └─InvertedResidual: 2-5                       --
# │    │    └─Sequential: 3-7                        10,000
# │    └─InvertedResidual: 2-6                       --
# │    │    └─Sequential: 3-8                        14,848
# │    └─InvertedResidual: 2-7                       --
# │    │    └─Sequential: 3-9                        14,848
# │    └─InvertedResidual: 2-8                       --
# │    │    └─Sequential: 3-10                       21,056
# │    └─InvertedResidual: 2-9                       --
# │    │    └─Sequential: 3-11                       54,272
# │    └─InvertedResidual: 2-10                      --
# │    │    └─Sequential: 3-12                       54,272
# │    └─InvertedResidual: 2-11                      --
# │    │    └─Sequential: 3-13                       54,272
# │    └─InvertedResidual: 2-12                      --
# │    │    └─Sequential: 3-14                       66,624
# │    └─InvertedResidual: 2-13                      --
# │    │    └─Sequential: 3-15                       118,272
# │    └─InvertedResidual: 2-14                      --
# │    │    └─Sequential: 3-16                       118,272
# │    └─InvertedResidual: 2-15                      --
# │    │    └─Sequential: 3-17                       155,264
# │    └─InvertedResidual: 2-16                      --
# │    │    └─Sequential: 3-18                       320,000
# │    └─InvertedResidual: 2-17                      --
# │    │    └─Sequential: 3-19                       320,000
# │    └─InvertedResidual: 2-18                      --
# │    │    └─Sequential: 3-20                       473,920
# │    └─Conv2dNormActivation: 2-19                  --
# │    │    └─Conv2d: 3-21                           409,600
# │    │    └─BatchNorm2d: 3-22                      2,560
# │    │    └─ReLU6: 3-23                            --
# ├─Sequential: 1-2                                  --
# │    └─Dropout: 2-20                               --
# │    └─Linear: 2-21                                1,281
# ===========================================================================
# Total params: 2,225,153
# Trainable params: 2,225,153
# Non-trainable params: 0
# ===========================================================================

# %% [markdown]
# Note the last 2 layers here. They are the so called top layers, and they are responsible of the classification in the model.
#
# **What you should remember:**
#
# MobileNetV2's unique features are:
# * Depthwise separable convolutions that provide lightweight feature filtering and creation
# * Input and output bottlenecks that preserve important information on either end of the block
# * Depthwise separable convolutions deal with both spatial and depth (number of channels) dimensions

# %%
# %%time

# Training parameters
task_type = "regression"  # Choose from "binary", "multiclass", "regression"
BATCH_SIZE = 32
EPOCHS = 25
FOLDS = 5

# Assuming CumulativeMetrics is implemented elsewhere and is compatible with task_type
cumulative_metrics = CumulativeMetrics(model_type=task_type, device=device)  # Instantiate metrics tracker

# 5-fold cross-validation setup
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)

# Initialize model, loss function, and optimizer
model = load_mobilenet()  # Your MobileNetV2 instance
loss_fn = torch.nn.BCEWithLogitsLoss() if task_type == "binary" else torch.nn.MSELoss()  # Select appropriate loss
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# Directory to save the model with the best performance metrics
os.makedirs(weights_dir, exist_ok=True)

best_val_score = -float('inf') if task_type == "binary" else -float('inf')
train_metrics_df = []
val_metrics_df = []

for epoch in range(EPOCHS):
    print(f"\nEpoch {epoch+1}/{EPOCHS}")
    fold = 1
    fold_best_train_f1score = float('inf') if task_type == "binary" else -float('inf')

    for train_idx, val_idx in kf.split(train_dataset):
        train_subset = Subset(image_dataset, train_idx)
        val_subset = Subset(image_dataset, val_idx)

        train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False)

        if fold == FOLDS:
            # Validation loop
            avg_val_loss, val_metrics = eval(val_loader, model, loss_fn, mode="Validation",
                                             cumulative_metrics=cumulative_metrics, task_type=task_type)

            if task_type == "binary":
                # Unpack classification metrics
                avg_val_accuracy, avg_val_precision, avg_val_recall, avg_val_f1, avg_val_auc = val_metrics.values()
                print(f"\nValidation: \tFold {fold} - Loss: {avg_val_loss:.4f}, Accuracy: {avg_val_accuracy:.4f}, "
                      f"Precision: {avg_val_precision:.4f}, Recall: {avg_val_recall:.4f}, F1 Score: {avg_val_f1:.4f}, AUC Score: {avg_val_auc:.4f}")

                # Save model with the best validation F1 score
                if avg_val_f1 > best_val_score:
                    best_val_score = avg_val_f1
                    val_metrics_dict = {**{"Loss": avg_val_loss}, **val_metrics}
                    val_metrics_df.append(val_metrics_dict)
                    torch.save(model.state_dict(), f'{weights_dir}/model_best_f1score_{task_type}_{signature}.pth')
                    print(f"Model with best F1 Score of {best_val_score:.4f} saved at epoch {epoch + 1}")

            elif task_type == "regression":
                # Unpack regression metrics
                avg_val_mse, avg_val_mae, avg_val_r2 = val_metrics.values()
                print(f"\nValidation: \tFold {fold} - Loss: {avg_val_loss:.4f}, MSE: {avg_val_mse:.4f}, "
                      f"MAE: {avg_val_mae:.4f}, R2 Score: {avg_val_r2:.4f}")

                # Save model with best R2 score
                if avg_val_r2 > best_val_score:
                    best_val_score = avg_val_r2
                    val_metrics_dict = {**{"Loss": avg_val_loss}, **val_metrics}
                    val_metrics_df.append(val_metrics_dict)
                    torch.save(model.state_dict(), f'{weights_dir}/model_best_r2score_{task_type}_{signature}.pth')
                    print(f"Model with best R2 Score of {best_val_score:.4f} saved at epoch {epoch + 1}")

        else:
            # Training loop
            avg_train_loss, train_metrics = train(train_loader, model, loss_fn, optimizer, cumulative_metrics, task_type=task_type)

            if task_type == "binary":
                # Unpack classification metrics
                avg_train_accuracy, avg_train_precision, avg_train_recall, avg_train_f1, avg_train_auc = train_metrics.values()
                print(f"Training: \tFold {fold} - Loss: {avg_train_loss:.4f}, Accuracy: {avg_train_accuracy:.4f}, "
                      f"Precision: {avg_train_precision:.4f}, Recall: {avg_train_recall:.4f}, F1 Score: {avg_train_f1:.4f}, AUC Score: {avg_train_auc:.4f}")
                train_metrics_dict = {**{"Loss": avg_train_loss}, **train_metrics}
                train_metrics_df.append(train_metrics_dict)

            elif task_type == "regression":
                # Unpack regression metrics
                avg_train_mse, avg_train_mae, avg_train_r2 = train_metrics.values()
                print(f"Training: \tFold {fold} - Loss: {avg_train_loss:.4f}, MSE: {avg_train_mse:.4f}, "
                      f"MAE: {avg_train_mae:.4f}, R2: {avg_train_r2:.4f}")
                train_metrics_dict = {**{"Loss": avg_train_loss}, **train_metrics}
                train_metrics_df.append(train_metrics_dict)

        # Reset metrics and prepare for the next fold
        cumulative_metrics.reset()
        fold += 1

print(get_model_size(model))
# Out:
# Epoch 1/25
# Training: 	Fold 1 - Loss: 104.2548, MSE: 104.2548, MAE: 9.9566, R2: -23.6988
# Training: 	Fold 2 - Loss: 75.8137, MSE: 75.8137, MAE: 8.4053, R2: -15.7298
# Training: 	Fold 3 - Loss: 54.2545, MSE: 54.2545, MAE: 6.9954, R2: -12.4177
# Training: 	Fold 4 - Loss: 38.9353, MSE: 38.9353, MAE: 5.8263, R2: -8.2967
#
# Validation: 	Fold 5 - Loss: 23.3245, MSE: 23.3245, MAE: 4.3653, R2 Score: -5.1854
# Model with best R2 Score of -5.1854 saved at epoch 1
#
# Epoch 2/25
# Training: 	Fold 1 - Loss: 28.0020, MSE: 28.0020, MAE: 4.8544, R2: -4.9344
# Training: 	Fold 2 - Loss: 19.2422, MSE: 19.2422, MAE: 3.8974, R2: -3.0334
# Training: 	Fold 3 - Loss: 13.7042, MSE: 13.7042, MAE: 3.2853, R2: -2.2696
# Training: 	Fold 4 - Loss: 10.2745, MSE: 10.2745, MAE: 2.7507, R2: -1.5830
#
# Validation: 	Fold 5 - Loss: 9.8492, MSE: 9.8492, MAE: 2.7789, R2 Score: -1.5700
# Model with best R2 Score of -1.5700 saved at epoch 2
#
# Epoch 3/25
# Training: 	Fold 1 - Loss: 8.2497, MSE: 8.2497, MAE: 2.4341, R2: -0.9456
# Training: 	Fold 2 - Loss: 6.9477, MSE: 6.9477, MAE: 2.1800, R2: -1.4460
# Training: 	Fold 3 - Loss: 5.5750, MSE: 5.5750, MAE: 1.9239, R2: -0.1926
# Training: 	Fold 4 - Loss: 4.7645, MSE: 4.7645, MAE: 1.7340, R2: -0.2368
#
# Validation: 	Fold 5 - Loss: 4.2475, MSE: 4.2475, MAE: 1.6364, R2 Score: 0.0201
# Model with best R2 Score of 0.0201 saved at epoch 3
#
# Epoch 4/25
# Training: 	Fold 1 - Loss: 4.9396, MSE: 4.9396, MAE: 1.8061, R2: -0.0793
# Training: 	Fold 2 - Loss: 5.4312, MSE: 5.4312, MAE: 1.7997, R2: -0.0694
# Training: 	Fold 3 - Loss: 4.6378, MSE: 4.6378, MAE: 1.6795, R2: -0.0119
# Training: 	Fold 4 - Loss: 4.1409, MSE: 4.1409, MAE: 1.5994, R2: -0.0415
#
# Validation: 	Fold 5 - Loss: 3.4330, MSE: 3.4330, MAE: 1.4634, R2 Score: 0.2294
# Model with best R2 Score of 0.2294 saved at epoch 4
#
# Epoch 5/25
# Training: 	Fold 1 - Loss: 4.2711, MSE: 4.2711, MAE: 1.6127, R2: 0.1188
# Training: 	Fold 2 - Loss: 4.4491, MSE: 4.4491, MAE: 1.6554, R2: 0.1217
# Training: 	Fold 3 - Loss: 4.1097, MSE: 4.1097, MAE: 1.5907, R2: 0.1267
# Training: 	Fold 4 - Loss: 3.9780, MSE: 3.9780, MAE: 1.5540, R2: 0.0408
#
# Validation: 	Fold 5 - Loss: 4.0048, MSE: 4.0048, MAE: 1.5486, R2 Score: 0.0709
#
# Epoch 6/25
# Training: 	Fold 1 - Loss: 4.0596, MSE: 4.0596, MAE: 1.5845, R2: 0.1355
# Training: 	Fold 2 - Loss: 4.4454, MSE: 4.4454, MAE: 1.6672, R2: 0.0987
# Training: 	Fold 3 - Loss: 3.9657, MSE: 3.9657, MAE: 1.5494, R2: 0.1032
# Training: 	Fold 4 - Loss: 3.5515, MSE: 3.5515, MAE: 1.4873, R2: 0.1587
#
# Validation: 	Fold 5 - Loss: 3.3013, MSE: 3.3013, MAE: 1.4901, R2 Score: 0.2537
# Model with best R2 Score of 0.2537 saved at epoch 6
#
# Epoch 7/25
# Training: 	Fold 1 - Loss: 4.1395, MSE: 4.1395, MAE: 1.6072, R2: 0.1534
# Training: 	Fold 2 - Loss: 3.9230, MSE: 3.9230, MAE: 1.5683, R2: 0.1353
# Training: 	Fold 3 - Loss: 4.0296, MSE: 4.0296, MAE: 1.5371, R2: 0.1657
# Training: 	Fold 4 - Loss: 3.4518, MSE: 3.4518, MAE: 1.4433, R2: 0.1907
#
# Validation: 	Fold 5 - Loss: 3.5372, MSE: 3.5372, MAE: 1.4927, R2 Score: 0.1716
#
# Epoch 8/25
# Training: 	Fold 1 - Loss: 4.3327, MSE: 4.3327, MAE: 1.5969, R2: -0.5817
# Training: 	Fold 2 - Loss: 4.0836, MSE: 4.0836, MAE: 1.5863, R2: 0.1430
# Training: 	Fold 3 - Loss: 3.4885, MSE: 3.4885, MAE: 1.4247, R2: 0.2581
# Training: 	Fold 4 - Loss: 3.4222, MSE: 3.4222, MAE: 1.4727, R2: 0.1005
#
# Validation: 	Fold 5 - Loss: 3.1242, MSE: 3.1242, MAE: 1.3965, R2 Score: 0.2843
# Model with best R2 Score of 0.2843 saved at epoch 8
#
# Epoch 9/25
# Training: 	Fold 1 - Loss: 3.2847, MSE: 3.2847, MAE: 1.3725, R2: 0.2671
# Training: 	Fold 2 - Loss: 3.4281, MSE: 3.4281, MAE: 1.4436, R2: 0.2998
# Training: 	Fold 3 - Loss: 3.4597, MSE: 3.4597, MAE: 1.4214, R2: 0.2049
# Training: 	Fold 4 - Loss: 3.0874, MSE: 3.0874, MAE: 1.3850, R2: 0.2027
#
# Validation: 	Fold 5 - Loss: 2.7276, MSE: 2.7276, MAE: 1.2822, R2 Score: 0.3878
# Model with best R2 Score of 0.3878 saved at epoch 9
#
# Epoch 10/25
# Training: 	Fold 1 - Loss: 3.4422, MSE: 3.4422, MAE: 1.4426, R2: 0.2888
# Training: 	Fold 2 - Loss: 3.3842, MSE: 3.3842, MAE: 1.4088, R2: 0.2825
# Training: 	Fold 3 - Loss: 3.5260, MSE: 3.5260, MAE: 1.4287, R2: 0.2956
# Training: 	Fold 4 - Loss: 3.3860, MSE: 3.3860, MAE: 1.4738, R2: 0.1981
#
# Validation: 	Fold 5 - Loss: 3.0948, MSE: 3.0948, MAE: 1.4091, R2 Score: 0.2603
#
# Epoch 11/25
# Training: 	Fold 1 - Loss: 3.1905, MSE: 3.1905, MAE: 1.3649, R2: 0.3700
# Training: 	Fold 2 - Loss: 3.5333, MSE: 3.5333, MAE: 1.4601, R2: 0.2886
# Training: 	Fold 3 - Loss: 3.8369, MSE: 3.8369, MAE: 1.5056, R2: 0.1756
# Training: 	Fold 4 - Loss: 3.4531, MSE: 3.4531, MAE: 1.4763, R2: 0.1228
#
# Validation: 	Fold 5 - Loss: 3.4878, MSE: 3.4878, MAE: 1.5002, R2 Score: 0.1340
#
# Epoch 12/25
# Training: 	Fold 1 - Loss: 3.9020, MSE: 3.9020, MAE: 1.5529, R2: 0.2404
# Training: 	Fold 2 - Loss: 3.4825, MSE: 3.4825, MAE: 1.4393, R2: 0.2735
# Training: 	Fold 3 - Loss: 3.6953, MSE: 3.6953, MAE: 1.4920, R2: 0.1828
# Training: 	Fold 4 - Loss: 2.9929, MSE: 2.9929, MAE: 1.3574, R2: 0.2996
#
# Validation: 	Fold 5 - Loss: 3.0229, MSE: 3.0229, MAE: 1.2959, R2 Score: 0.3323
#
# Epoch 13/25
# Training: 	Fold 1 - Loss: 3.4388, MSE: 3.4388, MAE: 1.4442, R2: 0.3176
# Training: 	Fold 2 - Loss: 3.0980, MSE: 3.0980, MAE: 1.3564, R2: 0.3237
# Training: 	Fold 3 - Loss: 3.3938, MSE: 3.3938, MAE: 1.4662, R2: 0.2235
# Training: 	Fold 4 - Loss: 2.7197, MSE: 2.7197, MAE: 1.2698, R2: 0.3573
#
# Validation: 	Fold 5 - Loss: 2.4625, MSE: 2.4625, MAE: 1.2229, R2 Score: 0.4279
# Model with best R2 Score of 0.4279 saved at epoch 13
#
# Epoch 14/25
# Training: 	Fold 1 - Loss: 3.0739, MSE: 3.0739, MAE: 1.3447, R2: 0.3772
# Training: 	Fold 2 - Loss: 2.9508, MSE: 2.9508, MAE: 1.3006, R2: 0.4123
# Training: 	Fold 3 - Loss: 3.1536, MSE: 3.1536, MAE: 1.3764, R2: 0.2750
# Training: 	Fold 4 - Loss: 2.8558, MSE: 2.8558, MAE: 1.3383, R2: 0.3468
#
# Validation: 	Fold 5 - Loss: 2.6847, MSE: 2.6847, MAE: 1.2628, R2 Score: 0.3525
#
# Epoch 15/25
# Training: 	Fold 1 - Loss: 3.0375, MSE: 3.0375, MAE: 1.3192, R2: 0.3531
# Training: 	Fold 2 - Loss: 3.1825, MSE: 3.1825, MAE: 1.3801, R2: 0.4200
# Training: 	Fold 3 - Loss: 2.8089, MSE: 2.8089, MAE: 1.2982, R2: 0.3697
# Training: 	Fold 4 - Loss: 3.0140, MSE: 3.0140, MAE: 1.3333, R2: 0.2764
#
# Validation: 	Fold 5 - Loss: 2.8923, MSE: 2.8923, MAE: 1.3189, R2 Score: 0.3079
#
# Epoch 16/25
# Training: 	Fold 1 - Loss: 3.5588, MSE: 3.5588, MAE: 1.4287, R2: 0.2879
# Training: 	Fold 2 - Loss: 3.4462, MSE: 3.4462, MAE: 1.3647, R2: 0.3550
# Training: 	Fold 3 - Loss: 3.2102, MSE: 3.2102, MAE: 1.3930, R2: 0.2871
# Training: 	Fold 4 - Loss: 3.0369, MSE: 3.0369, MAE: 1.3695, R2: 0.3413
#
# Validation: 	Fold 5 - Loss: 2.5204, MSE: 2.5204, MAE: 1.2310, R2 Score: 0.4218
#
# Epoch 17/25
# Training: 	Fold 1 - Loss: 3.3868, MSE: 3.3868, MAE: 1.3894, R2: 0.2516
# Training: 	Fold 2 - Loss: 2.9756, MSE: 2.9756, MAE: 1.3567, R2: 0.3009
# Training: 	Fold 3 - Loss: 2.7975, MSE: 2.7975, MAE: 1.2776, R2: 0.3756
# Training: 	Fold 4 - Loss: 2.5762, MSE: 2.5762, MAE: 1.2418, R2: 0.3277
#
# Validation: 	Fold 5 - Loss: 2.5372, MSE: 2.5372, MAE: 1.2135, R2 Score: 0.4105
#
# Epoch 18/25
# Training: 	Fold 1 - Loss: 2.9088, MSE: 2.9088, MAE: 1.3019, R2: 0.3819
# Training: 	Fold 2 - Loss: 2.6538, MSE: 2.6538, MAE: 1.2775, R2: 0.3817
# Training: 	Fold 3 - Loss: 2.4396, MSE: 2.4396, MAE: 1.1974, R2: 0.4497
# Training: 	Fold 4 - Loss: 2.7516, MSE: 2.7516, MAE: 1.3050, R2: 0.2382
#
# Validation: 	Fold 5 - Loss: 1.8815, MSE: 1.8815, MAE: 1.0098, R2 Score: 0.5610
# Model with best R2 Score of 0.5610 saved at epoch 18
#
# Epoch 19/25
# Training: 	Fold 1 - Loss: 3.0254, MSE: 3.0254, MAE: 1.3424, R2: 0.3743
# Training: 	Fold 2 - Loss: 2.6342, MSE: 2.6342, MAE: 1.2286, R2: 0.4442
# Training: 	Fold 3 - Loss: 2.4822, MSE: 2.4822, MAE: 1.2083, R2: 0.4302
# Training: 	Fold 4 - Loss: 2.4691, MSE: 2.4691, MAE: 1.1794, R2: 0.4331
#
# Validation: 	Fold 5 - Loss: 2.1987, MSE: 2.1987, MAE: 1.1219, R2 Score: 0.4865
#
# Epoch 20/25
# Training: 	Fold 1 - Loss: 2.7709, MSE: 2.7709, MAE: 1.2402, R2: 0.4577
# Training: 	Fold 2 - Loss: 2.8903, MSE: 2.8903, MAE: 1.3037, R2: 0.2836
# Training: 	Fold 3 - Loss: 3.1799, MSE: 3.1799, MAE: 1.3051, R2: 0.3554
# Training: 	Fold 4 - Loss: 2.8946, MSE: 2.8946, MAE: 1.2921, R2: 0.3699
#
# Validation: 	Fold 5 - Loss: 2.5204, MSE: 2.5204, MAE: 1.1991, R2 Score: 0.4215
#
# Epoch 21/25
# Training: 	Fold 1 - Loss: 2.4891, MSE: 2.4891, MAE: 1.2064, R2: 0.4767
# Training: 	Fold 2 - Loss: 2.6210, MSE: 2.6210, MAE: 1.2616, R2: 0.3920
# Training: 	Fold 3 - Loss: 2.4167, MSE: 2.4167, MAE: 1.1775, R2: 0.4150
# Training: 	Fold 4 - Loss: 2.3306, MSE: 2.3306, MAE: 1.1682, R2: 0.4624
#
# Validation: 	Fold 5 - Loss: 2.3374, MSE: 2.3374, MAE: 1.1425, R2 Score: 0.4627
#
# Epoch 22/25
# Training: 	Fold 1 - Loss: 2.4836, MSE: 2.4836, MAE: 1.2132, R2: 0.4888
# Training: 	Fold 2 - Loss: 2.6262, MSE: 2.6262, MAE: 1.2486, R2: 0.4766
# Training: 	Fold 3 - Loss: 2.3300, MSE: 2.3300, MAE: 1.1914, R2: 0.4382
# Training: 	Fold 4 - Loss: 2.5675, MSE: 2.5675, MAE: 1.2153, R2: 0.4303
#
# Validation: 	Fold 5 - Loss: 2.0157, MSE: 2.0157, MAE: 1.0483, R2 Score: 0.5261
#
# Epoch 23/25
# Training: 	Fold 1 - Loss: 2.3886, MSE: 2.3886, MAE: 1.1902, R2: 0.4894
# Training: 	Fold 2 - Loss: 2.5597, MSE: 2.5597, MAE: 1.2499, R2: 0.4396
# Training: 	Fold 3 - Loss: 2.1705, MSE: 2.1705, MAE: 1.1261, R2: 0.5263
# Training: 	Fold 4 - Loss: 2.2024, MSE: 2.2024, MAE: 1.1411, R2: 0.4932
#
# Validation: 	Fold 5 - Loss: 1.9695, MSE: 1.9695, MAE: 1.0043, R2 Score: 0.5559
#
# Epoch 24/25
# Training: 	Fold 1 - Loss: 2.7393, MSE: 2.7393, MAE: 1.2684, R2: 0.2907
# Training: 	Fold 2 - Loss: 2.2456, MSE: 2.2456, MAE: 1.1220, R2: 0.5517
# Training: 	Fold 3 - Loss: 2.5443, MSE: 2.5443, MAE: 1.1953, R2: 0.4511
# Training: 	Fold 4 - Loss: 2.2471, MSE: 2.2471, MAE: 1.1336, R2: 0.5131
#
# Validation: 	Fold 5 - Loss: 1.9724, MSE: 1.9724, MAE: 1.0527, R2 Score: 0.5402
#
# Epoch 25/25
# Training: 	Fold 1 - Loss: 2.3957, MSE: 2.3957, MAE: 1.1744, R2: 0.4951
# Training: 	Fold 2 - Loss: 2.5306, MSE: 2.5306, MAE: 1.2219, R2: -1.4090
# Training: 	Fold 3 - Loss: 2.0064, MSE: 2.0064, MAE: 1.0536, R2: 0.5412
# Training: 	Fold 4 - Loss: 2.2639, MSE: 2.2639, MAE: 1.1529, R2: 0.4286
#
# Validation: 	Fold 5 - Loss: 1.8838, MSE: 1.8838, MAE: 1.0284, R2 Score: 0.5696
# Model with best R2 Score of 0.5696 saved at epoch 25
# Model Size: 9.13 MB
# CPU times: user 33min 28s, sys: 2min 42s, total: 36min 10s
# Wall time: 1min 30s

# %% [markdown]
# We can now evaluate how our model performed on our regression task (hemoglobin estimation)

# %%
# %%time

model.load_state_dict(torch.load(f"{weights_dir}/model_best_r2score_regression_11062024.pth"))
test_loss, test_performance_metrics = eval(test_loader, model, loss_fn, 'Testing', CumulativeMetrics(model_type="regression", device=device))
test_mse, test_mae, test_r2 = test_performance_metrics.values()
print(f"Testing: \tLoss: {test_loss:.4f}, MSE: {test_mse:.4f}, MAE: {test_mae:.4f}, R2 Score: {test_r2:.4f}")
# Out:
# Testing: 	Loss: 4.7968, MSE: 94.7575, MAE: 9.5209, R2 Score: -404.5475
# CPU times: user 805 ms, sys: 81.5 ms, total: 886 ms
# Wall time: 64.9 ms

# %%
# %%time

# Training parameters
task_type = "binary"  # Choose from "binary", "multiclass", "regression"
BATCH_SIZE = 32
EPOCHS = 25
FOLDS = 5

# Assuming CumulativeMetrics is implemented elsewhere and is compatible with task_type
cumulative_metrics = CumulativeMetrics(model_type=task_type, device=device)  # Instantiate metrics tracker

# 5-fold cross-validation setup
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)

# Initialize model, loss function, and optimizer
model = load_mobilenet()  # Your MobileNetV2 instance
loss_fn = torch.nn.BCEWithLogitsLoss() if task_type == "binary" else torch.nn.MSELoss()  # Select appropriate loss
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# Directory to save the model with the best performance metrics
os.makedirs(weights_dir, exist_ok=True)

best_val_score = -float('inf') if task_type == "binary" else -float('inf')
train_metrics_df = []
val_metrics_df = []

for epoch in range(EPOCHS):
    print(f"\nEpoch {epoch+1}/{EPOCHS}")
    fold = 1
    fold_best_train_f1score = float('inf') if task_type == "binary" else -float('inf')

    for train_idx, val_idx in kf.split(train_dataset):
        train_subset = Subset(image_dataset, train_idx)
        val_subset = Subset(image_dataset, val_idx)

        train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False)

        if fold == FOLDS:
            # Validation loop
            avg_val_loss, val_metrics = eval(val_loader, model, loss_fn, mode="Validation",
                                             cumulative_metrics=cumulative_metrics, task_type=task_type)

            if task_type == "binary":
                # Unpack classification metrics
                avg_val_accuracy, avg_val_precision, avg_val_recall, avg_val_f1, avg_val_auc = val_metrics.values()
                print(f"\nValidation: \tFold {fold} - Loss: {avg_val_loss:.4f}, Accuracy: {avg_val_accuracy:.4f}, "
                      f"Precision: {avg_val_precision:.4f}, Recall: {avg_val_recall:.4f}, F1 Score: {avg_val_f1:.4f}, AUC Score: {avg_val_auc:.4f}")

                # Save model with the best validation F1 score
                if avg_val_f1 > best_val_score:
                    best_val_score = avg_val_f1
                    val_metrics_dict = {**{"Loss": avg_val_loss}, **val_metrics}
                    val_metrics_df.append(val_metrics_dict)
                    torch.save(model.state_dict(), f'{weights_dir}/model_best_f1score_{task_type}_{signature}.pth')
                    print(f"Model with best F1 Score of {best_val_score:.4f} saved at epoch {epoch + 1}")

            elif task_type == "regression":
                # Unpack regression metrics
                avg_val_mse, avg_val_mae, avg_val_r2 = val_metrics.values()
                print(f"\nValidation: \tFold {fold} - Loss: {avg_val_loss:.4f}, MSE: {avg_val_mse:.4f}, "
                      f"MAE: {avg_val_mae:.4f}, R2 Score: {avg_val_r2:.4f}")

                # Save model with best R2 score
                if avg_val_r2 > best_val_score:
                    best_val_score = avg_val_r2
                    val_metrics_dict = {**{"Loss": avg_val_loss}, **val_metrics}
                    val_metrics_df.append(val_metrics_dict)
                    torch.save(model.state_dict(), f'{weights_dir}/model_best_r2score_{task_type}_{signature}.pth')
                    print(f"Model with best R2 Score of {best_val_score:.4f} saved at epoch {epoch + 1}")

        else:
            # Training loop
            avg_train_loss, train_metrics = train(train_loader, model, loss_fn, optimizer, cumulative_metrics, task_type=task_type)

            if task_type == "binary":
                # Unpack classification metrics
                avg_train_accuracy, avg_train_precision, avg_train_recall, avg_train_f1, avg_train_auc = train_metrics.values()
                print(f"Training: \tFold {fold} - Loss: {avg_train_loss:.4f}, Accuracy: {avg_train_accuracy:.4f}, "
                      f"Precision: {avg_train_precision:.4f}, Recall: {avg_train_recall:.4f}, F1 Score: {avg_train_f1:.4f}, AUC Score: {avg_train_auc:.4f}")
                train_metrics_dict = {**{"Loss": avg_train_loss}, **train_metrics}
                train_metrics_df.append(train_metrics_dict)

            elif task_type == "regression":
                # Unpack regression metrics
                avg_train_mse, avg_train_mae, avg_train_r2 = train_metrics.values()
                print(f"Training: \tFold {fold} - Loss: {avg_train_loss:.4f}, MSE: {avg_train_mse:.4f}, "
                      f"MAE: {avg_train_mae:.4f}, R2: {avg_train_r2:.4f}")
                train_metrics_dict = {**{"Loss": avg_train_loss}, **train_metrics}
                train_metrics_df.append(train_metrics_dict)

        # Reset metrics and prepare for the next fold
        cumulative_metrics.reset()
        fold += 1

print(get_model_size(model))
# Out:
# Epoch 1/25
# Training: 	Fold 1 - Loss: 0.7305, Accuracy: 0.5104, Precision: 0.6498, Recall: 0.3434, F1 Score: 0.3684, AUC Score: 0.5355
# Training: 	Fold 2 - Loss: 0.6480, Accuracy: 0.6160, Precision: 0.6667, Recall: 0.7434, F1 Score: 0.6984, AUC Score: 0.6155
# Training: 	Fold 3 - Loss: 0.6168, Accuracy: 0.6681, Precision: 0.6837, Recall: 0.8470, F1 Score: 0.7541, AUC Score: 0.6879
# Training: 	Fold 4 - Loss: 0.6130, Accuracy: 0.6875, Precision: 0.6988, Recall: 0.8540, F1 Score: 0.7651, AUC Score: 0.6796
#
# Validation: 	Fold 5 - Loss: 0.5803, Accuracy: 0.6608, Precision: 0.6640, Recall: 0.8536, F1 Score: 0.7403, AUC Score: 0.7657
# Model with best F1 Score of 0.7403 saved at epoch 1
#
# Epoch 2/25
# Training: 	Fold 1 - Loss: 0.6066, Accuracy: 0.6833, Precision: 0.6877, Recall: 0.8383, F1 Score: 0.7514, AUC Score: 0.6964
# Training: 	Fold 2 - Loss: 0.5873, Accuracy: 0.6847, Precision: 0.7437, Recall: 0.7644, F1 Score: 0.7477, AUC Score: 0.7535
# Training: 	Fold 3 - Loss: 0.5701, Accuracy: 0.7083, Precision: 0.7184, Recall: 0.8576, F1 Score: 0.7738, AUC Score: 0.7640
# Training: 	Fold 4 - Loss: 0.5279, Accuracy: 0.7238, Precision: 0.7472, Recall: 0.8258, F1 Score: 0.7789, AUC Score: 0.7981
#
# Validation: 	Fold 5 - Loss: 0.4772, Accuracy: 0.7665, Precision: 0.7683, Recall: 0.8631, F1 Score: 0.8018, AUC Score: 0.8317
# Model with best F1 Score of 0.8018 saved at epoch 2
#
# Epoch 3/25
# Training: 	Fold 1 - Loss: 0.5201, Accuracy: 0.7500, Precision: 0.7536, Recall: 0.8343, F1 Score: 0.7878, AUC Score: 0.8014
# Training: 	Fold 2 - Loss: 0.4918, Accuracy: 0.7403, Precision: 0.7434, Recall: 0.8568, F1 Score: 0.7890, AUC Score: 0.8299
# Training: 	Fold 3 - Loss: 0.4771, Accuracy: 0.7639, Precision: 0.7897, Recall: 0.8515, F1 Score: 0.8121, AUC Score: 0.8352
# Training: 	Fold 4 - Loss: 0.4840, Accuracy: 0.7801, Precision: 0.7945, Recall: 0.8690, F1 Score: 0.8202, AUC Score: 0.8238
#
# Validation: 	Fold 5 - Loss: 0.3061, Accuracy: 0.9150, Precision: 0.8974, Recall: 0.9555, F1 Score: 0.9244, AUC Score: 0.9545
# Model with best F1 Score of 0.9244 saved at epoch 3
#
# Epoch 4/25
# Training: 	Fold 1 - Loss: 0.4359, Accuracy: 0.8139, Precision: 0.8290, Recall: 0.8732, F1 Score: 0.8446, AUC Score: 0.8791
# Training: 	Fold 2 - Loss: 0.4982, Accuracy: 0.7278, Precision: 0.7546, Recall: 0.8176, F1 Score: 0.7773, AUC Score: 0.8468
# Training: 	Fold 3 - Loss: 0.4401, Accuracy: 0.7840, Precision: 0.8200, Recall: 0.8397, F1 Score: 0.8248, AUC Score: 0.8758
# Training: 	Fold 4 - Loss: 0.4496, Accuracy: 0.7830, Precision: 0.7971, Recall: 0.8641, F1 Score: 0.8264, AUC Score: 0.8644
#
# Validation: 	Fold 5 - Loss: 0.2722, Accuracy: 0.9072, Precision: 0.8655, Recall: 0.9886, F1 Score: 0.9186, AUC Score: 0.9599
#
# Epoch 5/25
# Training: 	Fold 1 - Loss: 0.4119, Accuracy: 0.7972, Precision: 0.7772, Recall: 0.8980, F1 Score: 0.8288, AUC Score: 0.8929
# Training: 	Fold 2 - Loss: 0.4040, Accuracy: 0.8167, Precision: 0.8444, Recall: 0.8603, F1 Score: 0.8465, AUC Score: 0.8881
# Training: 	Fold 3 - Loss: 0.3960, Accuracy: 0.7944, Precision: 0.8288, Recall: 0.8407, F1 Score: 0.8287, AUC Score: 0.8985
# Training: 	Fold 4 - Loss: 0.4312, Accuracy: 0.8110, Precision: 0.8161, Recall: 0.8481, F1 Score: 0.8275, AUC Score: 0.9009
#
# Validation: 	Fold 5 - Loss: 0.2460, Accuracy: 0.9219, Precision: 0.9476, Recall: 0.9025, F1 Score: 0.9224, AUC Score: 0.9654
#
# Epoch 6/25
# Training: 	Fold 1 - Loss: 0.4043, Accuracy: 0.8000, Precision: 0.8071, Recall: 0.8577, F1 Score: 0.8128, AUC Score: 0.9054
# Training: 	Fold 2 - Loss: 0.3353, Accuracy: 0.8389, Precision: 0.8577, Recall: 0.8762, F1 Score: 0.8635, AUC Score: 0.9295
# Training: 	Fold 3 - Loss: 0.3126, Accuracy: 0.8688, Precision: 0.8924, Recall: 0.8912, F1 Score: 0.8906, AUC Score: 0.9371
# Training: 	Fold 4 - Loss: 0.2910, Accuracy: 0.8708, Precision: 0.8885, Recall: 0.8967, F1 Score: 0.8916, AUC Score: 0.9466
#
# Validation: 	Fold 5 - Loss: 0.1831, Accuracy: 0.9219, Precision: 0.9162, Recall: 0.9495, F1 Score: 0.9316, AUC Score: 0.9785
# Model with best F1 Score of 0.9316 saved at epoch 6
#
# Epoch 7/25
# Training: 	Fold 1 - Loss: 0.2992, Accuracy: 0.8549, Precision: 0.8799, Recall: 0.8798, F1 Score: 0.8764, AUC Score: 0.9492
# Training: 	Fold 2 - Loss: 0.3110, Accuracy: 0.8771, Precision: 0.9097, Recall: 0.8928, F1 Score: 0.8966, AUC Score: 0.9343
# Training: 	Fold 3 - Loss: 0.3063, Accuracy: 0.8507, Precision: 0.8592, Recall: 0.9061, F1 Score: 0.8743, AUC Score: 0.9441
# Training: 	Fold 4 - Loss: 0.3732, Accuracy: 0.8521, Precision: 0.8671, Recall: 0.8911, F1 Score: 0.8723, AUC Score: 0.9119
#
# Validation: 	Fold 5 - Loss: 0.1851, Accuracy: 0.9306, Precision: 0.9357, Recall: 0.9442, F1 Score: 0.9394, AUC Score: 0.9804
# Model with best F1 Score of 0.9394 saved at epoch 7
#
# Epoch 8/25
# Training: 	Fold 1 - Loss: 0.3015, Accuracy: 0.8688, Precision: 0.8734, Recall: 0.9068, F1 Score: 0.8853, AUC Score: 0.9383
# Training: 	Fold 2 - Loss: 0.2571, Accuracy: 0.8958, Precision: 0.9266, Recall: 0.8985, F1 Score: 0.9095, AUC Score: 0.9621
# Training: 	Fold 3 - Loss: 0.2771, Accuracy: 0.8785, Precision: 0.9028, Recall: 0.9090, F1 Score: 0.9024, AUC Score: 0.9542
# Training: 	Fold 4 - Loss: 0.2855, Accuracy: 0.8777, Precision: 0.8858, Recall: 0.9307, F1 Score: 0.9004, AUC Score: 0.9606
#
# Validation: 	Fold 5 - Loss: 0.0963, Accuracy: 0.9766, Precision: 0.9821, Recall: 0.9747, F1 Score: 0.9778, AUC Score: 0.9984
# Model with best F1 Score of 0.9778 saved at epoch 8
#
# Epoch 9/25
# Training: 	Fold 1 - Loss: 0.2600, Accuracy: 0.8792, Precision: 0.8826, Recall: 0.9160, F1 Score: 0.8937, AUC Score: 0.9550
# Training: 	Fold 2 - Loss: 0.2666, Accuracy: 0.8778, Precision: 0.9022, Recall: 0.9087, F1 Score: 0.8956, AUC Score: 0.9597
# Training: 	Fold 3 - Loss: 0.2148, Accuracy: 0.9229, Precision: 0.9345, Recall: 0.9452, F1 Score: 0.9373, AUC Score: 0.9698
# Training: 	Fold 4 - Loss: 0.2262, Accuracy: 0.9042, Precision: 0.9079, Recall: 0.9349, F1 Score: 0.9191, AUC Score: 0.9658
#
# Validation: 	Fold 5 - Loss: 0.1391, Accuracy: 0.9219, Precision: 0.9345, Recall: 0.9085, F1 Score: 0.9208, AUC Score: 0.9875
#
# Epoch 10/25
# Training: 	Fold 1 - Loss: 0.2588, Accuracy: 0.8965, Precision: 0.9143, Recall: 0.9209, F1 Score: 0.9121, AUC Score: 0.9725
# Training: 	Fold 2 - Loss: 0.2634, Accuracy: 0.8840, Precision: 0.9075, Recall: 0.8950, F1 Score: 0.8985, AUC Score: 0.9611
# Training: 	Fold 3 - Loss: 0.2671, Accuracy: 0.8792, Precision: 0.8852, Recall: 0.8917, F1 Score: 0.8859, AUC Score: 0.9671
# Training: 	Fold 4 - Loss: 0.2701, Accuracy: 0.8780, Precision: 0.9133, Recall: 0.8826, F1 Score: 0.8928, AUC Score: 0.9542
#
# Validation: 	Fold 5 - Loss: 0.0944, Accuracy: 0.9688, Precision: 0.9535, Recall: 0.9886, F1 Score: 0.9696, AUC Score: 0.9965
#
# Epoch 11/25
# Training: 	Fold 1 - Loss: 0.2611, Accuracy: 0.8694, Precision: 0.8723, Recall: 0.9065, F1 Score: 0.8791, AUC Score: 0.9636
# Training: 	Fold 2 - Loss: 0.2906, Accuracy: 0.8819, Precision: 0.9053, Recall: 0.9090, F1 Score: 0.9010, AUC Score: 0.9555
# Training: 	Fold 3 - Loss: 0.2254, Accuracy: 0.9014, Precision: 0.9510, Recall: 0.8922, F1 Score: 0.9187, AUC Score: 0.9709
# Training: 	Fold 4 - Loss: 0.2392, Accuracy: 0.8905, Precision: 0.9119, Recall: 0.9117, F1 Score: 0.9073, AUC Score: 0.9643
#
# Validation: 	Fold 5 - Loss: 0.1643, Accuracy: 0.9375, Precision: 0.9382, Recall: 0.9416, F1 Score: 0.9394, AUC Score: 0.9801
#
# Epoch 12/25
# Training: 	Fold 1 - Loss: 0.2299, Accuracy: 0.8958, Precision: 0.9300, Recall: 0.9137, F1 Score: 0.9145, AUC Score: 0.9782
# Training: 	Fold 2 - Loss: 0.2661, Accuracy: 0.9049, Precision: 0.9173, Recall: 0.9331, F1 Score: 0.9179, AUC Score: 0.9680
# Training: 	Fold 3 - Loss: 0.1910, Accuracy: 0.9417, Precision: 0.9505, Recall: 0.9530, F1 Score: 0.9506, AUC Score: 0.9793
# Training: 	Fold 4 - Loss: 0.2238, Accuracy: 0.9051, Precision: 0.9133, Recall: 0.9335, F1 Score: 0.9183, AUC Score: 0.9681
#
# Validation: 	Fold 5 - Loss: 0.0838, Accuracy: 0.9844, Precision: 0.9821, Recall: 0.9886, F1 Score: 0.9849, AUC Score: 0.9987
# Model with best F1 Score of 0.9849 saved at epoch 12
#
# Epoch 13/25
# Training: 	Fold 1 - Loss: 0.2018, Accuracy: 0.9181, Precision: 0.9259, Recall: 0.9381, F1 Score: 0.9290, AUC Score: 0.9794
# Training: 	Fold 2 - Loss: 0.1616, Accuracy: 0.9313, Precision: 0.9642, Recall: 0.9224, F1 Score: 0.9416, AUC Score: 0.9847
# Training: 	Fold 3 - Loss: 0.1895, Accuracy: 0.9243, Precision: 0.9600, Recall: 0.9218, F1 Score: 0.9392, AUC Score: 0.9806
# Training: 	Fold 4 - Loss: 0.1708, Accuracy: 0.9375, Precision: 0.9451, Recall: 0.9545, F1 Score: 0.9478, AUC Score: 0.9830
#
# Validation: 	Fold 5 - Loss: 0.0419, Accuracy: 0.9922, Precision: 0.9868, Recall: 1.0000, F1 Score: 0.9932, AUC Score: 1.0000
# Model with best F1 Score of 0.9932 saved at epoch 13
#
# Epoch 14/25
# Training: 	Fold 1 - Loss: 0.1492, Accuracy: 0.9472, Precision: 0.9605, Recall: 0.9570, F1 Score: 0.9548, AUC Score: 0.9880
# Training: 	Fold 2 - Loss: 0.2024, Accuracy: 0.9146, Precision: 0.9158, Recall: 0.9579, F1 Score: 0.9275, AUC Score: 0.9814
# Training: 	Fold 3 - Loss: 0.1905, Accuracy: 0.9208, Precision: 0.9511, Recall: 0.9198, F1 Score: 0.9327, AUC Score: 0.9747
# Training: 	Fold 4 - Loss: 0.1495, Accuracy: 0.9530, Precision: 0.9659, Recall: 0.9634, F1 Score: 0.9633, AUC Score: 0.9878
#
# Validation: 	Fold 5 - Loss: 0.1017, Accuracy: 0.9609, Precision: 0.9403, Recall: 0.9808, F1 Score: 0.9599, AUC Score: 0.9936
#
# Epoch 15/25
# Training: 	Fold 1 - Loss: 0.1629, Accuracy: 0.9389, Precision: 0.9508, Recall: 0.9476, F1 Score: 0.9473, AUC Score: 0.9867
# Training: 	Fold 2 - Loss: 0.2443, Accuracy: 0.9132, Precision: 0.9171, Recall: 0.9484, F1 Score: 0.9242, AUC Score: 0.9731
# Training: 	Fold 3 - Loss: 0.2411, Accuracy: 0.9014, Precision: 0.9207, Recall: 0.9184, F1 Score: 0.9138, AUC Score: 0.9657
# Training: 	Fold 4 - Loss: 0.1764, Accuracy: 0.9205, Precision: 0.9479, Recall: 0.9305, F1 Score: 0.9360, AUC Score: 0.9843
#
# Validation: 	Fold 5 - Loss: 0.1074, Accuracy: 0.9609, Precision: 0.9566, Recall: 0.9722, F1 Score: 0.9638, AUC Score: 0.9923
#
# Epoch 16/25
# Training: 	Fold 1 - Loss: 0.1788, Accuracy: 0.9264, Precision: 0.9311, Recall: 0.9504, F1 Score: 0.9364, AUC Score: 0.9809
# Training: 	Fold 2 - Loss: 0.1631, Accuracy: 0.9458, Precision: 0.9485, Recall: 0.9627, F1 Score: 0.9543, AUC Score: 0.9823
# Training: 	Fold 3 - Loss: 0.1428, Accuracy: 0.9472, Precision: 0.9547, Recall: 0.9639, F1 Score: 0.9569, AUC Score: 0.9927
# Training: 	Fold 4 - Loss: 0.2599, Accuracy: 0.9068, Precision: 0.9150, Recall: 0.9366, F1 Score: 0.9244, AUC Score: 0.9787
#
# Validation: 	Fold 5 - Loss: 0.0590, Accuracy: 0.9766, Precision: 0.9752, Recall: 0.9861, F1 Score: 0.9806, AUC Score: 0.9990
#
# Epoch 17/25
# Training: 	Fold 1 - Loss: 0.2129, Accuracy: 0.9104, Precision: 0.9290, Recall: 0.9190, F1 Score: 0.9206, AUC Score: 0.9708
# Training: 	Fold 2 - Loss: 0.1684, Accuracy: 0.9292, Precision: 0.9557, Recall: 0.9296, F1 Score: 0.9410, AUC Score: 0.9824
# Training: 	Fold 3 - Loss: 0.1162, Accuracy: 0.9667, Precision: 0.9632, Recall: 0.9836, F1 Score: 0.9729, AUC Score: 0.9929
# Training: 	Fold 4 - Loss: 0.1314, Accuracy: 0.9458, Precision: 0.9678, Recall: 0.9425, F1 Score: 0.9546, AUC Score: 0.9890
#
# Validation: 	Fold 5 - Loss: 0.0575, Accuracy: 0.9766, Precision: 0.9752, Recall: 0.9861, F1 Score: 0.9806, AUC Score: 0.9981
#
# Epoch 18/25
# Training: 	Fold 1 - Loss: 0.1125, Accuracy: 0.9535, Precision: 0.9711, Recall: 0.9567, F1 Score: 0.9621, AUC Score: 0.9941
# Training: 	Fold 2 - Loss: 0.1872, Accuracy: 0.9299, Precision: 0.9352, Recall: 0.9544, F1 Score: 0.9382, AUC Score: 0.9887
# Training: 	Fold 3 - Loss: 0.1364, Accuracy: 0.9451, Precision: 0.9671, Recall: 0.9460, F1 Score: 0.9552, AUC Score: 0.9890
# Training: 	Fold 4 - Loss: 0.1472, Accuracy: 0.9488, Precision: 0.9599, Recall: 0.9600, F1 Score: 0.9582, AUC Score: 0.9854
#
# Validation: 	Fold 5 - Loss: 0.0646, Accuracy: 0.9766, Precision: 0.9821, Recall: 0.9747, F1 Score: 0.9778, AUC Score: 0.9981
#
# Epoch 19/25
# Training: 	Fold 1 - Loss: 0.1143, Accuracy: 0.9542, Precision: 0.9508, Recall: 0.9690, F1 Score: 0.9587, AUC Score: 0.9921
# Training: 	Fold 2 - Loss: 0.1453, Accuracy: 0.9236, Precision: 0.9456, Recall: 0.9349, F1 Score: 0.9382, AUC Score: 0.9880
# Training: 	Fold 3 - Loss: 0.1440, Accuracy: 0.9514, Precision: 0.9619, Recall: 0.9650, F1 Score: 0.9615, AUC Score: 0.9912
# Training: 	Fold 4 - Loss: 0.1613, Accuracy: 0.9342, Precision: 0.9318, Recall: 0.9641, F1 Score: 0.9446, AUC Score: 0.9851
#
# Validation: 	Fold 5 - Loss: 0.0312, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 1.0000
# Model with best F1 Score of 0.9942 saved at epoch 19
#
# Epoch 20/25
# Training: 	Fold 1 - Loss: 0.1770, Accuracy: 0.9306, Precision: 0.9441, Recall: 0.9405, F1 Score: 0.9391, AUC Score: 0.9817
# Training: 	Fold 2 - Loss: 0.1820, Accuracy: 0.9264, Precision: 0.9426, Recall: 0.9445, F1 Score: 0.9404, AUC Score: 0.9817
# Training: 	Fold 3 - Loss: 0.1587, Accuracy: 0.9375, Precision: 0.9375, Recall: 0.9653, F1 Score: 0.9500, AUC Score: 0.9833
# Training: 	Fold 4 - Loss: 0.1068, Accuracy: 0.9604, Precision: 0.9547, Recall: 0.9814, F1 Score: 0.9662, AUC Score: 0.9938
#
# Validation: 	Fold 5 - Loss: 0.0393, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 0.9997
#
# Epoch 21/25
# Training: 	Fold 1 - Loss: 0.1099, Accuracy: 0.9625, Precision: 0.9699, Recall: 0.9691, F1 Score: 0.9681, AUC Score: 0.9924
# Training: 	Fold 2 - Loss: 0.1068, Accuracy: 0.9535, Precision: 0.9793, Recall: 0.9475, F1 Score: 0.9616, AUC Score: 0.9947
# Training: 	Fold 3 - Loss: 0.1531, Accuracy: 0.9431, Precision: 0.9509, Recall: 0.9604, F1 Score: 0.9510, AUC Score: 0.9902
# Training: 	Fold 4 - Loss: 0.1087, Accuracy: 0.9667, Precision: 0.9788, Recall: 0.9660, F1 Score: 0.9720, AUC Score: 0.9920
#
# Validation: 	Fold 5 - Loss: 0.0340, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9994
# Model with best F1 Score of 0.9944 saved at epoch 21
#
# Epoch 22/25
# Training: 	Fold 1 - Loss: 0.1084, Accuracy: 0.9597, Precision: 0.9619, Recall: 0.9658, F1 Score: 0.9612, AUC Score: 0.9952
# Training: 	Fold 2 - Loss: 0.1279, Accuracy: 0.9583, Precision: 0.9741, Recall: 0.9576, F1 Score: 0.9647, AUC Score: 0.9894
# Training: 	Fold 3 - Loss: 0.1254, Accuracy: 0.9576, Precision: 0.9731, Recall: 0.9621, F1 Score: 0.9660, AUC Score: 0.9947
# Training: 	Fold 4 - Loss: 0.1444, Accuracy: 0.9384, Precision: 0.9337, Recall: 0.9597, F1 Score: 0.9427, AUC Score: 0.9899
#
# Validation: 	Fold 5 - Loss: 0.0207, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
# Model with best F1 Score of 1.0000 saved at epoch 22
#
# Epoch 23/25
# Training: 	Fold 1 - Loss: 0.0738, Accuracy: 0.9771, Precision: 0.9791, Recall: 0.9793, F1 Score: 0.9785, AUC Score: 0.9969
# Training: 	Fold 2 - Loss: 0.0875, Accuracy: 0.9576, Precision: 0.9774, Recall: 0.9570, F1 Score: 0.9657, AUC Score: 0.9957
# Training: 	Fold 3 - Loss: 0.1020, Accuracy: 0.9576, Precision: 0.9842, Recall: 0.9521, F1 Score: 0.9666, AUC Score: 0.9955
# Training: 	Fold 4 - Loss: 0.1554, Accuracy: 0.9530, Precision: 0.9411, Recall: 0.9719, F1 Score: 0.9538, AUC Score: 0.9906
#
# Validation: 	Fold 5 - Loss: 0.0353, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9861, F1 Score: 0.9929, AUC Score: 0.9997
#
# Epoch 24/25
# Training: 	Fold 1 - Loss: 0.1860, Accuracy: 0.9451, Precision: 0.9238, Recall: 0.9630, F1 Score: 0.9347, AUC Score: 0.9876
# Training: 	Fold 2 - Loss: 0.1500, Accuracy: 0.9396, Precision: 0.9649, Recall: 0.9364, F1 Score: 0.9489, AUC Score: 0.9857
# Training: 	Fold 3 - Loss: 0.1261, Accuracy: 0.9542, Precision: 0.9731, Recall: 0.9543, F1 Score: 0.9623, AUC Score: 0.9907
# Training: 	Fold 4 - Loss: 0.0709, Accuracy: 0.9729, Precision: 0.9741, Recall: 0.9804, F1 Score: 0.9764, AUC Score: 0.9978
#
# Validation: 	Fold 5 - Loss: 0.0334, Accuracy: 0.9766, Precision: 0.9886, Recall: 0.9747, F1 Score: 0.9815, AUC Score: 0.9990
#
# Epoch 25/25
# Training: 	Fold 1 - Loss: 0.0854, Accuracy: 0.9771, Precision: 0.9743, Recall: 0.9860, F1 Score: 0.9793, AUC Score: 0.9934
# Training: 	Fold 2 - Loss: 0.0880, Accuracy: 0.9729, Precision: 0.9700, Recall: 0.9844, F1 Score: 0.9761, AUC Score: 0.9939
# Training: 	Fold 3 - Loss: 0.1096, Accuracy: 0.9403, Precision: 0.9772, Recall: 0.9362, F1 Score: 0.9523, AUC Score: 0.9941
# Training: 	Fold 4 - Loss: 0.1331, Accuracy: 0.9518, Precision: 0.9419, Recall: 0.9829, F1 Score: 0.9584, AUC Score: 0.9941
#
# Validation: 	Fold 5 - Loss: 0.0422, Accuracy: 0.9844, Precision: 0.9713, Recall: 1.0000, F1 Score: 0.9852, AUC Score: 0.9987
# Model Size: 9.13 MB
# CPU times: user 34min 26s, sys: 2min 55s, total: 37min 21s
# Wall time: 1min 33s

# %% [markdown]
# We can now evaluate our models performance using a test set on a single batch

# %%
# %%time

model.load_state_dict(torch.load(f"{weights_dir}/model_best_f1score_binary_11062024.pth"))
test_loss, test_performance_metrics = eval(test_loader, model, loss_fn, 'Testing', CumulativeMetrics(model_type="binary", device=device))
test_accuracy, test_precision, test_recall, test_f1, test_auc = test_performance_metrics.values()
print(f"Testing: \tLoss: {test_loss:.4f}, Accuracy: {test_accuracy:.4f}, Precision: {test_precision:.4f}, Recall: {test_recall:.4f}, F1 Score: {test_f1:.4f}, AUC Score: {test_auc:.4f}")
# Out:
# Testing: 	Loss: 0.0766, Accuracy: 0.9688, Precision: 0.9642, Recall: 0.9746, F1 Score: 0.9689, AUC Score: 0.9960
# CPU times: user 935 ms, sys: 110 ms, total: 1.05 s
# Wall time: 72 ms

# %%
train_metrics_df = pd.DataFrame(train_metrics_df)
display(train_metrics_df.sort_values(by='Accuracy', ascending=False)[:25])
# Out:
#         Loss  Accuracy  Precision    Recall  F1 Score  AUC Score
# 88  0.073814  0.977083   0.979097  0.979282  0.978477   0.996907
# 96  0.085422  0.977083   0.974269  0.986032  0.979306   0.993358
# 95  0.070945  0.972917   0.974075  0.980414  0.976390   0.997794
# 97  0.088032  0.972917   0.969997  0.984357  0.976130   0.993938
# 66  0.116188  0.966667   0.963202  0.983556  0.972877   0.992902
# 83  0.108668  0.966667   0.978778  0.965986  0.971965   0.991958
# 80  0.109879  0.962500   0.969876  0.969073  0.968076   0.992407
# 79  0.106792  0.960417   0.954749  0.981362  0.966174   0.993783
# 84  0.108362  0.959722   0.961912  0.965795  0.961165   0.995182
# 85  0.127860  0.958333   0.974061  0.957619  0.964723   0.989436
# 90  0.102039  0.957639   0.984151  0.952079  0.966577   0.995472
# 89  0.087490  0.957639   0.977384  0.956991  0.965679   0.995722
# 86  0.125440  0.957639   0.973068  0.962104  0.966043   0.994738
# 94  0.126061  0.954167   0.973108  0.954338  0.962299   0.990740
# 72  0.114280  0.954167   0.950834  0.969013  0.958748   0.992109
# 68  0.112540  0.953472   0.971085  0.956695  0.962088   0.994092
# 81  0.106788  0.953472   0.979300  0.947491  0.961627   0.994688
# 91  0.155400  0.952976   0.941133  0.971852  0.953755   0.990614
# 55  0.149542  0.952976   0.965905  0.963406  0.963266   0.987767
# 99  0.133137  0.951786   0.941942  0.982852  0.958427   0.994144
# 74  0.143963  0.951389   0.961901  0.965001  0.961508   0.991209
# 71  0.147150  0.948810   0.959923  0.959997  0.958157   0.985420
# 52  0.149230  0.947222   0.960498  0.956963  0.954781   0.988045
# 62  0.142753  0.947222   0.954713  0.963915  0.956914   0.992719
# 61  0.163121  0.945833   0.948483  0.962728  0.954281   0.982279

# %%
val_metrics_df = pd.DataFrame(val_metrics_df)
display(val_metrics_df.sort_values(by='Accuracy', ascending=False)[:25])
# Out:
#         Loss  Accuracy  Precision    Recall  F1 Score  AUC Score
# 10  0.020727  1.000000   1.000000  1.000000  1.000000   1.000000
# 9   0.033951  0.992188   0.989130  1.000000  0.994444   0.999359
# 7   0.041916  0.992188   0.986842  1.000000  0.993243   1.000000
# 8   0.031214  0.992188   1.000000  0.988636  0.994186   1.000000
# 6   0.083802  0.984375   0.982143  0.988636  0.984927   0.998718
# 5   0.096305  0.976562   0.982143  0.974747  0.977784   0.998397
# 4   0.185108  0.930607   0.935745  0.944153  0.939438   0.980449
# 3   0.183136  0.921875   0.916162  0.949495  0.931638   0.978526
# 2   0.306116  0.914982   0.897436  0.955517  0.924357   0.954487
# 1   0.477154  0.766544   0.768287  0.863054  0.801765   0.831731
# 0   0.580323  0.660846   0.663988  0.853584  0.740312   0.765705

# %%
model_name = f"MobileNetV2"#, {get_model_size(model)}"
plot_metrics(train_metrics_df, "Training", model_name)
plot_metrics(val_metrics_df, "Validation", model_name)
