# %% [markdown]
# <a href="https://colab.research.google.com/github/romerocruzsa/cp-anemia-detection/blob/notebook-upload/Anemia_MobileNet_BaseVsQAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transfer Learning on MobileNetV2 for Anemia Detection and Hemoglobin Estimation
#
# **Author**: [Sebastián A. Cruz Romero](https://github.com/romerocruzsa/)
#
# **Reviewed by**:
#
# This tutorial builds on [CP-Anemic Paper]() paper. Transfer learning refers to methods that leverage pretrained models in different applications and datasets. This tutorial replicates the methodology for implementing Deep Learning architectures for Anemia Detection and Hemoglobin estimation through *Conjutiva pallor* analysis. Warning: we use a lot of boilerplate code from other PyTorch repos to, for example, define the [MobileNetV2](https://arxiv.org/abs/1801.04381) model architecture, define data loaders, and so on.

# %% [markdown]
# ## Installing Dependencies and Pre-Requisites

# %%
# !yes y | pip uninstall torch torchvision
# !yes y | pip install --pre torch torchvision -f https://download.pytorch.org/whl/nightly/cu101/torch_nightly.html
# # Install other dependencies
# !yes y | pip install torchinfo
# !yes y | pip install torchmetrics

# %%
# Import necessary libraries for file handling, data manipulation, and visualization
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Import libraries for working with images and transformations
from PIL import Image
import cv2 as cv

# Import PyTorch modules for model building, data handling, and evaluation
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.models as models
import torchvision.models.quantization as quant_models
from torch.utils.data import Dataset, DataLoader, Subset
from torchinfo import summary

# Import libraries for machine learning metrics and model evaluation
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve, mean_squared_error, mean_absolute_error, r2_score
import torchmetrics
from tqdm import tqdm

import warnings
warnings.filterwarnings('ignore')

# Set the seed.
seed = 42
torch.manual_seed(seed)

# %% [markdown]
# ## CP-AnemiC: A *conjunctival pallor* dataset and benchmark for anemia detection in children
#
# Anemia is a universal public health issue, which occurs as the result of a reduction in red blood cells. Early detection of anemia in children is highly desirable for effective treatment measures. We train and test our quantizable MobileNetV2 architecture to detect anemia on [CP-AnemiC](https://www.sciencedirect.com/science/article/pii/S2590093523000395), comprising 710 individuals (range of age, 6–59 months), gathered from several hospitals in Ghana. The conjunctiva image-based dataset is supported with Hb levels (g/dL) annotations for accurate diagnosis of anemia.

# %%
data_dir="/home/sebastian-cruz6/workspace/cp-anemia-detection/data/cp-anemia/"
weights_dir="/home/sebastian-cruz6/workspace/cp-anemia-detection/notebooks/weights"
anemic_dir=data_dir+"/Anemic"
non_anemic_dir=data_dir+"/Non-anemic"
signature = "11062024"

# %%
# data_dir = "/home/sebastian-cruz6/workspace/model-compression/data/cp-anemia/"
# weights_dir = "/home/sebastian-cruz6/workspace/model-compression/models/weights/"
# anemic_dir = data_dir+"Anemic/"
# non_anemic_dir = data_dir+"Non-anemic/"

data_sheet_path = data_dir+"Anemia_Data_Collection_Sheet.csv"
data_sheet = pd.read_csv(data_sheet_path)
display(data_sheet)
# Out:
#       IMAGE_ID  HB_LEVEL    Severity  Age(Months)  GENDER      REMARK  \
# 0    Image_001      9.80    Moderate            6  Female      Anemic
# 1    Image_002      9.90    Moderate           24    Male      Anemic
# 2    Image_003     11.10  Non-Anemic           24  Female  Non-anemic
# 3    Image_004     12.50  Non-Anemic           12    Male  Non-anemic
# 4    Image_005      9.90    Moderate           24    Male      Anemic
# ..         ...       ...         ...          ...     ...         ...
# 705  Image_706     12.80  Non-Anemic           48    Male  Non-anemic
# 706  Image_707     11.47  Non-Anemic           48  Female  Non-anemic
# 707  Image_708     11.60  Non-Anemic           60    Male  Non-anemic
# 708  Image_709     12.10  Non-Anemic           48    Male  Non-anemic
# 709  Image_710     11.70  Non-Anemic           24    Male  Non-anemic
#
#                              HOSPITAL     CITY/TOWN    MUNICIPALITY/DISTRICT  \
# 0    Nkawie-Toase Government Hospital  Nkawie-Toase   Atwima Nwabiagya South
# 1           Ejusu Government Hospital         Ejusu       Ejusu Municipality
# 2           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 3           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 4          Sunyani Municipal Hospital       Sunyani     Sunyani Municipality
# ..                                ...           ...                      ...
# 705      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 706         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 707   Komfo Anokye Teaching Hospital        Kumasi       Kumasi Metropolitan
# 708      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 709         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
#
#          REGION COUNTRY
# 0       Ashanti   Ghana
# 1       Ashanti   Ghana
# 2     Bono-East   Ghana
# 3     Bono-East   Ghana
# 4          Bono   Ghana
# ..          ...     ...
# 705  Upper East   Ghana
# 706   Bono-East   Ghana
# 707     Ashanti   Ghana
# 708  Upper East   Ghana
# 709   Bono-East   Ghana
#
# [710 rows x 11 columns]

# %%
# Mapping diagnosis to severity
severity_mapping = {
    "Non-Anemic": [1,0,0,0],
    "Mild": [0,1,0,0],
    "Moderate": [0,0,1,0],
    "Severe": [0,0,0,1],
}
# Mapping diagnosis to severity
remark_mapping = {
    "Non-anemic": 0,
    "Anemic": 1
}

data_sheet['SEVERITY_ONEHOT'] = data_sheet['Severity'].map(severity_mapping)
data_sheet['REMARK_ONEHOT'] = data_sheet['REMARK'].map(remark_mapping)
display(data_sheet)
# Out:
#       IMAGE_ID  HB_LEVEL    Severity  Age(Months)  GENDER      REMARK  \
# 0    Image_001      9.80    Moderate            6  Female      Anemic
# 1    Image_002      9.90    Moderate           24    Male      Anemic
# 2    Image_003     11.10  Non-Anemic           24  Female  Non-anemic
# 3    Image_004     12.50  Non-Anemic           12    Male  Non-anemic
# 4    Image_005      9.90    Moderate           24    Male      Anemic
# ..         ...       ...         ...          ...     ...         ...
# 705  Image_706     12.80  Non-Anemic           48    Male  Non-anemic
# 706  Image_707     11.47  Non-Anemic           48  Female  Non-anemic
# 707  Image_708     11.60  Non-Anemic           60    Male  Non-anemic
# 708  Image_709     12.10  Non-Anemic           48    Male  Non-anemic
# 709  Image_710     11.70  Non-Anemic           24    Male  Non-anemic
#
#                              HOSPITAL     CITY/TOWN    MUNICIPALITY/DISTRICT  \
# 0    Nkawie-Toase Government Hospital  Nkawie-Toase   Atwima Nwabiagya South
# 1           Ejusu Government Hospital         Ejusu       Ejusu Municipality
# 2           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 3           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 4          Sunyani Municipal Hospital       Sunyani     Sunyani Municipality
# ..                                ...           ...                      ...
# 705      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 706         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 707   Komfo Anokye Teaching Hospital        Kumasi       Kumasi Metropolitan
# 708      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 709         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
#
#          REGION COUNTRY SEVERITY_ONEHOT  REMARK_ONEHOT
# 0       Ashanti   Ghana    [0, 0, 1, 0]              1
# 1       Ashanti   Ghana    [0, 0, 1, 0]              1
# 2     Bono-East   Ghana    [1, 0, 0, 0]              0
# 3     Bono-East   Ghana    [1, 0, 0, 0]              0
# 4          Bono   Ghana    [0, 0, 1, 0]              1
# ..          ...     ...             ...            ...
# 705  Upper East   Ghana    [1, 0, 0, 0]              0
# 706   Bono-East   Ghana    [1, 0, 0, 0]              0
# 707     Ashanti   Ghana    [1, 0, 0, 0]              0
# 708  Upper East   Ghana    [1, 0, 0, 0]              0
# 709   Bono-East   Ghana    [1, 0, 0, 0]              0
#
# [710 rows x 13 columns]

# %% [markdown]
# ### Loading Data
#
# We will use `torchvision` and `torch.utils.data` packages to load the data. The problem we are trying to solve today is classifying images of the inner-part of the eyelid between Anemic and Non-anemic patients. The dataset contains about 710 images of which we will do an 80/20 split between training and testing subset. After that, we perform 5-fold cross-validation with our training set to avoid overfitting on smaller dataset. Since we are using transfer learning, we should be able to generalize reasonably well.

# %%
# # BATCH_SIZE = 4
# # test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# for img, binary_label, multiclass_label, hb_level, descriptor in test_loader:
#   print(binary_label, multiclass_label, hb_level, descriptor)
#   break

# %%
# Define data augmentations or transformations
transform = transforms.Compose([
    transforms.Resize((256, 192)),
    transforms.RandomHorizontalFlip(p=np.random.rand()),
    transforms.RandomVerticalFlip(p=np.random.rand()),
    transforms.RandomRotation(degrees=np.random.randint(0, 360)),
    transforms.RandomAffine(degrees=np.random.randint(0, 360)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Custom dataset class
class CPAnemiCDataset(Dataset):
    def __init__(self, dir, df, transform=None):
        self.dir = dir
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_id = row['IMAGE_ID']
        img_folder = row['REMARK']
        img_path = os.path.join(self.dir, img_folder, img_id + ".png")
        img = Image.open(img_path).convert('RGB')

        if self.transform:
            img = self.transform(img)

        binary_label = torch.tensor(row['REMARK_ONEHOT'], dtype=torch.float32)  # Adjusted for BCEWithLogitsLoss
        multiclass_label = torch.tensor(row['SEVERITY_ONEHOT'], dtype=torch.float32)
        hb_level = torch.tensor(row['HB_LEVEL'], dtype=torch.float32)
        descriptor = row['REMARK']+"/"+row['Severity']

        return img, binary_label, multiclass_label, hb_level, descriptor

    # Load the dataset
image_dataset = CPAnemiCDataset(data_dir, data_sheet, transform=transform)
train_dataset, test_dataset = train_test_split(image_dataset, test_size=0.20, shuffle=True)

print(f"Image Dataset Size (All): {len(image_dataset)}, \
        Train Size: {len(train_dataset)}, \
        Test Size: {len(test_dataset)}")

BATCH_SIZE = 32
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Image Dataset Size (All): 710,         Train Size: 568,         Test Size: 142

# %%
# Default device
device = torch.device('cpu')

# Check for CUDA availability
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    print("CUDA is not available, using CPU.")

print(f"Selected device: {device}")
# Out:
# Selected device: cuda

# %% [markdown]
# ## Helper functions
#
# We define several helper functions to help with model evaluation, understanding our predicitve performance, and visualizing our results.

# %% [markdown]
# ### Performance Metrics and Model Evalution

# %%
import torch
import torchmetrics
import numpy as np
from sklearn.metrics import roc_auc_score, mean_squared_error, mean_absolute_error, r2_score

class CumulativeMetrics:
    def __init__(self, model_type="binary", num_classes=1, device="cpu"):
        self.model_type = model_type
        self.num_classes = num_classes
        self.device = device
        self.reset()

        # Classification metrics initialization
        if model_type == "binary":
            self.accuracy = torchmetrics.Accuracy(task="binary").to(device)
            self.precision = torchmetrics.Precision(task="binary").to(device)
            self.recall = torchmetrics.Recall(task="binary").to(device)
            self.f1_score = torchmetrics.F1Score(task="binary").to(device)

    def reset(self):
        self.num_batches = 0
        # Cumulative sums for each metric
        self.cum_acc = 0.0
        self.cum_prec = 0.0
        self.cum_rec = 0.0
        self.cum_f1 = 0.0
        self.cum_mse = 0.0
        self.cum_mae = 0.0
        self.cum_r2 = 0.0
        # Storage for AUC
        self.y_true_all = []
        self.y_score_all = []

    def update(self, y_pred: torch.Tensor, y_true: torch.Tensor):
        if self.model_type == "binary":
            y_pred_class = torch.round(torch.sigmoid(y_pred)).int()
            self.y_true_all.extend(y_true.detach().cpu().numpy().tolist())
            self.y_score_all.extend(torch.sigmoid(y_pred).detach().cpu().numpy().tolist())

            # Update binary classification metrics
            self.cum_acc += self.accuracy(y_pred_class, y_true).item()
            self.cum_prec += self.precision(y_pred_class, y_true).item()
            self.cum_rec += self.recall(y_pred_class, y_true).item()
            self.cum_f1 += self.f1_score(y_pred_class, y_true).item()

        elif self.model_type == "regression":
            y_true_np = y_true.detach().cpu().numpy()
            y_pred_np = y_pred.detach().cpu().numpy()
            self.y_true_all.extend(y_true_np.tolist())
            self.y_score_all.extend(y_pred_np.tolist())

            # Compute per-batch regression metrics
            self.cum_mse += mean_squared_error(y_true_np, y_pred_np)
            self.cum_mae += mean_absolute_error(y_true_np, y_pred_np)
            self.cum_r2 += r2_score(y_true_np, y_pred_np)

        self.num_batches += 1

    def compute(self):
        if self.model_type == "binary":
            return {
                "Accuracy": self.cum_acc / self.num_batches,
                "Precision": self.cum_prec / self.num_batches,
                "Recall": self.cum_rec / self.num_batches,
                "F1 Score": self.cum_f1 / self.num_batches,
                "AUC Score": roc_auc_score(self.y_true_all, self.y_score_all)
            }

        elif self.model_type == "regression":
            return {
                "Mean Squared Error": self.cum_mse / self.num_batches,
                "Mean Absolute Error": self.cum_mae / self.num_batches,
                "R2 Score": self.cum_r2 / self.num_batches,
            }

# %% [markdown]
# ## Model Training and Evaluation
#
# Below is a generic function for model training. This function also
#
# * Calculates model performance metrics (Loss, Accuracy, Precision, F1 Score, etc.)
# * Saves the best model per highest F1 Score during the validation fold
# * Switches between `Validation` and `Test` phases

# %%
def train(dataloader, model, loss_fn, optimizer, cumulative_metrics, task_type="binary"):
    model.train()
    cumulative_metrics.reset()
    batch_losses = []

    for _, (img, binary, multiclass, hb_level, _) in enumerate(dataloader):
        img = img.to(device)
        binary = binary.to(device).unsqueeze(1).float()
        multiclass = multiclass.to(device)
        hb_level = hb_level.to(device).unsqueeze(1).float()

        optimizer.zero_grad()

        # Forward pass and loss calculation based on task type
        if task_type == "binary":
            pred = model(img)
            loss = loss_fn(pred, binary)  # Binary target
        elif task_type == "regression":
            pred = model(img)  # Direct prediction for regression
            loss = loss_fn(pred, hb_level)  # Regression target
        else:
            raise ValueError("Unsupported task type. Choose 'binary' or 'regression'.")
        
        # Backpropagation
        loss.backward()
        optimizer.step()

        batch_losses.append(loss.item())
        cumulative_metrics.update(pred, binary if task_type == "binary" else hb_level)

    avg_loss = sum(batch_losses) / len(batch_losses)
    performance_metrics = cumulative_metrics.compute()

    return avg_loss, performance_metrics


def eval(dataloader, model, loss_fn, mode, cumulative_metrics, task_type="binary"):
    model.eval()
    cumulative_metrics.reset()
    batch_losses = []

    with torch.no_grad():
        for _, (img, binary, multiclass, hb_level, _) in enumerate(dataloader):
            img = img.to(device)
            binary = binary.to(device).unsqueeze(1).float()
            multiclass = multiclass.to(device)
            hb_level = hb_level.to(device).unsqueeze(1).float()

            # Forward pass and loss calculation based on task type
            if task_type == "binary":
                pred = model(img)
                loss = loss_fn(pred, binary)  # Binary target
            elif task_type == "regression":
                pred = model(img)  # Direct prediction for regression
                loss = loss_fn(pred, hb_level)  # Regression target
            else:
                raise ValueError("Unsupported task type. Choose 'binary' or 'regression'.")

            batch_losses.append(loss.item())
            cumulative_metrics.update(pred, binary if task_type == "binary" else hb_level)

    avg_loss = sum(batch_losses) / len(batch_losses)
    performance_metrics = cumulative_metrics.compute()

    return avg_loss, performance_metrics

# %% [markdown]
# More support functions to:
#
# * Get model size in MB
# * Plot phase accuracy and loss
# * Visualize our model predictions
# * Load the `MobileNetV2` in its base and quantizable form
#
# *Note that we do modifications in the last sequential layer to adjust for the classes to be predicted.*

# %%
def get_model_size(mdl):
    torch.save(mdl.state_dict(), "tmp.pt")
    model_size = "Model Size: %.2f MB" %(os.path.getsize("tmp.pt")/1e6)
    os.remove('tmp.pt')
    return model_size

def plot_metrics(metrics_df, phase, model):
    # Create a figure with 2 subplots (1 row, 2 columns)
    fig, ax = plt.subplots(1, 2, figsize=(14, 5))

    # Plot Loss
    loss_df = metrics_df["Loss"]
    ax[0].plot(range(len(loss_df)), loss_df, linestyle='-', color='blue')
    ax[0].set_title(f"{phase} Loss with {model} on CP-AnemiC Dataset")
    ax[0].set_xlabel("Folds")
    ax[0].set_ylabel("Cross-Entropy Loss")
    ax[0].grid(True)

    # Plot Accuracy
    acc_df = metrics_df["Accuracy"]
    ax[1].plot(range(len(acc_df)), acc_df, linestyle='-', color='green')
    ax[1].set_title(f"{phase} Accuracy with {model} on CP-AnemiC Dataset")
    ax[1].set_xlabel("Folds")
    ax[1].set_ylabel("Accuracy")
    ax[1].grid(True)

    # Adjust layout to prevent overlap and display the plots
    plt.tight_layout()
    plt.show()

def visualize_predictions(model, dataloader, rows=5, cols=5, device='cpu'):
    # Set the model to evaluation mode
    model.eval()
    size = len(dataloader.dataset)

    # Get a batch of images from the dataloader
    X, y, descriptors = next(iter(dataloader))
    inputs = X.to(device)
    labels = y.to(device)

    # Run the inputs through the model
    with torch.no_grad():
        pred = (torch.sigmoid(model(X)) >= 0.5).float()
        pred = pred.to(device)

        # Create a grid of images with their predictions
        fig, axes = plt.subplots(rows, cols, figsize=(cols * 3, rows * 3))
        fig.suptitle('Model Predictions', fontsize=12)

        # Loop through the grid and plot images
        for i in range(rows * cols):
            if i >= len(inputs):
                break

            ax = axes[i // cols, i % cols] if rows > 1 else axes[i % cols]
            img = inputs[i].numpy().transpose((1, 2, 0))
            mean = np.array([0.485, 0.456, 0.406])
            std = np.array([0.229, 0.224, 0.225])
            img = std * img + mean  # Unnormalize the image
            img = np.clip(img, 0, 1)

            ax.imshow(img)
            ax.axis('off')
            pred_label = pred[i].item()
            true_label = labels[i].item()
            ax.set_title(f'Pred: {pred_label} | True: {true_label}', fontsize=10)

        plt.tight_layout()
        plt.show()

def load_mobilenet():
#     model_quantized = quant_models.mobilenet_v2(weights="MobileNet_V2_Weights.DEFAULT", quantize=False)
    model = models.mobilenet_v2(pretrained=True)
    num_ftrs = model.classifier[1].in_features
    model.classifier = nn.Sequential(
        nn.Dropout(p=0.2),
        nn.Linear(num_ftrs, 1)  # Adjust based on your number of classes
    )

    model = model.to(device)
    return model

# %% [markdown]
# ## Transfer Learning with MobileNetV2
#
# MobileNetV2 was trained on ImageNet and is optimized to run on mobile and other low-power applications. It's 155 layers deep and very efficient for object detection and image segmentation tasks, as well as classification tasks like this one. The architecture has three defining characteristics:
#
# * Depthwise separable convolutions
# * Thin input and output bottlenecks between layers
# * Shortcut connections between bottleneck layers

# %% [markdown]
# MobileNetV2 uses depthwise separable convolutions as efficient building blocks. Traditional convolutions are often very resource-intensive, and depthwise separable convolutions are able to reduce the number of trainable parameters and operations and also speed up convolutions in two steps:
#
# 1. The first step calculates an intermediate result by convolving on each of the channels independently. This is the depthwise convolution.
#
# 1. In the second step, another convolution merges the outputs of the previous step into one. This gets a single result from a single feature at a time, and then is applied to all the filters in the output layer. This is the pointwise convolution, or: Shape of the depthwise convolution X Number of filters.
#
# Each block consists of an inverted residual structure with a bottleneck at each end. These bottlenecks encode the intermediate inputs and outputs in a low dimensional space, and prevent non-linearities from destroying important information.
#
# The shortcut connections, which are similar to the ones in traditional residual networks, serve the same purpose of speeding up training and improving predictions. These connections skip over the intermediate convolutions and connect the bottleneck layers.

# %%
model = models.mobilenet_v2(weights="IMAGENET1K_V1")
model.classifier[1] = torch.nn.Linear(in_features=1280, out_features=1)
model = model.to(device)
print(summary(model))
# Out:
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# MobileNetV2                                        --
# ├─Sequential: 1-1                                  --
# │    └─Conv2dNormActivation: 2-1                   --
# │    │    └─Conv2d: 3-1                            864
# │    │    └─BatchNorm2d: 3-2                       64
# │    │    └─ReLU6: 3-3                             --
# │    └─InvertedResidual: 2-2                       --
# │    │    └─Sequential: 3-4                        896
# │    └─InvertedResidual: 2-3                       --
# │    │    └─Sequential: 3-5                        5,136
# │    └─InvertedResidual: 2-4                       --
# │    │    └─Sequential: 3-6                        8,832
# │    └─InvertedResidual: 2-5                       --
# │    │    └─Sequential: 3-7                        10,000
# │    └─InvertedResidual: 2-6                       --
# │    │    └─Sequential: 3-8                        14,848
# │    └─InvertedResidual: 2-7                       --
# │    │    └─Sequential: 3-9                        14,848
# │    └─InvertedResidual: 2-8                       --
# │    │    └─Sequential: 3-10                       21,056
# │    └─InvertedResidual: 2-9                       --
# │    │    └─Sequential: 3-11                       54,272
# │    └─InvertedResidual: 2-10                      --
# │    │    └─Sequential: 3-12                       54,272
# │    └─InvertedResidual: 2-11                      --
# │    │    └─Sequential: 3-13                       54,272
# │    └─InvertedResidual: 2-12                      --
# │    │    └─Sequential: 3-14                       66,624
# │    └─InvertedResidual: 2-13                      --
# │    │    └─Sequential: 3-15                       118,272
# │    └─InvertedResidual: 2-14                      --
# │    │    └─Sequential: 3-16                       118,272
# │    └─InvertedResidual: 2-15                      --
# │    │    └─Sequential: 3-17                       155,264
# │    └─InvertedResidual: 2-16                      --
# │    │    └─Sequential: 3-18                       320,000
# │    └─InvertedResidual: 2-17                      --
# │    │    └─Sequential: 3-19                       320,000
# │    └─InvertedResidual: 2-18                      --
# │    │    └─Sequential: 3-20                       473,920
# │    └─Conv2dNormActivation: 2-19                  --
# │    │    └─Conv2d: 3-21                           409,600
# │    │    └─BatchNorm2d: 3-22                      2,560
# │    │    └─ReLU6: 3-23                            --
# ├─Sequential: 1-2                                  --
# │    └─Dropout: 2-20                               --
# │    └─Linear: 2-21                                1,281
# ===========================================================================
# Total params: 2,225,153
# Trainable params: 2,225,153
# Non-trainable params: 0
# ===========================================================================

# %% [markdown]
# Note the last 2 layers here. They are the so called top layers, and they are responsible of the classification in the model.
#
# **What you should remember:**
#
# MobileNetV2's unique features are:
# * Depthwise separable convolutions that provide lightweight feature filtering and creation
# * Input and output bottlenecks that preserve important information on either end of the block
# * Depthwise separable convolutions deal with both spatial and depth (number of channels) dimensions

# %%
# %%time

# # Training parameters
# task_type = "regression"  # Choose from "binary", "multiclass", "regression"
# BATCH_SIZE = 32
# EPOCHS = 150
# FOLDS = 5

# # Assuming CumulativeMetrics is implemented elsewhere and is compatible with task_type
# cumulative_metrics = CumulativeMetrics(model_type=task_type, device=device)  # Instantiate metrics tracker

# # 5-fold cross-validation setup
# kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)

# # Initialize model, loss function, and optimizer
# model = load_mobilenet()  # Your MobileNetV2 instance
# loss_fn = torch.nn.BCEWithLogitsLoss() if task_type == "binary" else torch.nn.MSELoss()  # Select appropriate loss
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# # Directory to save the model with the best performance metrics
# os.makedirs(weights_dir, exist_ok=True)

# best_val_score = -float('inf') if task_type == "binary" else -float('inf')
# train_metrics_df = []
# val_metrics_df = []

# for epoch in range(EPOCHS):
#     print(f"\nEpoch {epoch+1}/{EPOCHS}")
#     fold = 1
#     fold_best_train_f1score = float('inf') if task_type == "binary" else -float('inf')

#     for train_idx, val_idx in kf.split(train_dataset):
#         train_subset = Subset(image_dataset, train_idx)
#         val_subset = Subset(image_dataset, val_idx)

#         train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
#         val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False)

#         if fold == FOLDS:
#             # Validation loop
#             avg_val_loss, val_metrics = eval(val_loader, model, loss_fn, mode="Validation",
#                                              cumulative_metrics=cumulative_metrics, task_type=task_type)

#             if task_type == "binary":
#                 # Unpack classification metrics
#                 avg_val_accuracy, avg_val_precision, avg_val_recall, avg_val_f1, avg_val_auc = val_metrics.values()
#                 print(f"\nValidation: \tFold {fold} - Loss: {avg_val_loss:.4f}, Accuracy: {avg_val_accuracy:.4f}, "
#                       f"Precision: {avg_val_precision:.4f}, Recall: {avg_val_recall:.4f}, F1 Score: {avg_val_f1:.4f}, AUC Score: {avg_val_auc:.4f}")

#                 # Save model with the best validation F1 score
#                 if avg_val_f1 > best_val_score:
#                     best_val_score = avg_val_f1
#                     val_metrics_dict = {**{"Loss": avg_val_loss}, **val_metrics}
#                     val_metrics_df.append(val_metrics_dict)
#                     torch.save(model.state_dict(), f'{weights_dir}/model_best_f1score_{task_type}_{signature}.pth')
#                     print(f"Model with best F1 Score of {best_val_score:.4f} saved at epoch {epoch + 1}")

#             elif task_type == "regression":
#                 # Unpack regression metrics
#                 avg_val_mse, avg_val_mae, avg_val_r2 = val_metrics.values()
#                 print(f"\nValidation: \tFold {fold} - Loss: {avg_val_loss:.4f}, MSE: {avg_val_mse:.4f}, "
#                       f"MAE: {avg_val_mae:.4f}, R2 Score: {avg_val_r2:.4f}")

#                 # Save model with best R2 score
#                 if avg_val_r2 > best_val_score:
#                     best_val_score = avg_val_r2
#                     val_metrics_dict = {**{"Loss": avg_val_loss}, **val_metrics}
#                     val_metrics_df.append(val_metrics_dict)
#                     torch.save(model.state_dict(), f'{weights_dir}/model_best_r2score_{task_type}_{signature}.pth')
#                     print(f"Model with best R2 Score of {best_val_score:.4f} saved at epoch {epoch + 1}")

#         else:
#             # Training loop
#             avg_train_loss, train_metrics = train(train_loader, model, loss_fn, optimizer, cumulative_metrics, task_type=task_type)

#             if task_type == "binary":
#                 # Unpack classification metrics
#                 avg_train_accuracy, avg_train_precision, avg_train_recall, avg_train_f1, avg_train_auc = train_metrics.values()
#                 print(f"Training: \tFold {fold} - Loss: {avg_train_loss:.4f}, Accuracy: {avg_train_accuracy:.4f}, "
#                       f"Precision: {avg_train_precision:.4f}, Recall: {avg_train_recall:.4f}, F1 Score: {avg_train_f1:.4f}, AUC Score: {avg_train_auc:.4f}")
#                 train_metrics_dict = {**{"Loss": avg_train_loss}, **train_metrics}
#                 train_metrics_df.append(train_metrics_dict)

#             elif task_type == "regression":
#                 # Unpack regression metrics
#                 avg_train_mse, avg_train_mae, avg_train_r2 = train_metrics.values()
#                 print(f"Training: \tFold {fold} - Loss: {avg_train_loss:.4f}, MSE: {avg_train_mse:.4f}, "
#                       f"MAE: {avg_train_mae:.4f}, R2: {avg_train_r2:.4f}")
#                 train_metrics_dict = {**{"Loss": avg_train_loss}, **train_metrics}
#                 train_metrics_df.append(train_metrics_dict)

#         # Reset metrics and prepare for the next fold
#         cumulative_metrics.reset()
#         fold += 1

# print(get_model_size(model))

# %% [markdown]
# We can now evaluate how our model performed on our regression task (hemoglobin estimation)

# %%
# %%time

# model.load_state_dict(torch.load(f"{weights_dir}/model_best_r2score_regression_11062024.pth"))
# test_loss, test_performance_metrics = eval(test_loader, model, loss_fn, 'Testing', CumulativeMetrics(model_type="regression", device=device))
# test_mse, test_mae, test_r2 = test_performance_metrics.values()
# print(f"Testing: \tLoss: {test_loss:.4f}, MSE: {test_mse:.4f}, MAE: {test_mae:.4f}, R2 Score: {test_r2:.4f}")

# %%
# %%time

# Training parameters
task_type = "binary"  # Choose from "binary", "multiclass", "regression"
BATCH_SIZE = 32
EPOCHS = 150
FOLDS = 5

# Assuming CumulativeMetrics is implemented elsewhere and is compatible with task_type
cumulative_metrics = CumulativeMetrics(model_type=task_type, device=device)  # Instantiate metrics tracker

# 5-fold cross-validation setup
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)

# Initialize model, loss function, and optimizer
model = load_mobilenet()  # Your MobileNetV2 instance
loss_fn = torch.nn.BCEWithLogitsLoss() if task_type == "binary" else torch.nn.MSELoss()  # Select appropriate loss
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# Directory to save the model with the best performance metrics
os.makedirs(weights_dir, exist_ok=True)

best_val_score = -float('inf') if task_type == "binary" else -float('inf')
train_metrics_df = []
val_metrics_df = []

for epoch in range(EPOCHS):
    print(f"\nEpoch {epoch+1}/{EPOCHS}")
    fold = 1
    fold_best_train_f1score = float('inf') if task_type == "binary" else -float('inf')

    for train_idx, val_idx in kf.split(train_dataset):
        train_subset = Subset(image_dataset, train_idx)
        val_subset = Subset(image_dataset, val_idx)

        train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False)

        if fold == FOLDS:
            # Validation loop
            avg_val_loss, val_metrics = eval(val_loader, model, loss_fn, mode="Validation",
                                             cumulative_metrics=cumulative_metrics, task_type=task_type)

            if task_type == "binary":
                # Unpack classification metrics
                avg_val_accuracy, avg_val_precision, avg_val_recall, avg_val_f1, avg_val_auc = val_metrics.values()
                print(f"\nValidation: \tFold {fold} - Loss: {avg_val_loss:.4f}, Accuracy: {avg_val_accuracy:.4f}, "
                      f"Precision: {avg_val_precision:.4f}, Recall: {avg_val_recall:.4f}, F1 Score: {avg_val_f1:.4f}, AUC Score: {avg_val_auc:.4f}")

                # Save model with the best validation F1 score
                if avg_val_f1 > best_val_score:
                    best_val_score = avg_val_f1
                    val_metrics_dict = {**{"Loss": avg_val_loss}, **val_metrics}
                    val_metrics_df.append(val_metrics_dict)
                    torch.save(model.state_dict(), f'{weights_dir}/model_best_f1score_{task_type}_{signature}.pth')
                    print(f"Model with best F1 Score of {best_val_score:.4f} saved at epoch {epoch + 1}")

            elif task_type == "regression":
                # Unpack regression metrics
                avg_val_mse, avg_val_mae, avg_val_r2 = val_metrics.values()
                print(f"\nValidation: \tFold {fold} - Loss: {avg_val_loss:.4f}, MSE: {avg_val_mse:.4f}, "
                      f"MAE: {avg_val_mae:.4f}, R2 Score: {avg_val_r2:.4f}")

                # Save model with best R2 score
                if avg_val_r2 > best_val_score:
                    best_val_score = avg_val_r2
                    val_metrics_dict = {**{"Loss": avg_val_loss}, **val_metrics}
                    val_metrics_df.append(val_metrics_dict)
                    torch.save(model.state_dict(), f'{weights_dir}/model_best_r2score_{task_type}_{signature}.pth')
                    print(f"Model with best R2 Score of {best_val_score:.4f} saved at epoch {epoch + 1}")

        else:
            # Training loop
            avg_train_loss, train_metrics = train(train_loader, model, loss_fn, optimizer, cumulative_metrics, task_type=task_type)

            if task_type == "binary":
                # Unpack classification metrics
                avg_train_accuracy, avg_train_precision, avg_train_recall, avg_train_f1, avg_train_auc = train_metrics.values()
                print(f"Training: \tFold {fold} - Loss: {avg_train_loss:.4f}, Accuracy: {avg_train_accuracy:.4f}, "
                      f"Precision: {avg_train_precision:.4f}, Recall: {avg_train_recall:.4f}, F1 Score: {avg_train_f1:.4f}, AUC Score: {avg_train_auc:.4f}")
                train_metrics_dict = {**{"Loss": avg_train_loss}, **train_metrics}
                train_metrics_df.append(train_metrics_dict)

            elif task_type == "regression":
                # Unpack regression metrics
                avg_train_mse, avg_train_mae, avg_train_r2 = train_metrics.values()
                print(f"Training: \tFold {fold} - Loss: {avg_train_loss:.4f}, MSE: {avg_train_mse:.4f}, "
                      f"MAE: {avg_train_mae:.4f}, R2: {avg_train_r2:.4f}")
                train_metrics_dict = {**{"Loss": avg_train_loss}, **train_metrics}
                train_metrics_df.append(train_metrics_dict)

        # Reset metrics and prepare for the next fold
        cumulative_metrics.reset()
        fold += 1

print(get_model_size(model))
# Out:
# Epoch 1/150
# Training: 	Fold 1 - Loss: 0.6911, Accuracy: 0.5174, Precision: 0.5693, Recall: 0.6185, F1 Score: 0.5759, AUC Score: 0.5223
# Training: 	Fold 2 - Loss: 0.6404, Accuracy: 0.6590, Precision: 0.6809, Recall: 0.8426, F1 Score: 0.7507, AUC Score: 0.6353
# Training: 	Fold 3 - Loss: 0.6208, Accuracy: 0.6618, Precision: 0.6901, Recall: 0.8290, F1 Score: 0.7454, AUC Score: 0.6711
# Training: 	Fold 4 - Loss: 0.5842, Accuracy: 0.7134, Precision: 0.7027, Recall: 0.8922, F1 Score: 0.7823, AUC Score: 0.7290
#
# Validation: 	Fold 5 - Loss: 0.5351, Accuracy: 0.6990, Precision: 0.7182, Recall: 0.8346, F1 Score: 0.7583, AUC Score: 0.8054
# Model with best F1 Score of 0.7583 saved at epoch 1
#
# Epoch 2/150
# Training: 	Fold 1 - Loss: 0.5748, Accuracy: 0.7083, Precision: 0.7082, Recall: 0.8460, F1 Score: 0.7682, AUC Score: 0.7450
# Training: 	Fold 2 - Loss: 0.5377, Accuracy: 0.7215, Precision: 0.7656, Recall: 0.7889, F1 Score: 0.7719, AUC Score: 0.8004
# Training: 	Fold 3 - Loss: 0.5419, Accuracy: 0.7257, Precision: 0.7459, Recall: 0.8154, F1 Score: 0.7762, AUC Score: 0.7817
# Training: 	Fold 4 - Loss: 0.5581, Accuracy: 0.7143, Precision: 0.7238, Recall: 0.8513, F1 Score: 0.7764, AUC Score: 0.7834
#
# Validation: 	Fold 5 - Loss: 0.4786, Accuracy: 0.7293, Precision: 0.6950, Recall: 0.9057, F1 Score: 0.7844, AUC Score: 0.8692
# Model with best F1 Score of 0.7844 saved at epoch 2
#
# Epoch 3/150
# Training: 	Fold 1 - Loss: 0.4774, Accuracy: 0.7590, Precision: 0.7506, Recall: 0.8633, F1 Score: 0.7977, AUC Score: 0.8496
# Training: 	Fold 2 - Loss: 0.5018, Accuracy: 0.7667, Precision: 0.8066, Recall: 0.8159, F1 Score: 0.7892, AUC Score: 0.8412
# Training: 	Fold 3 - Loss: 0.5109, Accuracy: 0.7778, Precision: 0.7935, Recall: 0.8406, F1 Score: 0.8032, AUC Score: 0.8322
# Training: 	Fold 4 - Loss: 0.4318, Accuracy: 0.8083, Precision: 0.8178, Recall: 0.8758, F1 Score: 0.8415, AUC Score: 0.8707
#
# Validation: 	Fold 5 - Loss: 0.3645, Accuracy: 0.8438, Precision: 0.8514, Recall: 0.8577, F1 Score: 0.8532, AUC Score: 0.9147
# Model with best F1 Score of 0.8532 saved at epoch 3
#
# Epoch 4/150
# Training: 	Fold 1 - Loss: 0.4455, Accuracy: 0.7958, Precision: 0.7935, Recall: 0.8659, F1 Score: 0.8125, AUC Score: 0.8866
# Training: 	Fold 2 - Loss: 0.4634, Accuracy: 0.7931, Precision: 0.8241, Recall: 0.8203, F1 Score: 0.8117, AUC Score: 0.8732
# Training: 	Fold 3 - Loss: 0.4018, Accuracy: 0.8139, Precision: 0.8301, Recall: 0.8756, F1 Score: 0.8493, AUC Score: 0.8992
# Training: 	Fold 4 - Loss: 0.3903, Accuracy: 0.8089, Precision: 0.8385, Recall: 0.8522, F1 Score: 0.8415, AUC Score: 0.9041
#
# Validation: 	Fold 5 - Loss: 0.3024, Accuracy: 0.8672, Precision: 0.9286, Recall: 0.8186, F1 Score: 0.8645, AUC Score: 0.9478
# Model with best F1 Score of 0.8645 saved at epoch 4
#
# Epoch 5/150
# Training: 	Fold 1 - Loss: 0.3613, Accuracy: 0.8458, Precision: 0.8482, Recall: 0.8904, F1 Score: 0.8644, AUC Score: 0.9130
# Training: 	Fold 2 - Loss: 0.3906, Accuracy: 0.8021, Precision: 0.8222, Recall: 0.8601, F1 Score: 0.8237, AUC Score: 0.9131
# Training: 	Fold 3 - Loss: 0.3509, Accuracy: 0.8389, Precision: 0.8552, Recall: 0.8910, F1 Score: 0.8685, AUC Score: 0.9223
# Training: 	Fold 4 - Loss: 0.3511, Accuracy: 0.8259, Precision: 0.8498, Recall: 0.8627, F1 Score: 0.8523, AUC Score: 0.9196
#
# Validation: 	Fold 5 - Loss: 0.2397, Accuracy: 0.9150, Precision: 0.9514, Recall: 0.8902, F1 Score: 0.9194, AUC Score: 0.9692
# Model with best F1 Score of 0.9194 saved at epoch 5
#
# Epoch 6/150
# Training: 	Fold 1 - Loss: 0.3243, Accuracy: 0.8597, Precision: 0.8823, Recall: 0.8887, F1 Score: 0.8750, AUC Score: 0.9351
# Training: 	Fold 2 - Loss: 0.3630, Accuracy: 0.8410, Precision: 0.8795, Recall: 0.8603, F1 Score: 0.8626, AUC Score: 0.9190
# Training: 	Fold 3 - Loss: 0.3071, Accuracy: 0.8729, Precision: 0.8960, Recall: 0.8969, F1 Score: 0.8941, AUC Score: 0.9364
# Training: 	Fold 4 - Loss: 0.3079, Accuracy: 0.8747, Precision: 0.8734, Recall: 0.9395, F1 Score: 0.9025, AUC Score: 0.9477
#
# Validation: 	Fold 5 - Loss: 0.2335, Accuracy: 0.9062, Precision: 0.9219, Recall: 0.9050, F1 Score: 0.9111, AUC Score: 0.9631
#
# Epoch 7/150
# Training: 	Fold 1 - Loss: 0.3073, Accuracy: 0.8632, Precision: 0.8704, Recall: 0.8862, F1 Score: 0.8764, AUC Score: 0.9453
# Training: 	Fold 2 - Loss: 0.3102, Accuracy: 0.8708, Precision: 0.8841, Recall: 0.9053, F1 Score: 0.8909, AUC Score: 0.9358
# Training: 	Fold 3 - Loss: 0.3078, Accuracy: 0.8715, Precision: 0.9071, Recall: 0.8870, F1 Score: 0.8952, AUC Score: 0.9556
# Training: 	Fold 4 - Loss: 0.3279, Accuracy: 0.8411, Precision: 0.8650, Recall: 0.8771, F1 Score: 0.8640, AUC Score: 0.9411
#
# Validation: 	Fold 5 - Loss: 0.2269, Accuracy: 0.9072, Precision: 0.9054, Recall: 0.9303, F1 Score: 0.9170, AUC Score: 0.9651
#
# Epoch 8/150
# Training: 	Fold 1 - Loss: 0.3533, Accuracy: 0.8347, Precision: 0.8222, Recall: 0.8459, F1 Score: 0.8289, AUC Score: 0.9441
# Training: 	Fold 2 - Loss: 0.2698, Accuracy: 0.8764, Precision: 0.9142, Recall: 0.8873, F1 Score: 0.8946, AUC Score: 0.9604
# Training: 	Fold 3 - Loss: 0.2611, Accuracy: 0.8958, Precision: 0.9291, Recall: 0.9063, F1 Score: 0.9145, AUC Score: 0.9587
# Training: 	Fold 4 - Loss: 0.2453, Accuracy: 0.9051, Precision: 0.9054, Recall: 0.9406, F1 Score: 0.9188, AUC Score: 0.9702
#
# Validation: 	Fold 5 - Loss: 0.1274, Accuracy: 0.9531, Precision: 0.9661, Recall: 0.9416, F1 Score: 0.9535, AUC Score: 0.9897
# Model with best F1 Score of 0.9535 saved at epoch 8
#
# Epoch 9/150
# Training: 	Fold 1 - Loss: 0.2038, Accuracy: 0.9069, Precision: 0.9367, Recall: 0.9153, F1 Score: 0.9206, AUC Score: 0.9785
# Training: 	Fold 2 - Loss: 0.1899, Accuracy: 0.9292, Precision: 0.9331, Recall: 0.9530, F1 Score: 0.9417, AUC Score: 0.9785
# Training: 	Fold 3 - Loss: 0.2068, Accuracy: 0.9021, Precision: 0.9415, Recall: 0.9003, F1 Score: 0.9191, AUC Score: 0.9726
# Training: 	Fold 4 - Loss: 0.2592, Accuracy: 0.8926, Precision: 0.9100, Recall: 0.9229, F1 Score: 0.9126, AUC Score: 0.9618
#
# Validation: 	Fold 5 - Loss: 0.0868, Accuracy: 0.9766, Precision: 0.9752, Recall: 0.9861, F1 Score: 0.9806, AUC Score: 0.9968
# Model with best F1 Score of 0.9806 saved at epoch 9
#
# Epoch 10/150
# Training: 	Fold 1 - Loss: 0.2189, Accuracy: 0.9104, Precision: 0.9152, Recall: 0.9372, F1 Score: 0.9228, AUC Score: 0.9687
# Training: 	Fold 2 - Loss: 0.2341, Accuracy: 0.9139, Precision: 0.9152, Recall: 0.9458, F1 Score: 0.9269, AUC Score: 0.9690
# Training: 	Fold 3 - Loss: 0.2370, Accuracy: 0.9042, Precision: 0.9383, Recall: 0.9070, F1 Score: 0.9205, AUC Score: 0.9627
# Training: 	Fold 4 - Loss: 0.1854, Accuracy: 0.9125, Precision: 0.9008, Recall: 0.9611, F1 Score: 0.9259, AUC Score: 0.9789
#
# Validation: 	Fold 5 - Loss: 0.1003, Accuracy: 0.9531, Precision: 0.9749, Recall: 0.9388, F1 Score: 0.9550, AUC Score: 0.9942
#
# Epoch 11/150
# Training: 	Fold 1 - Loss: 0.1408, Accuracy: 0.9500, Precision: 0.9506, Recall: 0.9649, F1 Score: 0.9568, AUC Score: 0.9886
# Training: 	Fold 2 - Loss: 0.2618, Accuracy: 0.9097, Precision: 0.9453, Recall: 0.9075, F1 Score: 0.9225, AUC Score: 0.9727
# Training: 	Fold 3 - Loss: 0.1853, Accuracy: 0.9181, Precision: 0.9413, Recall: 0.9286, F1 Score: 0.9319, AUC Score: 0.9800
# Training: 	Fold 4 - Loss: 0.1667, Accuracy: 0.9310, Precision: 0.9177, Recall: 0.9662, F1 Score: 0.9357, AUC Score: 0.9867
#
# Validation: 	Fold 5 - Loss: 0.0874, Accuracy: 0.9766, Precision: 0.9558, Recall: 1.0000, F1 Score: 0.9766, AUC Score: 0.9981
#
# Epoch 12/150
# Training: 	Fold 1 - Loss: 0.2502, Accuracy: 0.9090, Precision: 0.9080, Recall: 0.9310, F1 Score: 0.9061, AUC Score: 0.9748
# Training: 	Fold 2 - Loss: 0.2272, Accuracy: 0.8854, Precision: 0.9429, Recall: 0.8888, F1 Score: 0.9083, AUC Score: 0.9737
# Training: 	Fold 3 - Loss: 0.2394, Accuracy: 0.9097, Precision: 0.9121, Recall: 0.9449, F1 Score: 0.9233, AUC Score: 0.9637
# Training: 	Fold 4 - Loss: 0.1271, Accuracy: 0.9625, Precision: 0.9842, Recall: 0.9538, F1 Score: 0.9674, AUC Score: 0.9913
#
# Validation: 	Fold 5 - Loss: 0.0620, Accuracy: 0.9844, Precision: 0.9891, Recall: 0.9861, F1 Score: 0.9873, AUC Score: 0.9994
# Model with best F1 Score of 0.9873 saved at epoch 12
#
# Epoch 13/150
# Training: 	Fold 1 - Loss: 0.1593, Accuracy: 0.9437, Precision: 0.9388, Recall: 0.9651, F1 Score: 0.9502, AUC Score: 0.9828
# Training: 	Fold 2 - Loss: 0.1340, Accuracy: 0.9431, Precision: 0.9526, Recall: 0.9491, F1 Score: 0.9477, AUC Score: 0.9914
# Training: 	Fold 3 - Loss: 0.1492, Accuracy: 0.9174, Precision: 0.9318, Recall: 0.9267, F1 Score: 0.9265, AUC Score: 0.9890
# Training: 	Fold 4 - Loss: 0.1933, Accuracy: 0.9155, Precision: 0.9271, Recall: 0.9377, F1 Score: 0.9293, AUC Score: 0.9795
#
# Validation: 	Fold 5 - Loss: 0.0375, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
# Model with best F1 Score of 1.0000 saved at epoch 13
#
# Epoch 14/150
# Training: 	Fold 1 - Loss: 0.1175, Accuracy: 0.9583, Precision: 0.9611, Recall: 0.9703, F1 Score: 0.9653, AUC Score: 0.9919
# Training: 	Fold 2 - Loss: 0.1514, Accuracy: 0.9417, Precision: 0.9493, Recall: 0.9537, F1 Score: 0.9461, AUC Score: 0.9848
# Training: 	Fold 3 - Loss: 0.2111, Accuracy: 0.9444, Precision: 0.9681, Recall: 0.9554, F1 Score: 0.9587, AUC Score: 0.9877
# Training: 	Fold 4 - Loss: 0.1623, Accuracy: 0.9446, Precision: 0.9540, Recall: 0.9569, F1 Score: 0.9537, AUC Score: 0.9861
#
# Validation: 	Fold 5 - Loss: 0.0761, Accuracy: 0.9766, Precision: 0.9581, Recall: 1.0000, F1 Score: 0.9784, AUC Score: 0.9990
#
# Epoch 15/150
# Training: 	Fold 1 - Loss: 0.2059, Accuracy: 0.9083, Precision: 0.8966, Recall: 0.9600, F1 Score: 0.9255, AUC Score: 0.9855
# Training: 	Fold 2 - Loss: 0.1414, Accuracy: 0.9458, Precision: 0.9701, Recall: 0.9397, F1 Score: 0.9533, AUC Score: 0.9882
# Training: 	Fold 3 - Loss: 0.1279, Accuracy: 0.9583, Precision: 0.9747, Recall: 0.9582, F1 Score: 0.9652, AUC Score: 0.9914
# Training: 	Fold 4 - Loss: 0.1277, Accuracy: 0.9458, Precision: 0.9540, Recall: 0.9579, F1 Score: 0.9531, AUC Score: 0.9895
#
# Validation: 	Fold 5 - Loss: 0.0292, Accuracy: 0.9922, Precision: 0.9821, Recall: 1.0000, F1 Score: 0.9907, AUC Score: 1.0000
#
# Epoch 16/150
# Training: 	Fold 1 - Loss: 0.1534, Accuracy: 0.9424, Precision: 0.9200, Recall: 0.9783, F1 Score: 0.9373, AUC Score: 0.9900
# Training: 	Fold 2 - Loss: 0.1673, Accuracy: 0.9347, Precision: 0.9598, Recall: 0.9386, F1 Score: 0.9469, AUC Score: 0.9857
# Training: 	Fold 3 - Loss: 0.1796, Accuracy: 0.9271, Precision: 0.9319, Recall: 0.9487, F1 Score: 0.9374, AUC Score: 0.9776
# Training: 	Fold 4 - Loss: 0.1281, Accuracy: 0.9405, Precision: 0.9508, Recall: 0.9553, F1 Score: 0.9507, AUC Score: 0.9902
#
# Validation: 	Fold 5 - Loss: 0.0450, Accuracy: 0.9922, Precision: 0.9868, Recall: 1.0000, F1 Score: 0.9932, AUC Score: 0.9990
#
# Epoch 17/150
# Training: 	Fold 1 - Loss: 0.2045, Accuracy: 0.9340, Precision: 0.9446, Recall: 0.9303, F1 Score: 0.9365, AUC Score: 0.9875
# Training: 	Fold 2 - Loss: 0.1056, Accuracy: 0.9625, Precision: 0.9656, Recall: 0.9737, F1 Score: 0.9690, AUC Score: 0.9930
# Training: 	Fold 3 - Loss: 0.1430, Accuracy: 0.9410, Precision: 0.9490, Recall: 0.9590, F1 Score: 0.9519, AUC Score: 0.9892
# Training: 	Fold 4 - Loss: 0.1139, Accuracy: 0.9667, Precision: 0.9642, Recall: 0.9786, F1 Score: 0.9707, AUC Score: 0.9917
#
# Validation: 	Fold 5 - Loss: 0.0529, Accuracy: 0.9844, Precision: 0.9760, Recall: 1.0000, F1 Score: 0.9877, AUC Score: 0.9978
#
# Epoch 18/150
# Training: 	Fold 1 - Loss: 0.1719, Accuracy: 0.9194, Precision: 0.9167, Recall: 0.9584, F1 Score: 0.9298, AUC Score: 0.9887
# Training: 	Fold 2 - Loss: 0.1620, Accuracy: 0.9354, Precision: 0.9620, Recall: 0.9365, F1 Score: 0.9473, AUC Score: 0.9825
# Training: 	Fold 3 - Loss: 0.1298, Accuracy: 0.9410, Precision: 0.9415, Recall: 0.9695, F1 Score: 0.9528, AUC Score: 0.9913
# Training: 	Fold 4 - Loss: 0.1838, Accuracy: 0.9277, Precision: 0.9309, Recall: 0.9544, F1 Score: 0.9327, AUC Score: 0.9884
#
# Validation: 	Fold 5 - Loss: 0.0428, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 19/150
# Training: 	Fold 1 - Loss: 0.1706, Accuracy: 0.9458, Precision: 0.9452, Recall: 0.9575, F1 Score: 0.9469, AUC Score: 0.9803
# Training: 	Fold 2 - Loss: 0.1592, Accuracy: 0.9285, Precision: 0.9526, Recall: 0.9365, F1 Score: 0.9414, AUC Score: 0.9863
# Training: 	Fold 3 - Loss: 0.1169, Accuracy: 0.9604, Precision: 0.9724, Recall: 0.9654, F1 Score: 0.9677, AUC Score: 0.9910
# Training: 	Fold 4 - Loss: 0.1023, Accuracy: 0.9592, Precision: 0.9664, Recall: 0.9703, F1 Score: 0.9670, AUC Score: 0.9947
#
# Validation: 	Fold 5 - Loss: 0.0391, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 20/150
# Training: 	Fold 1 - Loss: 0.0954, Accuracy: 0.9681, Precision: 0.9705, Recall: 0.9793, F1 Score: 0.9734, AUC Score: 0.9975
# Training: 	Fold 2 - Loss: 0.1434, Accuracy: 0.9410, Precision: 0.9686, Recall: 0.9448, F1 Score: 0.9543, AUC Score: 0.9917
# Training: 	Fold 3 - Loss: 0.1372, Accuracy: 0.9431, Precision: 0.9513, Recall: 0.9630, F1 Score: 0.9551, AUC Score: 0.9897
# Training: 	Fold 4 - Loss: 0.1626, Accuracy: 0.9321, Precision: 0.9314, Recall: 0.9598, F1 Score: 0.9427, AUC Score: 0.9830
#
# Validation: 	Fold 5 - Loss: 0.0583, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9981
#
# Epoch 21/150
# Training: 	Fold 1 - Loss: 0.1002, Accuracy: 0.9667, Precision: 0.9629, Recall: 0.9798, F1 Score: 0.9701, AUC Score: 0.9942
# Training: 	Fold 2 - Loss: 0.1222, Accuracy: 0.9514, Precision: 0.9515, Recall: 0.9684, F1 Score: 0.9574, AUC Score: 0.9918
# Training: 	Fold 3 - Loss: 0.1440, Accuracy: 0.9507, Precision: 0.9652, Recall: 0.9658, F1 Score: 0.9647, AUC Score: 0.9919
# Training: 	Fold 4 - Loss: 0.1847, Accuracy: 0.9256, Precision: 0.9365, Recall: 0.9529, F1 Score: 0.9382, AUC Score: 0.9827
#
# Validation: 	Fold 5 - Loss: 0.0612, Accuracy: 0.9844, Precision: 0.9891, Recall: 0.9808, F1 Score: 0.9844, AUC Score: 0.9990
#
# Epoch 22/150
# Training: 	Fold 1 - Loss: 0.1559, Accuracy: 0.9514, Precision: 0.9422, Recall: 0.9722, F1 Score: 0.9543, AUC Score: 0.9889
# Training: 	Fold 2 - Loss: 0.1460, Accuracy: 0.9437, Precision: 0.9696, Recall: 0.9379, F1 Score: 0.9526, AUC Score: 0.9878
# Training: 	Fold 3 - Loss: 0.1049, Accuracy: 0.9597, Precision: 0.9658, Recall: 0.9747, F1 Score: 0.9685, AUC Score: 0.9957
# Training: 	Fold 4 - Loss: 0.0745, Accuracy: 0.9812, Precision: 0.9841, Recall: 0.9836, F1 Score: 0.9835, AUC Score: 0.9976
#
# Validation: 	Fold 5 - Loss: 0.0492, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9978
#
# Epoch 23/150
# Training: 	Fold 1 - Loss: 0.1192, Accuracy: 0.9576, Precision: 0.9544, Recall: 0.9757, F1 Score: 0.9631, AUC Score: 0.9932
# Training: 	Fold 2 - Loss: 0.0901, Accuracy: 0.9688, Precision: 0.9760, Recall: 0.9743, F1 Score: 0.9739, AUC Score: 0.9938
# Training: 	Fold 3 - Loss: 0.0616, Accuracy: 0.9812, Precision: 0.9923, Recall: 0.9781, F1 Score: 0.9849, AUC Score: 0.9977
# Training: 	Fold 4 - Loss: 0.0622, Accuracy: 0.9771, Precision: 0.9797, Recall: 0.9840, F1 Score: 0.9815, AUC Score: 0.9980
#
# Validation: 	Fold 5 - Loss: 0.0208, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 1.0000
#
# Epoch 24/150
# Training: 	Fold 1 - Loss: 0.1416, Accuracy: 0.9569, Precision: 0.9505, Recall: 0.9811, F1 Score: 0.9595, AUC Score: 0.9959
# Training: 	Fold 2 - Loss: 0.1223, Accuracy: 0.9563, Precision: 0.9786, Recall: 0.9483, F1 Score: 0.9625, AUC Score: 0.9908
# Training: 	Fold 3 - Loss: 0.1327, Accuracy: 0.9563, Precision: 0.9741, Recall: 0.9595, F1 Score: 0.9651, AUC Score: 0.9883
# Training: 	Fold 4 - Loss: 0.1127, Accuracy: 0.9479, Precision: 0.9449, Recall: 0.9658, F1 Score: 0.9539, AUC Score: 0.9922
#
# Validation: 	Fold 5 - Loss: 0.0310, Accuracy: 0.9844, Precision: 0.9891, Recall: 0.9861, F1 Score: 0.9873, AUC Score: 0.9997
#
# Epoch 25/150
# Training: 	Fold 1 - Loss: 0.0797, Accuracy: 0.9660, Precision: 0.9571, Recall: 0.9864, F1 Score: 0.9700, AUC Score: 0.9983
# Training: 	Fold 2 - Loss: 0.2217, Accuracy: 0.9264, Precision: 0.9219, Recall: 0.8967, F1 Score: 0.9084, AUC Score: 0.9901
# Training: 	Fold 3 - Loss: 0.1110, Accuracy: 0.9583, Precision: 0.9744, Recall: 0.9573, F1 Score: 0.9642, AUC Score: 0.9920
# Training: 	Fold 4 - Loss: 0.0897, Accuracy: 0.9643, Precision: 0.9598, Recall: 0.9810, F1 Score: 0.9644, AUC Score: 0.9976
#
# Validation: 	Fold 5 - Loss: 0.0533, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9974
#
# Epoch 26/150
# Training: 	Fold 1 - Loss: 0.0782, Accuracy: 0.9771, Precision: 0.9800, Recall: 0.9808, F1 Score: 0.9795, AUC Score: 0.9953
# Training: 	Fold 2 - Loss: 0.0925, Accuracy: 0.9625, Precision: 0.9822, Recall: 0.9595, F1 Score: 0.9697, AUC Score: 0.9942
# Training: 	Fold 3 - Loss: 0.1029, Accuracy: 0.9722, Precision: 0.9864, Recall: 0.9695, F1 Score: 0.9765, AUC Score: 0.9968
# Training: 	Fold 4 - Loss: 0.1587, Accuracy: 0.9455, Precision: 0.9583, Recall: 0.9590, F1 Score: 0.9576, AUC Score: 0.9917
#
# Validation: 	Fold 5 - Loss: 0.0364, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 0.9994
#
# Epoch 27/150
# Training: 	Fold 1 - Loss: 0.1644, Accuracy: 0.9326, Precision: 0.9381, Recall: 0.9368, F1 Score: 0.9340, AUC Score: 0.9873
# Training: 	Fold 2 - Loss: 0.1401, Accuracy: 0.9431, Precision: 0.9627, Recall: 0.9396, F1 Score: 0.9477, AUC Score: 0.9915
# Training: 	Fold 3 - Loss: 0.1107, Accuracy: 0.9465, Precision: 0.9851, Recall: 0.9387, F1 Score: 0.9576, AUC Score: 0.9935
# Training: 	Fold 4 - Loss: 0.1194, Accuracy: 0.9527, Precision: 0.9453, Recall: 0.9800, F1 Score: 0.9615, AUC Score: 0.9974
#
# Validation: 	Fold 5 - Loss: 0.0453, Accuracy: 0.9766, Precision: 0.9755, Recall: 0.9886, F1 Score: 0.9819, AUC Score: 0.9987
#
# Epoch 28/150
# Training: 	Fold 1 - Loss: 0.1621, Accuracy: 0.9174, Precision: 0.9083, Recall: 0.9455, F1 Score: 0.9247, AUC Score: 0.9903
# Training: 	Fold 2 - Loss: 0.1399, Accuracy: 0.9451, Precision: 0.9741, Recall: 0.9368, F1 Score: 0.9526, AUC Score: 0.9884
# Training: 	Fold 3 - Loss: 0.1468, Accuracy: 0.9403, Precision: 0.9710, Recall: 0.9420, F1 Score: 0.9523, AUC Score: 0.9891
# Training: 	Fold 4 - Loss: 0.0838, Accuracy: 0.9655, Precision: 0.9546, Recall: 0.9897, F1 Score: 0.9699, AUC Score: 0.9973
#
# Validation: 	Fold 5 - Loss: 0.0432, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9987
#
# Epoch 29/150
# Training: 	Fold 1 - Loss: 0.0875, Accuracy: 0.9729, Precision: 0.9663, Recall: 0.9876, F1 Score: 0.9763, AUC Score: 0.9947
# Training: 	Fold 2 - Loss: 0.1432, Accuracy: 0.9382, Precision: 0.9526, Recall: 0.9590, F1 Score: 0.9511, AUC Score: 0.9887
# Training: 	Fold 3 - Loss: 0.0781, Accuracy: 0.9812, Precision: 0.9862, Recall: 0.9872, F1 Score: 0.9861, AUC Score: 0.9955
# Training: 	Fold 4 - Loss: 0.1168, Accuracy: 0.9443, Precision: 0.9770, Recall: 0.9497, F1 Score: 0.9586, AUC Score: 0.9972
#
# Validation: 	Fold 5 - Loss: 0.0273, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9997
#
# Epoch 30/150
# Training: 	Fold 1 - Loss: 0.1544, Accuracy: 0.9319, Precision: 0.9098, Recall: 0.9796, F1 Score: 0.9363, AUC Score: 0.9925
# Training: 	Fold 2 - Loss: 0.1345, Accuracy: 0.9451, Precision: 0.9545, Recall: 0.9568, F1 Score: 0.9520, AUC Score: 0.9910
# Training: 	Fold 3 - Loss: 0.1500, Accuracy: 0.9444, Precision: 0.9773, Recall: 0.9411, F1 Score: 0.9544, AUC Score: 0.9914
# Training: 	Fold 4 - Loss: 0.1439, Accuracy: 0.9485, Precision: 0.9496, Recall: 0.9743, F1 Score: 0.9527, AUC Score: 0.9938
#
# Validation: 	Fold 5 - Loss: 0.0503, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Epoch 31/150
# Training: 	Fold 1 - Loss: 0.1310, Accuracy: 0.9542, Precision: 0.9539, Recall: 0.9682, F1 Score: 0.9594, AUC Score: 0.9888
# Training: 	Fold 2 - Loss: 0.1403, Accuracy: 0.9521, Precision: 0.9378, Recall: 0.9886, F1 Score: 0.9479, AUC Score: 0.9962
# Training: 	Fold 3 - Loss: 0.1170, Accuracy: 0.9604, Precision: 0.9689, Recall: 0.9700, F1 Score: 0.9683, AUC Score: 0.9893
# Training: 	Fold 4 - Loss: 0.0797, Accuracy: 0.9613, Precision: 0.9850, Recall: 0.9514, F1 Score: 0.9665, AUC Score: 0.9974
#
# Validation: 	Fold 5 - Loss: 0.0187, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 32/150
# Training: 	Fold 1 - Loss: 0.0655, Accuracy: 0.9701, Precision: 0.9720, Recall: 0.9807, F1 Score: 0.9748, AUC Score: 0.9981
# Training: 	Fold 2 - Loss: 0.0604, Accuracy: 0.9750, Precision: 0.9850, Recall: 0.9738, F1 Score: 0.9786, AUC Score: 0.9977
# Training: 	Fold 3 - Loss: 0.0697, Accuracy: 0.9639, Precision: 0.9866, Recall: 0.9603, F1 Score: 0.9721, AUC Score: 0.9981
# Training: 	Fold 4 - Loss: 0.0714, Accuracy: 0.9738, Precision: 0.9767, Recall: 0.9794, F1 Score: 0.9765, AUC Score: 0.9987
#
# Validation: 	Fold 5 - Loss: 0.0333, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9984
#
# Epoch 33/150
# Training: 	Fold 1 - Loss: 0.0904, Accuracy: 0.9701, Precision: 0.9521, Recall: 1.0000, F1 Score: 0.9734, AUC Score: 0.9962
# Training: 	Fold 2 - Loss: 0.0619, Accuracy: 0.9812, Precision: 0.9932, Recall: 0.9807, F1 Score: 0.9863, AUC Score: 0.9980
# Training: 	Fold 3 - Loss: 0.0454, Accuracy: 0.9875, Precision: 0.9893, Recall: 0.9903, F1 Score: 0.9896, AUC Score: 0.9987
# Training: 	Fold 4 - Loss: 0.0447, Accuracy: 0.9854, Precision: 0.9838, Recall: 0.9907, F1 Score: 0.9869, AUC Score: 0.9991
#
# Validation: 	Fold 5 - Loss: 0.0214, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 34/150
# Training: 	Fold 1 - Loss: 0.0450, Accuracy: 0.9958, Precision: 0.9958, Recall: 0.9963, F1 Score: 0.9959, AUC Score: 0.9996
# Training: 	Fold 2 - Loss: 0.0904, Accuracy: 0.9722, Precision: 0.9559, Recall: 0.9829, F1 Score: 0.9635, AUC Score: 0.9984
# Training: 	Fold 3 - Loss: 0.0956, Accuracy: 0.9646, Precision: 0.9790, Recall: 0.9640, F1 Score: 0.9709, AUC Score: 0.9947
# Training: 	Fold 4 - Loss: 0.0913, Accuracy: 0.9601, Precision: 0.9543, Recall: 0.9787, F1 Score: 0.9605, AUC Score: 0.9962
#
# Validation: 	Fold 5 - Loss: 0.0342, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9994
#
# Epoch 35/150
# Training: 	Fold 1 - Loss: 0.1306, Accuracy: 0.9500, Precision: 0.9830, Recall: 0.9540, F1 Score: 0.9624, AUC Score: 0.9954
# Training: 	Fold 2 - Loss: 0.1044, Accuracy: 0.9646, Precision: 0.9693, Recall: 0.9755, F1 Score: 0.9705, AUC Score: 0.9918
# Training: 	Fold 3 - Loss: 0.0923, Accuracy: 0.9667, Precision: 0.9653, Recall: 0.9795, F1 Score: 0.9710, AUC Score: 0.9925
# Training: 	Fold 4 - Loss: 0.0655, Accuracy: 0.9696, Precision: 0.9707, Recall: 0.9803, F1 Score: 0.9738, AUC Score: 0.9975
#
# Validation: 	Fold 5 - Loss: 0.0346, Accuracy: 0.9766, Precision: 0.9886, Recall: 0.9694, F1 Score: 0.9786, AUC Score: 0.9990
#
# Epoch 36/150
# Training: 	Fold 1 - Loss: 0.0889, Accuracy: 0.9639, Precision: 0.9673, Recall: 0.9745, F1 Score: 0.9676, AUC Score: 0.9976
# Training: 	Fold 2 - Loss: 0.0685, Accuracy: 0.9681, Precision: 0.9844, Recall: 0.9618, F1 Score: 0.9716, AUC Score: 0.9983
# Training: 	Fold 3 - Loss: 0.1092, Accuracy: 0.9597, Precision: 0.9581, Recall: 0.9793, F1 Score: 0.9664, AUC Score: 0.9932
# Training: 	Fold 4 - Loss: 0.0611, Accuracy: 0.9812, Precision: 0.9760, Recall: 0.9940, F1 Score: 0.9844, AUC Score: 0.9981
#
# Validation: 	Fold 5 - Loss: 0.0243, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 37/150
# Training: 	Fold 1 - Loss: 0.0800, Accuracy: 0.9667, Precision: 0.9758, Recall: 0.9665, F1 Score: 0.9702, AUC Score: 0.9967
# Training: 	Fold 2 - Loss: 0.0536, Accuracy: 0.9812, Precision: 0.9890, Recall: 0.9826, F1 Score: 0.9853, AUC Score: 0.9988
# Training: 	Fold 3 - Loss: 0.1201, Accuracy: 0.9458, Precision: 0.9776, Recall: 0.9550, F1 Score: 0.9602, AUC Score: 0.9972
# Training: 	Fold 4 - Loss: 0.0727, Accuracy: 0.9696, Precision: 0.9690, Recall: 0.9830, F1 Score: 0.9749, AUC Score: 0.9982
#
# Validation: 	Fold 5 - Loss: 0.0249, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 1.0000
#
# Epoch 38/150
# Training: 	Fold 1 - Loss: 0.0853, Accuracy: 0.9743, Precision: 0.9678, Recall: 0.9910, F1 Score: 0.9778, AUC Score: 0.9981
# Training: 	Fold 2 - Loss: 0.1234, Accuracy: 0.9583, Precision: 0.9745, Recall: 0.9593, F1 Score: 0.9657, AUC Score: 0.9903
# Training: 	Fold 3 - Loss: 0.1255, Accuracy: 0.9597, Precision: 0.9810, Recall: 0.9596, F1 Score: 0.9690, AUC Score: 0.9921
# Training: 	Fold 4 - Loss: 0.0944, Accuracy: 0.9634, Precision: 0.9564, Recall: 0.9813, F1 Score: 0.9667, AUC Score: 0.9960
#
# Validation: 	Fold 5 - Loss: 0.0345, Accuracy: 0.9766, Precision: 0.9881, Recall: 0.9773, F1 Score: 0.9826, AUC Score: 0.9994
#
# Epoch 39/150
# Training: 	Fold 1 - Loss: 0.0719, Accuracy: 0.9701, Precision: 0.9806, Recall: 0.9740, F1 Score: 0.9761, AUC Score: 0.9982
# Training: 	Fold 2 - Loss: 0.0800, Accuracy: 0.9688, Precision: 0.9734, Recall: 0.9769, F1 Score: 0.9744, AUC Score: 0.9956
# Training: 	Fold 3 - Loss: 0.0457, Accuracy: 0.9875, Precision: 0.9900, Recall: 0.9920, F1 Score: 0.9906, AUC Score: 0.9982
# Training: 	Fold 4 - Loss: 0.0435, Accuracy: 0.9792, Precision: 0.9849, Recall: 0.9811, F1 Score: 0.9826, AUC Score: 0.9992
#
# Validation: 	Fold 5 - Loss: 0.0144, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Epoch 40/150
# Training: 	Fold 1 - Loss: 0.0366, Accuracy: 0.9896, Precision: 0.9926, Recall: 0.9913, F1 Score: 0.9915, AUC Score: 0.9995
# Training: 	Fold 2 - Loss: 0.0474, Accuracy: 0.9792, Precision: 0.9808, Recall: 0.9858, F1 Score: 0.9826, AUC Score: 0.9985
# Training: 	Fold 3 - Loss: 0.0518, Accuracy: 0.9826, Precision: 0.9704, Recall: 0.9971, F1 Score: 0.9814, AUC Score: 0.9993
# Training: 	Fold 4 - Loss: 0.0507, Accuracy: 0.9771, Precision: 0.9902, Recall: 0.9735, F1 Score: 0.9809, AUC Score: 0.9987
#
# Validation: 	Fold 5 - Loss: 0.0308, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9997
#
# Epoch 41/150
# Training: 	Fold 1 - Loss: 0.0466, Accuracy: 0.9833, Precision: 0.9851, Recall: 0.9852, F1 Score: 0.9845, AUC Score: 0.9990
# Training: 	Fold 2 - Loss: 0.0295, Accuracy: 0.9875, Precision: 0.9895, Recall: 0.9907, F1 Score: 0.9898, AUC Score: 0.9997
# Training: 	Fold 3 - Loss: 0.0349, Accuracy: 0.9896, Precision: 0.9924, Recall: 0.9913, F1 Score: 0.9916, AUC Score: 0.9990
# Training: 	Fold 4 - Loss: 0.0321, Accuracy: 0.9896, Precision: 0.9855, Recall: 0.9967, F1 Score: 0.9909, AUC Score: 0.9995
#
# Validation: 	Fold 5 - Loss: 0.0125, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Epoch 42/150
# Training: 	Fold 1 - Loss: 0.0347, Accuracy: 0.9833, Precision: 0.9752, Recall: 0.9929, F1 Score: 0.9825, AUC Score: 0.9996
# Training: 	Fold 2 - Loss: 0.1188, Accuracy: 0.9681, Precision: 0.9595, Recall: 0.9838, F1 Score: 0.9687, AUC Score: 0.9962
# Training: 	Fold 3 - Loss: 0.1819, Accuracy: 0.9507, Precision: 0.9890, Recall: 0.9405, F1 Score: 0.9606, AUC Score: 0.9942
# Training: 	Fold 4 - Loss: 0.1188, Accuracy: 0.9571, Precision: 0.9693, Recall: 0.9649, F1 Score: 0.9650, AUC Score: 0.9913
#
# Validation: 	Fold 5 - Loss: 0.0981, Accuracy: 0.9540, Precision: 0.9361, Recall: 0.9886, F1 Score: 0.9608, AUC Score: 0.9965
#
# Epoch 43/150
# Training: 	Fold 1 - Loss: 0.1190, Accuracy: 0.9583, Precision: 0.9451, Recall: 0.9862, F1 Score: 0.9628, AUC Score: 0.9916
# Training: 	Fold 2 - Loss: 0.0992, Accuracy: 0.9722, Precision: 0.9848, Recall: 0.9750, F1 Score: 0.9792, AUC Score: 0.9980
# Training: 	Fold 3 - Loss: 0.1074, Accuracy: 0.9806, Precision: 0.9887, Recall: 0.9838, F1 Score: 0.9853, AUC Score: 0.9969
# Training: 	Fold 4 - Loss: 0.1109, Accuracy: 0.9685, Precision: 0.9698, Recall: 0.9771, F1 Score: 0.9733, AUC Score: 0.9974
#
# Validation: 	Fold 5 - Loss: 0.0316, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9994
#
# Epoch 44/150
# Training: 	Fold 1 - Loss: 0.0726, Accuracy: 0.9681, Precision: 0.9696, Recall: 0.9803, F1 Score: 0.9733, AUC Score: 0.9985
# Training: 	Fold 2 - Loss: 0.0724, Accuracy: 0.9750, Precision: 0.9851, Recall: 0.9748, F1 Score: 0.9793, AUC Score: 0.9967
# Training: 	Fold 3 - Loss: 0.0814, Accuracy: 0.9729, Precision: 0.9719, Recall: 0.9840, F1 Score: 0.9765, AUC Score: 0.9964
# Training: 	Fold 4 - Loss: 0.1033, Accuracy: 0.9560, Precision: 0.9404, Recall: 0.9848, F1 Score: 0.9561, AUC Score: 0.9977
#
# Validation: 	Fold 5 - Loss: 0.0170, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Epoch 45/150
# Training: 	Fold 1 - Loss: 0.0660, Accuracy: 0.9708, Precision: 0.9891, Recall: 0.9638, F1 Score: 0.9757, AUC Score: 0.9975
# Training: 	Fold 2 - Loss: 0.0526, Accuracy: 0.9854, Precision: 0.9896, Recall: 0.9865, F1 Score: 0.9877, AUC Score: 0.9987
# Training: 	Fold 3 - Loss: 0.0343, Accuracy: 0.9854, Precision: 0.9839, Recall: 0.9896, F1 Score: 0.9863, AUC Score: 0.9994
# Training: 	Fold 4 - Loss: 0.0377, Accuracy: 0.9854, Precision: 0.9808, Recall: 0.9939, F1 Score: 0.9866, AUC Score: 0.9995
#
# Validation: 	Fold 5 - Loss: 0.0184, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 46/150
# Training: 	Fold 1 - Loss: 0.1370, Accuracy: 0.9563, Precision: 0.9427, Recall: 0.9903, F1 Score: 0.9512, AUC Score: 0.9986
# Training: 	Fold 2 - Loss: 0.0977, Accuracy: 0.9646, Precision: 0.9848, Recall: 0.9601, F1 Score: 0.9707, AUC Score: 0.9956
# Training: 	Fold 3 - Loss: 0.0507, Accuracy: 0.9792, Precision: 0.9927, Recall: 0.9745, F1 Score: 0.9830, AUC Score: 0.9983
# Training: 	Fold 4 - Loss: 0.0645, Accuracy: 0.9780, Precision: 0.9749, Recall: 0.9898, F1 Score: 0.9809, AUC Score: 0.9986
#
# Validation: 	Fold 5 - Loss: 0.0216, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9861, F1 Score: 0.9929, AUC Score: 1.0000
#
# Epoch 47/150
# Training: 	Fold 1 - Loss: 0.0727, Accuracy: 0.9743, Precision: 0.9779, Recall: 0.9833, F1 Score: 0.9794, AUC Score: 0.9987
# Training: 	Fold 2 - Loss: 0.0806, Accuracy: 0.9646, Precision: 0.9639, Recall: 0.9821, F1 Score: 0.9720, AUC Score: 0.9953
# Training: 	Fold 3 - Loss: 0.0786, Accuracy: 0.9722, Precision: 0.9829, Recall: 0.9780, F1 Score: 0.9794, AUC Score: 0.9980
# Training: 	Fold 4 - Loss: 0.0679, Accuracy: 0.9688, Precision: 0.9825, Recall: 0.9663, F1 Score: 0.9728, AUC Score: 0.9970
#
# Validation: 	Fold 5 - Loss: 0.0190, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 48/150
# Training: 	Fold 1 - Loss: 0.0541, Accuracy: 0.9743, Precision: 0.9793, Recall: 0.9775, F1 Score: 0.9765, AUC Score: 0.9989
# Training: 	Fold 2 - Loss: 0.1420, Accuracy: 0.9826, Precision: 0.9590, Recall: 0.9968, F1 Score: 0.9722, AUC Score: 0.9960
# Training: 	Fold 3 - Loss: 0.0563, Accuracy: 0.9743, Precision: 0.9687, Recall: 0.9903, F1 Score: 0.9779, AUC Score: 0.9988
# Training: 	Fold 4 - Loss: 0.0636, Accuracy: 0.9833, Precision: 0.9825, Recall: 0.9915, F1 Score: 0.9866, AUC Score: 0.9974
#
# Validation: 	Fold 5 - Loss: 0.0176, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 49/150
# Training: 	Fold 1 - Loss: 0.0433, Accuracy: 0.9854, Precision: 0.9794, Recall: 0.9939, F1 Score: 0.9860, AUC Score: 0.9989
# Training: 	Fold 2 - Loss: 0.0401, Accuracy: 0.9917, Precision: 0.9858, Recall: 1.0000, F1 Score: 0.9926, AUC Score: 0.9989
# Training: 	Fold 3 - Loss: 0.0285, Accuracy: 0.9896, Precision: 0.9898, Recall: 0.9943, F1 Score: 0.9918, AUC Score: 0.9997
# Training: 	Fold 4 - Loss: 0.0464, Accuracy: 0.9789, Precision: 0.9689, Recall: 1.0000, F1 Score: 0.9810, AUC Score: 0.9997
#
# Validation: 	Fold 5 - Loss: 0.0142, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 50/150
# Training: 	Fold 1 - Loss: 0.0338, Accuracy: 0.9875, Precision: 0.9873, Recall: 0.9898, F1 Score: 0.9882, AUC Score: 0.9995
# Training: 	Fold 2 - Loss: 0.0519, Accuracy: 0.9812, Precision: 0.9877, Recall: 0.9798, F1 Score: 0.9832, AUC Score: 0.9983
# Training: 	Fold 3 - Loss: 0.0458, Accuracy: 0.9792, Precision: 0.9752, Recall: 0.9878, F1 Score: 0.9800, AUC Score: 0.9977
# Training: 	Fold 4 - Loss: 0.0250, Accuracy: 0.9917, Precision: 0.9922, Recall: 0.9938, F1 Score: 0.9926, AUC Score: 0.9995
#
# Validation: 	Fold 5 - Loss: 0.0175, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 51/150
# Training: 	Fold 1 - Loss: 0.0270, Accuracy: 0.9854, Precision: 0.9927, Recall: 0.9831, F1 Score: 0.9876, AUC Score: 0.9998
# Training: 	Fold 2 - Loss: 0.0194, Accuracy: 0.9958, Precision: 0.9926, Recall: 1.0000, F1 Score: 0.9962, AUC Score: 0.9999
# Training: 	Fold 3 - Loss: 0.0237, Accuracy: 0.9938, Precision: 0.9896, Recall: 1.0000, F1 Score: 0.9947, AUC Score: 0.9997
# Training: 	Fold 4 - Loss: 0.0331, Accuracy: 0.9842, Precision: 0.9970, Recall: 0.9805, F1 Score: 0.9881, AUC Score: 0.9998
#
# Validation: 	Fold 5 - Loss: 0.0140, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 52/150
# Training: 	Fold 1 - Loss: 0.0428, Accuracy: 0.9785, Precision: 0.9846, Recall: 0.9800, F1 Score: 0.9807, AUC Score: 0.9996
# Training: 	Fold 2 - Loss: 0.0387, Accuracy: 0.9854, Precision: 0.9835, Recall: 0.9938, F1 Score: 0.9884, AUC Score: 0.9989
# Training: 	Fold 3 - Loss: 0.0354, Accuracy: 0.9896, Precision: 0.9965, Recall: 0.9869, F1 Score: 0.9915, AUC Score: 0.9994
# Training: 	Fold 4 - Loss: 0.0496, Accuracy: 0.9780, Precision: 0.9880, Recall: 0.9789, F1 Score: 0.9827, AUC Score: 0.9989
#
# Validation: 	Fold 5 - Loss: 0.0199, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9994
#
# Epoch 53/150
# Training: 	Fold 1 - Loss: 0.1304, Accuracy: 0.9611, Precision: 0.9777, Recall: 0.9694, F1 Score: 0.9708, AUC Score: 0.9969
# Training: 	Fold 2 - Loss: 0.0895, Accuracy: 0.9688, Precision: 0.9659, Recall: 0.9847, F1 Score: 0.9740, AUC Score: 0.9950
# Training: 	Fold 3 - Loss: 0.0691, Accuracy: 0.9771, Precision: 0.9709, Recall: 0.9936, F1 Score: 0.9810, AUC Score: 0.9957
# Training: 	Fold 4 - Loss: 0.0295, Accuracy: 0.9896, Precision: 0.9896, Recall: 0.9940, F1 Score: 0.9917, AUC Score: 0.9998
#
# Validation: 	Fold 5 - Loss: 0.0157, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 54/150
# Training: 	Fold 1 - Loss: 0.0503, Accuracy: 0.9792, Precision: 0.9886, Recall: 0.9769, F1 Score: 0.9820, AUC Score: 0.9988
# Training: 	Fold 2 - Loss: 0.0366, Accuracy: 0.9854, Precision: 0.9899, Recall: 0.9878, F1 Score: 0.9884, AUC Score: 0.9990
# Training: 	Fold 3 - Loss: 0.0480, Accuracy: 0.9785, Precision: 0.9877, Recall: 0.9774, F1 Score: 0.9811, AUC Score: 0.9984
# Training: 	Fold 4 - Loss: 0.0516, Accuracy: 0.9812, Precision: 0.9857, Recall: 0.9824, F1 Score: 0.9828, AUC Score: 0.9979
#
# Validation: 	Fold 5 - Loss: 0.0146, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 55/150
# Training: 	Fold 1 - Loss: 0.0378, Accuracy: 0.9854, Precision: 0.9807, Recall: 0.9942, F1 Score: 0.9870, AUC Score: 0.9993
# Training: 	Fold 2 - Loss: 0.0729, Accuracy: 0.9632, Precision: 0.9930, Recall: 0.9630, F1 Score: 0.9755, AUC Score: 0.9994
# Training: 	Fold 3 - Loss: 0.0689, Accuracy: 0.9750, Precision: 0.9686, Recall: 0.9908, F1 Score: 0.9790, AUC Score: 0.9967
# Training: 	Fold 4 - Loss: 0.0197, Accuracy: 0.9938, Precision: 0.9894, Recall: 1.0000, F1 Score: 0.9945, AUC Score: 0.9999
#
# Validation: 	Fold 5 - Loss: 0.0123, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 56/150
# Training: 	Fold 1 - Loss: 0.0669, Accuracy: 0.9632, Precision: 0.9446, Recall: 0.9965, F1 Score: 0.9647, AUC Score: 0.9993
# Training: 	Fold 2 - Loss: 0.1311, Accuracy: 0.9660, Precision: 0.9926, Recall: 0.9601, F1 Score: 0.9751, AUC Score: 0.9938
# Training: 	Fold 3 - Loss: 0.1141, Accuracy: 0.9639, Precision: 0.9799, Recall: 0.9642, F1 Score: 0.9705, AUC Score: 0.9919
# Training: 	Fold 4 - Loss: 0.1460, Accuracy: 0.9571, Precision: 0.9458, Recall: 0.9862, F1 Score: 0.9629, AUC Score: 0.9907
#
# Validation: 	Fold 5 - Loss: 0.0350, Accuracy: 0.9844, Precision: 0.9792, Recall: 1.0000, F1 Score: 0.9891, AUC Score: 0.9994
#
# Epoch 57/150
# Training: 	Fold 1 - Loss: 0.1643, Accuracy: 0.9486, Precision: 0.9416, Recall: 0.9828, F1 Score: 0.9579, AUC Score: 0.9955
# Training: 	Fold 2 - Loss: 0.1056, Accuracy: 0.9701, Precision: 0.9703, Recall: 0.9777, F1 Score: 0.9715, AUC Score: 0.9945
# Training: 	Fold 3 - Loss: 0.2001, Accuracy: 0.9333, Precision: 0.9507, Recall: 0.9368, F1 Score: 0.9409, AUC Score: 0.9777
# Training: 	Fold 4 - Loss: 0.1831, Accuracy: 0.9455, Precision: 0.9472, Recall: 0.9611, F1 Score: 0.9476, AUC Score: 0.9897
#
# Validation: 	Fold 5 - Loss: 0.0515, Accuracy: 0.9844, Precision: 0.9891, Recall: 0.9861, F1 Score: 0.9873, AUC Score: 0.9971
#
# Epoch 58/150
# Training: 	Fold 1 - Loss: 0.0980, Accuracy: 0.9583, Precision: 0.9674, Recall: 0.9615, F1 Score: 0.9636, AUC Score: 0.9936
# Training: 	Fold 2 - Loss: 0.0623, Accuracy: 0.9792, Precision: 0.9831, Recall: 0.9800, F1 Score: 0.9809, AUC Score: 0.9982
# Training: 	Fold 3 - Loss: 0.0670, Accuracy: 0.9701, Precision: 0.9956, Recall: 0.9668, F1 Score: 0.9798, AUC Score: 0.9991
# Training: 	Fold 4 - Loss: 0.0590, Accuracy: 0.9750, Precision: 0.9716, Recall: 0.9852, F1 Score: 0.9780, AUC Score: 0.9981
#
# Validation: 	Fold 5 - Loss: 0.0128, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Epoch 59/150
# Training: 	Fold 1 - Loss: 0.0476, Accuracy: 0.9896, Precision: 0.9799, Recall: 1.0000, F1 Score: 0.9894, AUC Score: 0.9987
# Training: 	Fold 2 - Loss: 0.0405, Accuracy: 0.9958, Precision: 1.0000, Recall: 0.9939, F1 Score: 0.9969, AUC Score: 0.9995
# Training: 	Fold 3 - Loss: 0.0348, Accuracy: 0.9896, Precision: 0.9857, Recall: 0.9965, F1 Score: 0.9908, AUC Score: 0.9996
# Training: 	Fold 4 - Loss: 0.0333, Accuracy: 0.9833, Precision: 0.9799, Recall: 0.9899, F1 Score: 0.9845, AUC Score: 0.9993
#
# Validation: 	Fold 5 - Loss: 0.0170, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 60/150
# Training: 	Fold 1 - Loss: 0.0864, Accuracy: 0.9826, Precision: 0.9743, Recall: 0.9968, F1 Score: 0.9842, AUC Score: 0.9985
# Training: 	Fold 2 - Loss: 0.0354, Accuracy: 0.9826, Precision: 0.9883, Recall: 0.9867, F1 Score: 0.9866, AUC Score: 0.9997
# Training: 	Fold 3 - Loss: 0.0813, Accuracy: 0.9653, Precision: 0.9926, Recall: 0.9652, F1 Score: 0.9765, AUC Score: 0.9993
# Training: 	Fold 4 - Loss: 0.0285, Accuracy: 0.9917, Precision: 0.9890, Recall: 0.9967, F1 Score: 0.9927, AUC Score: 0.9995
#
# Validation: 	Fold 5 - Loss: 0.0362, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9994
#
# Epoch 61/150
# Training: 	Fold 1 - Loss: 0.0344, Accuracy: 0.9875, Precision: 0.9845, Recall: 0.9921, F1 Score: 0.9882, AUC Score: 0.9997
# Training: 	Fold 2 - Loss: 0.0341, Accuracy: 0.9938, Precision: 0.9935, Recall: 0.9972, F1 Score: 0.9952, AUC Score: 0.9998
# Training: 	Fold 3 - Loss: 0.0432, Accuracy: 0.9875, Precision: 0.9846, Recall: 0.9944, F1 Score: 0.9891, AUC Score: 0.9979
# Training: 	Fold 4 - Loss: 0.0262, Accuracy: 0.9917, Precision: 0.9882, Recall: 0.9968, F1 Score: 0.9923, AUC Score: 0.9996
#
# Validation: 	Fold 5 - Loss: 0.0127, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 62/150
# Training: 	Fold 1 - Loss: 0.0553, Accuracy: 0.9757, Precision: 0.9667, Recall: 0.9970, F1 Score: 0.9762, AUC Score: 0.9998
# Training: 	Fold 2 - Loss: 0.2045, Accuracy: 0.9528, Precision: 0.9961, Recall: 0.9387, F1 Score: 0.9640, AUC Score: 0.9936
# Training: 	Fold 3 - Loss: 0.0517, Accuracy: 0.9792, Precision: 0.9794, Recall: 0.9877, F1 Score: 0.9833, AUC Score: 0.9983
# Training: 	Fold 4 - Loss: 0.0957, Accuracy: 0.9622, Precision: 0.9548, Recall: 0.9879, F1 Score: 0.9673, AUC Score: 0.9928
#
# Validation: 	Fold 5 - Loss: 0.0230, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 0.9997
#
# Epoch 63/150
# Training: 	Fold 1 - Loss: 0.0661, Accuracy: 0.9743, Precision: 0.9681, Recall: 0.9883, F1 Score: 0.9766, AUC Score: 0.9974
# Training: 	Fold 2 - Loss: 0.0790, Accuracy: 0.9639, Precision: 0.9935, Recall: 0.9552, F1 Score: 0.9730, AUC Score: 0.9980
# Training: 	Fold 3 - Loss: 0.1168, Accuracy: 0.9632, Precision: 0.9681, Recall: 0.9646, F1 Score: 0.9660, AUC Score: 0.9955
# Training: 	Fold 4 - Loss: 0.0700, Accuracy: 0.9738, Precision: 0.9815, Recall: 0.9752, F1 Score: 0.9769, AUC Score: 0.9968
#
# Validation: 	Fold 5 - Loss: 0.0195, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Epoch 64/150
# Training: 	Fold 1 - Loss: 0.0683, Accuracy: 0.9750, Precision: 0.9800, Recall: 0.9779, F1 Score: 0.9780, AUC Score: 0.9977
# Training: 	Fold 2 - Loss: 0.0435, Accuracy: 0.9785, Precision: 0.9826, Recall: 0.9802, F1 Score: 0.9797, AUC Score: 0.9996
# Training: 	Fold 3 - Loss: 0.0523, Accuracy: 0.9854, Precision: 0.9893, Recall: 0.9883, F1 Score: 0.9885, AUC Score: 0.9976
# Training: 	Fold 4 - Loss: 0.0648, Accuracy: 0.9685, Precision: 0.9520, Recall: 0.9938, F1 Score: 0.9668, AUC Score: 0.9993
#
# Validation: 	Fold 5 - Loss: 0.0121, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Epoch 65/150
# Training: 	Fold 1 - Loss: 0.0919, Accuracy: 0.9743, Precision: 0.9876, Recall: 0.9699, F1 Score: 0.9773, AUC Score: 0.9974
# Training: 	Fold 2 - Loss: 0.0731, Accuracy: 0.9771, Precision: 0.9858, Recall: 0.9762, F1 Score: 0.9805, AUC Score: 0.9973
# Training: 	Fold 3 - Loss: 0.0657, Accuracy: 0.9812, Precision: 0.9896, Recall: 0.9807, F1 Score: 0.9848, AUC Score: 0.9968
# Training: 	Fold 4 - Loss: 0.0630, Accuracy: 0.9812, Precision: 0.9808, Recall: 0.9874, F1 Score: 0.9835, AUC Score: 0.9971
#
# Validation: 	Fold 5 - Loss: 0.0212, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 66/150
# Training: 	Fold 1 - Loss: 0.0439, Accuracy: 0.9833, Precision: 0.9749, Recall: 0.9938, F1 Score: 0.9833, AUC Score: 0.9990
# Training: 	Fold 2 - Loss: 0.0329, Accuracy: 0.9917, Precision: 1.0000, Recall: 0.9874, F1 Score: 0.9935, AUC Score: 0.9996
# Training: 	Fold 3 - Loss: 0.0258, Accuracy: 0.9938, Precision: 0.9967, Recall: 0.9947, F1 Score: 0.9955, AUC Score: 0.9998
# Training: 	Fold 4 - Loss: 0.0149, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Validation: 	Fold 5 - Loss: 0.0120, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 1.0000
#
# Epoch 67/150
# Training: 	Fold 1 - Loss: 0.1122, Accuracy: 0.9806, Precision: 0.9655, Recall: 0.9974, F1 Score: 0.9789, AUC Score: 0.9980
# Training: 	Fold 2 - Loss: 0.0500, Accuracy: 0.9875, Precision: 0.9932, Recall: 0.9878, F1 Score: 0.9903, AUC Score: 0.9982
# Training: 	Fold 3 - Loss: 0.0356, Accuracy: 0.9896, Precision: 0.9861, Recall: 0.9971, F1 Score: 0.9913, AUC Score: 0.9991
# Training: 	Fold 4 - Loss: 0.0411, Accuracy: 0.9896, Precision: 0.9893, Recall: 0.9935, F1 Score: 0.9912, AUC Score: 0.9987
#
# Validation: 	Fold 5 - Loss: 0.0135, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 68/150
# Training: 	Fold 1 - Loss: 0.0289, Accuracy: 0.9917, Precision: 0.9917, Recall: 0.9947, F1 Score: 0.9928, AUC Score: 0.9996
# Training: 	Fold 2 - Loss: 0.0337, Accuracy: 0.9917, Precision: 0.9913, Recall: 0.9926, F1 Score: 0.9919, AUC Score: 0.9989
# Training: 	Fold 3 - Loss: 0.0190, Accuracy: 0.9917, Precision: 0.9933, Recall: 0.9935, F1 Score: 0.9932, AUC Score: 0.9999
# Training: 	Fold 4 - Loss: 0.0287, Accuracy: 0.9884, Precision: 0.9963, Recall: 0.9889, F1 Score: 0.9920, AUC Score: 0.9999
#
# Validation: 	Fold 5 - Loss: 0.0116, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 69/150
# Training: 	Fold 1 - Loss: 0.0801, Accuracy: 0.9826, Precision: 0.9695, Recall: 0.9967, F1 Score: 0.9807, AUC Score: 0.9978
# Training: 	Fold 2 - Loss: 0.0595, Accuracy: 0.9812, Precision: 0.9788, Recall: 0.9893, F1 Score: 0.9838, AUC Score: 0.9956
# Training: 	Fold 3 - Loss: 0.0354, Accuracy: 0.9896, Precision: 0.9965, Recall: 0.9882, F1 Score: 0.9921, AUC Score: 0.9994
# Training: 	Fold 4 - Loss: 0.0264, Accuracy: 0.9958, Precision: 0.9961, Recall: 0.9967, F1 Score: 0.9963, AUC Score: 0.9996
#
# Validation: 	Fold 5 - Loss: 0.0173, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9997
#
# Epoch 70/150
# Training: 	Fold 1 - Loss: 0.0335, Accuracy: 0.9826, Precision: 0.9928, Recall: 0.9833, F1 Score: 0.9872, AUC Score: 0.9998
# Training: 	Fold 2 - Loss: 0.0245, Accuracy: 0.9958, Precision: 1.0000, Recall: 0.9941, F1 Score: 0.9970, AUC Score: 0.9998
# Training: 	Fold 3 - Loss: 0.0736, Accuracy: 0.9681, Precision: 0.9566, Recall: 0.9886, F1 Score: 0.9698, AUC Score: 0.9988
# Training: 	Fold 4 - Loss: 0.0684, Accuracy: 0.9696, Precision: 0.9837, Recall: 0.9679, F1 Score: 0.9748, AUC Score: 0.9979
#
# Validation: 	Fold 5 - Loss: 0.0505, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9978
#
# Epoch 71/150
# Training: 	Fold 1 - Loss: 0.0604, Accuracy: 0.9750, Precision: 0.9796, Recall: 0.9801, F1 Score: 0.9790, AUC Score: 0.9972
# Training: 	Fold 2 - Loss: 0.1601, Accuracy: 0.9514, Precision: 0.9505, Recall: 0.9685, F1 Score: 0.9562, AUC Score: 0.9914
# Training: 	Fold 3 - Loss: 0.0565, Accuracy: 0.9771, Precision: 0.9863, Recall: 0.9779, F1 Score: 0.9818, AUC Score: 0.9980
# Training: 	Fold 4 - Loss: 0.0416, Accuracy: 0.9896, Precision: 0.9900, Recall: 0.9933, F1 Score: 0.9914, AUC Score: 0.9984
#
# Validation: 	Fold 5 - Loss: 0.0247, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 72/150
# Training: 	Fold 1 - Loss: 0.0474, Accuracy: 0.9896, Precision: 0.9854, Recall: 0.9967, F1 Score: 0.9908, AUC Score: 0.9985
# Training: 	Fold 2 - Loss: 0.0336, Accuracy: 0.9875, Precision: 0.9892, Recall: 0.9910, F1 Score: 0.9899, AUC Score: 0.9995
# Training: 	Fold 3 - Loss: 0.0354, Accuracy: 0.9826, Precision: 0.9922, Recall: 0.9800, F1 Score: 0.9847, AUC Score: 0.9997
# Training: 	Fold 4 - Loss: 0.0825, Accuracy: 0.9655, Precision: 0.9594, Recall: 0.9827, F1 Score: 0.9690, AUC Score: 0.9979
#
# Validation: 	Fold 5 - Loss: 0.0185, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 73/150
# Training: 	Fold 1 - Loss: 0.0162, Accuracy: 0.9938, Precision: 0.9926, Recall: 0.9971, F1 Score: 0.9946, AUC Score: 1.0000
# Training: 	Fold 2 - Loss: 0.0522, Accuracy: 0.9722, Precision: 0.9879, Recall: 0.9660, F1 Score: 0.9754, AUC Score: 0.9991
# Training: 	Fold 3 - Loss: 0.0329, Accuracy: 0.9896, Precision: 0.9843, Recall: 0.9971, F1 Score: 0.9903, AUC Score: 0.9993
# Training: 	Fold 4 - Loss: 0.0414, Accuracy: 0.9821, Precision: 0.9885, Recall: 0.9802, F1 Score: 0.9828, AUC Score: 0.9994
#
# Validation: 	Fold 5 - Loss: 0.0143, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 74/150
# Training: 	Fold 1 - Loss: 0.0311, Accuracy: 0.9938, Precision: 0.9920, Recall: 0.9970, F1 Score: 0.9943, AUC Score: 0.9998
# Training: 	Fold 2 - Loss: 0.0224, Accuracy: 0.9958, Precision: 1.0000, Recall: 0.9939, F1 Score: 0.9968, AUC Score: 0.9996
# Training: 	Fold 3 - Loss: 0.0290, Accuracy: 0.9896, Precision: 0.9926, Recall: 0.9923, F1 Score: 0.9922, AUC Score: 0.9995
# Training: 	Fold 4 - Loss: 0.0361, Accuracy: 0.9810, Precision: 0.9778, Recall: 0.9778, F1 Score: 0.9778, AUC Score: 0.9999
#
# Validation: 	Fold 5 - Loss: 0.0106, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 75/150
# Training: 	Fold 1 - Loss: 0.0666, Accuracy: 0.9681, Precision: 0.9799, Recall: 0.9659, F1 Score: 0.9713, AUC Score: 0.9974
# Training: 	Fold 2 - Loss: 0.0850, Accuracy: 0.9771, Precision: 0.9742, Recall: 0.9866, F1 Score: 0.9799, AUC Score: 0.9939
# Training: 	Fold 3 - Loss: 0.0687, Accuracy: 0.9792, Precision: 0.9786, Recall: 0.9826, F1 Score: 0.9800, AUC Score: 0.9969
# Training: 	Fold 4 - Loss: 0.0679, Accuracy: 0.9896, Precision: 0.9929, Recall: 0.9911, F1 Score: 0.9918, AUC Score: 0.9967
#
# Validation: 	Fold 5 - Loss: 0.0226, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9997
#
# Epoch 76/150
# Training: 	Fold 1 - Loss: 0.1188, Accuracy: 0.9563, Precision: 0.9685, Recall: 0.9696, F1 Score: 0.9681, AUC Score: 0.9978
# ...
#
# Epoch 126/150
# Training: 	Fold 1 - Loss: 0.0273, Accuracy: 0.9917, Precision: 0.9924, Recall: 0.9922, F1 Score: 0.9921, AUC Score: 0.9996
# Training: 	Fold 2 - Loss: 0.0264, Accuracy: 0.9847, Precision: 0.9963, Recall: 0.9803, F1 Score: 0.9870, AUC Score: 0.9998
# Training: 	Fold 3 - Loss: 0.0739, Accuracy: 0.9847, Precision: 0.9743, Recall: 0.9965, F1 Score: 0.9832, AUC Score: 0.9991
# Training: 	Fold 4 - Loss: 0.0380, Accuracy: 0.9833, Precision: 0.9781, Recall: 0.9924, F1 Score: 0.9848, AUC Score: 0.9992
#
# Validation: 	Fold 5 - Loss: 0.0357, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 0.9990
#
# Epoch 127/150
# Training: 	Fold 1 - Loss: 0.0245, Accuracy: 0.9896, Precision: 0.9967, Recall: 0.9867, F1 Score: 0.9914, AUC Score: 0.9998
# Training: 	Fold 2 - Loss: 0.0657, Accuracy: 0.9750, Precision: 0.9714, Recall: 0.9841, F1 Score: 0.9764, AUC Score: 0.9965
# Training: 	Fold 3 - Loss: 0.0369, Accuracy: 0.9771, Precision: 0.9812, Recall: 0.9814, F1 Score: 0.9805, AUC Score: 0.9993
# Training: 	Fold 4 - Loss: 0.0147, Accuracy: 0.9958, Precision: 0.9961, Recall: 0.9967, F1 Score: 0.9963, AUC Score: 0.9999
#
# Validation: 	Fold 5 - Loss: 0.0130, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 128/150
# Training: 	Fold 1 - Loss: 0.0256, Accuracy: 0.9868, Precision: 0.9778, Recall: 0.9961, F1 Score: 0.9846, AUC Score: 0.9999
# Training: 	Fold 2 - Loss: 0.0162, Accuracy: 0.9958, Precision: 0.9968, Recall: 0.9961, F1 Score: 0.9964, AUC Score: 1.0000
# Training: 	Fold 3 - Loss: 0.0249, Accuracy: 0.9896, Precision: 1.0000, Recall: 0.9839, F1 Score: 0.9918, AUC Score: 0.9998
# Training: 	Fold 4 - Loss: 0.0185, Accuracy: 0.9938, Precision: 1.0000, Recall: 0.9907, F1 Score: 0.9952, AUC Score: 0.9997
#
# Validation: 	Fold 5 - Loss: 0.0122, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 0.9997
#
# Epoch 129/150
# Training: 	Fold 1 - Loss: 0.0414, Accuracy: 0.9847, Precision: 0.9698, Recall: 1.0000, F1 Score: 0.9826, AUC Score: 0.9998
# Training: 	Fold 2 - Loss: 0.0364, Accuracy: 0.9917, Precision: 1.0000, Recall: 0.9875, F1 Score: 0.9936, AUC Score: 0.9995
# Training: 	Fold 3 - Loss: 0.0338, Accuracy: 0.9806, Precision: 0.9963, Recall: 0.9763, F1 Score: 0.9853, AUC Score: 0.9998
# Training: 	Fold 4 - Loss: 0.0285, Accuracy: 0.9917, Precision: 0.9968, Recall: 0.9873, F1 Score: 0.9916, AUC Score: 0.9995
#
# Validation: 	Fold 5 - Loss: 0.0164, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 130/150
# Training: 	Fold 1 - Loss: 0.0248, Accuracy: 0.9917, Precision: 0.9831, Recall: 1.0000, F1 Score: 0.9911, AUC Score: 0.9999
# Training: 	Fold 2 - Loss: 0.0256, Accuracy: 0.9917, Precision: 0.9884, Recall: 0.9958, F1 Score: 0.9919, AUC Score: 0.9998
# Training: 	Fold 3 - Loss: 0.0129, Accuracy: 0.9979, Precision: 0.9965, Recall: 1.0000, F1 Score: 0.9982, AUC Score: 1.0000
# Training: 	Fold 4 - Loss: 0.0385, Accuracy: 0.9863, Precision: 0.9743, Recall: 0.9973, F1 Score: 0.9835, AUC Score: 0.9994
#
# Validation: 	Fold 5 - Loss: 0.0127, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 131/150
# Training: 	Fold 1 - Loss: 0.0433, Accuracy: 0.9701, Precision: 0.9744, Recall: 0.9775, F1 Score: 0.9740, AUC Score: 0.9992
# Training: 	Fold 2 - Loss: 0.0316, Accuracy: 0.9896, Precision: 0.9921, Recall: 0.9911, F1 Score: 0.9914, AUC Score: 0.9992
# Training: 	Fold 3 - Loss: 0.0259, Accuracy: 0.9896, Precision: 0.9927, Recall: 0.9908, F1 Score: 0.9915, AUC Score: 0.9996
# Training: 	Fold 4 - Loss: 0.0433, Accuracy: 0.9833, Precision: 0.9834, Recall: 0.9900, F1 Score: 0.9863, AUC Score: 0.9988
#
# Validation: 	Fold 5 - Loss: 0.0144, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 132/150
# Training: 	Fold 1 - Loss: 0.0211, Accuracy: 0.9896, Precision: 0.9879, Recall: 0.9919, F1 Score: 0.9898, AUC Score: 0.9998
# Training: 	Fold 2 - Loss: 0.0153, Accuracy: 0.9979, Precision: 0.9970, Recall: 1.0000, F1 Score: 0.9984, AUC Score: 1.0000
# Training: 	Fold 3 - Loss: 0.0098, Accuracy: 0.9979, Precision: 1.0000, Recall: 0.9971, F1 Score: 0.9985, AUC Score: 1.0000
# Training: 	Fold 4 - Loss: 0.0190, Accuracy: 0.9938, Precision: 0.9881, Recall: 1.0000, F1 Score: 0.9938, AUC Score: 0.9999
#
# Validation: 	Fold 5 - Loss: 0.0129, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 0.9997
#
# Epoch 133/150
# Training: 	Fold 1 - Loss: 0.0872, Accuracy: 0.9757, Precision: 0.9667, Recall: 0.9973, F1 Score: 0.9764, AUC Score: 0.9990
# Training: 	Fold 2 - Loss: 0.1026, Accuracy: 0.9625, Precision: 0.9837, Recall: 0.9572, F1 Score: 0.9692, AUC Score: 0.9950
# Training: 	Fold 3 - Loss: 0.0231, Accuracy: 0.9896, Precision: 0.9968, Recall: 0.9876, F1 Score: 0.9921, AUC Score: 0.9998
# Training: 	Fold 4 - Loss: 0.0348, Accuracy: 0.9917, Precision: 0.9917, Recall: 0.9933, F1 Score: 0.9923, AUC Score: 0.9990
#
# Validation: 	Fold 5 - Loss: 0.0102, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 134/150
# Training: 	Fold 1 - Loss: 0.0313, Accuracy: 0.9917, Precision: 0.9870, Recall: 0.9961, F1 Score: 0.9910, AUC Score: 0.9992
# Training: 	Fold 2 - Loss: 0.0222, Accuracy: 0.9938, Precision: 0.9958, Recall: 0.9936, F1 Score: 0.9946, AUC Score: 0.9999
# Training: 	Fold 3 - Loss: 0.0419, Accuracy: 0.9806, Precision: 0.9762, Recall: 0.9936, F1 Score: 0.9835, AUC Score: 0.9996
# Training: 	Fold 4 - Loss: 0.0346, Accuracy: 0.9821, Precision: 0.9921, Recall: 0.9798, F1 Score: 0.9850, AUC Score: 0.9997
#
# Validation: 	Fold 5 - Loss: 0.0138, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Epoch 135/150
# Training: 	Fold 1 - Loss: 0.0575, Accuracy: 0.9812, Precision: 0.9770, Recall: 0.9885, F1 Score: 0.9824, AUC Score: 0.9961
# Training: 	Fold 2 - Loss: 0.0400, Accuracy: 0.9875, Precision: 0.9929, Recall: 0.9874, F1 Score: 0.9900, AUC Score: 0.9992
# Training: 	Fold 3 - Loss: 0.0524, Accuracy: 0.9806, Precision: 0.9896, Recall: 0.9800, F1 Score: 0.9834, AUC Score: 0.9995
# Training: 	Fold 4 - Loss: 0.0196, Accuracy: 0.9938, Precision: 0.9963, Recall: 0.9940, F1 Score: 0.9950, AUC Score: 0.9999
#
# Validation: 	Fold 5 - Loss: 0.0175, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9997
#
# Epoch 136/150
# Training: 	Fold 1 - Loss: 0.0291, Accuracy: 0.9896, Precision: 0.9838, Recall: 0.9965, F1 Score: 0.9897, AUC Score: 0.9998
# Training: 	Fold 2 - Loss: 0.0365, Accuracy: 0.9938, Precision: 0.9905, Recall: 0.9973, F1 Score: 0.9935, AUC Score: 0.9980
# Training: 	Fold 3 - Loss: 0.0456, Accuracy: 0.9847, Precision: 0.9963, Recall: 0.9860, F1 Score: 0.9906, AUC Score: 0.9999
# Training: 	Fold 4 - Loss: 0.0172, Accuracy: 0.9938, Precision: 0.9967, Recall: 0.9933, F1 Score: 0.9949, AUC Score: 0.9998
#
# Validation: 	Fold 5 - Loss: 0.0201, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 0.9997
#
# Epoch 137/150
# Training: 	Fold 1 - Loss: 0.0264, Accuracy: 0.9896, Precision: 0.9857, Recall: 0.9961, F1 Score: 0.9906, AUC Score: 0.9998
# Training: 	Fold 2 - Loss: 0.0164, Accuracy: 0.9938, Precision: 0.9942, Recall: 0.9965, F1 Score: 0.9952, AUC Score: 0.9999
# Training: 	Fold 3 - Loss: 0.0364, Accuracy: 0.9868, Precision: 1.0000, Recall: 0.9838, F1 Score: 0.9911, AUC Score: 1.0000
# Training: 	Fold 4 - Loss: 0.0598, Accuracy: 0.9792, Precision: 0.9684, Recall: 0.9963, F1 Score: 0.9819, AUC Score: 0.9981
#
# Validation: 	Fold 5 - Loss: 0.1051, Accuracy: 0.9609, Precision: 0.9472, Recall: 0.9886, F1 Score: 0.9673, AUC Score: 0.9978
#
# Epoch 138/150
# Training: 	Fold 1 - Loss: 0.0385, Accuracy: 0.9854, Precision: 0.9763, Recall: 0.9961, F1 Score: 0.9859, AUC Score: 0.9995
# Training: 	Fold 2 - Loss: 0.0521, Accuracy: 0.9806, Precision: 0.9664, Recall: 0.9971, F1 Score: 0.9792, AUC Score: 0.9990
# Training: 	Fold 3 - Loss: 0.1535, Accuracy: 0.9653, Precision: 0.9736, Recall: 0.9626, F1 Score: 0.9678, AUC Score: 0.9967
# Training: 	Fold 4 - Loss: 0.0939, Accuracy: 0.9729, Precision: 0.9883, Recall: 0.9647, F1 Score: 0.9756, AUC Score: 0.9946
#
# Validation: 	Fold 5 - Loss: 0.0554, Accuracy: 0.9688, Precision: 0.9881, Recall: 0.9634, F1 Score: 0.9754, AUC Score: 0.9984
#
# Epoch 139/150
# Training: 	Fold 1 - Loss: 0.1545, Accuracy: 0.9549, Precision: 0.9679, Recall: 0.9711, F1 Score: 0.9665, AUC Score: 0.9942
# Training: 	Fold 2 - Loss: 0.0889, Accuracy: 0.9743, Precision: 0.9795, Recall: 0.9838, F1 Score: 0.9806, AUC Score: 0.9946
# Training: 	Fold 3 - Loss: 0.1346, Accuracy: 0.9660, Precision: 0.9752, Recall: 0.9706, F1 Score: 0.9712, AUC Score: 0.9941
# Training: 	Fold 4 - Loss: 0.0436, Accuracy: 0.9875, Precision: 0.9862, Recall: 0.9942, F1 Score: 0.9898, AUC Score: 0.9990
#
# Validation: 	Fold 5 - Loss: 0.0234, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9997
#
# Epoch 140/150
# Training: 	Fold 1 - Loss: 0.0256, Accuracy: 0.9958, Precision: 0.9925, Recall: 1.0000, F1 Score: 0.9962, AUC Score: 1.0000
# Training: 	Fold 2 - Loss: 0.0304, Accuracy: 0.9938, Precision: 0.9919, Recall: 0.9963, F1 Score: 0.9939, AUC Score: 0.9994
# Training: 	Fold 3 - Loss: 0.0453, Accuracy: 0.9806, Precision: 0.9890, Recall: 0.9861, F1 Score: 0.9867, AUC Score: 0.9976
# Training: 	Fold 4 - Loss: 0.0271, Accuracy: 0.9938, Precision: 0.9967, Recall: 0.9939, F1 Score: 0.9951, AUC Score: 0.9997
#
# Validation: 	Fold 5 - Loss: 0.0132, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Epoch 141/150
# Training: 	Fold 1 - Loss: 0.0804, Accuracy: 0.9736, Precision: 0.9686, Recall: 0.9778, F1 Score: 0.9730, AUC Score: 0.9994
# Training: 	Fold 2 - Loss: 0.3015, Accuracy: 0.9347, Precision: 0.9141, Recall: 0.9206, F1 Score: 0.9168, AUC Score: 0.9926
# Training: 	Fold 3 - Loss: 0.0692, Accuracy: 0.9785, Precision: 0.9952, Recall: 0.9748, F1 Score: 0.9840, AUC Score: 0.9982
# Training: 	Fold 4 - Loss: 0.1009, Accuracy: 0.9589, Precision: 0.9638, Recall: 0.9380, F1 Score: 0.9494, AUC Score: 0.9988
#
# Validation: 	Fold 5 - Loss: 0.0239, Accuracy: 0.9844, Precision: 0.9891, Recall: 0.9861, F1 Score: 0.9873, AUC Score: 0.9997
#
# Epoch 142/150
# Training: 	Fold 1 - Loss: 0.0639, Accuracy: 0.9771, Precision: 0.9773, Recall: 0.9845, F1 Score: 0.9803, AUC Score: 0.9973
# Training: 	Fold 2 - Loss: 0.1004, Accuracy: 0.9660, Precision: 0.9622, Recall: 0.9774, F1 Score: 0.9672, AUC Score: 0.9937
# Training: 	Fold 3 - Loss: 0.0628, Accuracy: 0.9785, Precision: 0.9593, Recall: 0.9901, F1 Score: 0.9689, AUC Score: 0.9969
# Training: 	Fold 4 - Loss: 0.0314, Accuracy: 0.9875, Precision: 0.9933, Recall: 0.9865, F1 Score: 0.9897, AUC Score: 0.9996
#
# Validation: 	Fold 5 - Loss: 0.0205, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 0.9997
#
# Epoch 143/150
# Training: 	Fold 1 - Loss: 0.0426, Accuracy: 0.9938, Precision: 0.9911, Recall: 0.9974, F1 Score: 0.9941, AUC Score: 0.9995
# Training: 	Fold 2 - Loss: 0.0195, Accuracy: 0.9938, Precision: 0.9965, Recall: 0.9927, F1 Score: 0.9944, AUC Score: 1.0000
# Training: 	Fold 3 - Loss: 0.0159, Accuracy: 0.9958, Precision: 1.0000, Recall: 0.9943, F1 Score: 0.9971, AUC Score: 1.0000
# Training: 	Fold 4 - Loss: 0.0331, Accuracy: 0.9875, Precision: 0.9920, Recall: 0.9895, F1 Score: 0.9904, AUC Score: 0.9993
#
# Validation: 	Fold 5 - Loss: 0.0114, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 144/150
# Training: 	Fold 1 - Loss: 0.0134, Accuracy: 0.9979, Precision: 0.9961, Recall: 1.0000, F1 Score: 0.9980, AUC Score: 0.9999
# Training: 	Fold 2 - Loss: 0.0144, Accuracy: 0.9958, Precision: 1.0000, Recall: 0.9928, F1 Score: 0.9963, AUC Score: 0.9999
# Training: 	Fold 3 - Loss: 0.0165, Accuracy: 0.9979, Precision: 0.9970, Recall: 1.0000, F1 Score: 0.9984, AUC Score: 1.0000
# Training: 	Fold 4 - Loss: 0.0119, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Validation: 	Fold 5 - Loss: 0.0126, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 145/150
# Training: 	Fold 1 - Loss: 0.0237, Accuracy: 0.9958, Precision: 0.9927, Recall: 1.0000, F1 Score: 0.9962, AUC Score: 0.9998
# Training: 	Fold 2 - Loss: 0.0191, Accuracy: 0.9938, Precision: 0.9958, Recall: 0.9946, F1 Score: 0.9951, AUC Score: 0.9998
# Training: 	Fold 3 - Loss: 0.0240, Accuracy: 0.9938, Precision: 0.9968, Recall: 0.9938, F1 Score: 0.9952, AUC Score: 0.9997
# Training: 	Fold 4 - Loss: 0.0114, Accuracy: 0.9958, Precision: 0.9970, Recall: 0.9961, F1 Score: 0.9964, AUC Score: 1.0000
#
# Validation: 	Fold 5 - Loss: 0.0147, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 146/150
# Training: 	Fold 1 - Loss: 0.0150, Accuracy: 0.9917, Precision: 0.9890, Recall: 0.9968, F1 Score: 0.9928, AUC Score: 0.9999
# Training: 	Fold 2 - Loss: 0.0121, Accuracy: 0.9958, Precision: 1.0000, Recall: 0.9942, F1 Score: 0.9970, AUC Score: 1.0000
# Training: 	Fold 3 - Loss: 0.0114, Accuracy: 0.9938, Precision: 0.9972, Recall: 0.9939, F1 Score: 0.9955, AUC Score: 1.0000
# Training: 	Fold 4 - Loss: 0.0122, Accuracy: 0.9958, Precision: 0.9965, Recall: 0.9970, F1 Score: 0.9966, AUC Score: 0.9999
#
# Validation: 	Fold 5 - Loss: 0.0123, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 147/150
# Training: 	Fold 1 - Loss: 0.0067, Accuracy: 0.9979, Precision: 0.9968, Recall: 1.0000, F1 Score: 0.9984, AUC Score: 1.0000
# Training: 	Fold 2 - Loss: 0.0126, Accuracy: 0.9979, Precision: 0.9967, Recall: 1.0000, F1 Score: 0.9983, AUC Score: 1.0000
# Training: 	Fold 3 - Loss: 0.0060, Accuracy: 0.9979, Precision: 0.9974, Recall: 1.0000, F1 Score: 0.9987, AUC Score: 1.0000
# Training: 	Fold 4 - Loss: 0.0077, Accuracy: 1.0000, Precision: 1.0000, Recall: 1.0000, F1 Score: 1.0000, AUC Score: 1.0000
#
# Validation: 	Fold 5 - Loss: 0.0096, Accuracy: 0.9922, Precision: 0.9891, Recall: 1.0000, F1 Score: 0.9944, AUC Score: 1.0000
#
# Epoch 148/150
# Training: 	Fold 1 - Loss: 0.0113, Accuracy: 0.9979, Precision: 0.9958, Recall: 1.0000, F1 Score: 0.9978, AUC Score: 0.9999
# Training: 	Fold 2 - Loss: 0.0106, Accuracy: 0.9958, Precision: 0.9963, Recall: 0.9965, F1 Score: 0.9963, AUC Score: 1.0000
# Training: 	Fold 3 - Loss: 0.0186, Accuracy: 0.9958, Precision: 0.9920, Recall: 1.0000, F1 Score: 0.9959, AUC Score: 0.9998
# Training: 	Fold 4 - Loss: 0.0137, Accuracy: 0.9958, Precision: 0.9958, Recall: 0.9968, F1 Score: 0.9962, AUC Score: 1.0000
#
# Validation: 	Fold 5 - Loss: 0.0141, Accuracy: 0.9844, Precision: 0.9886, Recall: 0.9886, F1 Score: 0.9886, AUC Score: 0.9997
#
# Epoch 149/150
# Training: 	Fold 1 - Loss: 0.0094, Accuracy: 0.9979, Precision: 0.9968, Recall: 1.0000, F1 Score: 0.9984, AUC Score: 1.0000
# Training: 	Fold 2 - Loss: 0.0122, Accuracy: 0.9938, Precision: 0.9958, Recall: 0.9937, F1 Score: 0.9946, AUC Score: 0.9999
# Training: 	Fold 3 - Loss: 0.0076, Accuracy: 0.9979, Precision: 1.0000, Recall: 0.9973, F1 Score: 0.9986, AUC Score: 1.0000
# Training: 	Fold 4 - Loss: 0.0062, Accuracy: 0.9958, Precision: 0.9970, Recall: 0.9967, F1 Score: 0.9967, AUC Score: 1.0000
#
# Validation: 	Fold 5 - Loss: 0.0115, Accuracy: 0.9922, Precision: 1.0000, Recall: 0.9886, F1 Score: 0.9942, AUC Score: 0.9997
#
# Epoch 150/150
# Training: 	Fold 1 - Loss: 0.0075, Accuracy: 0.9958, Precision: 0.9973, Recall: 0.9968, F1 Score: 0.9970, AUC Score: 1.0000
# Training: 	Fold 2 - Loss: 0.0090, Accuracy: 0.9938, Precision: 0.9933, Recall: 0.9961, F1 Score: 0.9946, AUC Score: 0.9999
# Training: 	Fold 3 - Loss: 0.0944, Accuracy: 0.9868, Precision: 0.9970, Recall: 0.9833, F1 Score: 0.9889, AUC Score: 0.9984
# Training: 	Fold 4 - Loss: 0.0398, Accuracy: 0.9854, Precision: 0.9810, Recall: 0.9938, F1 Score: 0.9870, AUC Score: 0.9991
#
# Validation: 	Fold 5 - Loss: 0.0653, Accuracy: 0.9844, Precision: 0.9760, Recall: 1.0000, F1 Score: 0.9877, AUC Score: 0.9990
# Model Size: 9.13 MB
# CPU times: user 3h 25min 31s, sys: 16min 46s, total: 3h 42min 17s
# Wall time: 9min 15s

# %% [markdown]
# We can now evaluate our models performance using a test set on a single batch

# %%
# %%time

model.load_state_dict(torch.load(f"{weights_dir}/model_best_f1score_binary_11062024.pth"))
test_loss, test_performance_metrics = eval(test_loader, model, loss_fn, 'Testing', CumulativeMetrics(model_type="binary", device=device))
test_accuracy, test_precision, test_recall, test_f1, test_auc = test_performance_metrics.values()
print(f"Testing: \tLoss: {test_loss:.4f}, Accuracy: {test_accuracy:.4f}, Precision: {test_precision:.4f}, Recall: {test_recall:.4f}, F1 Score: {test_f1:.4f}, AUC Score: {test_auc:.4f}")
# Out:
# Testing: 	Loss: 0.1945, Accuracy: 0.9357, Precision: 1.0000, Recall: 0.8917, F1 Score: 0.9424, AUC Score: 0.9774
# CPU times: user 973 ms, sys: 108 ms, total: 1.08 s
# Wall time: 73.3 ms

# %%
train_metrics_df = pd.DataFrame(train_metrics_df)
display(train_metrics_df.sort_values(by='Accuracy', ascending=False)[:25])
# Out:
#          Loss  Accuracy  Precision    Recall  F1 Score  AUC Score
# 587  0.007728  1.000000   1.000000  1.000000  1.000000   1.000000
# 575  0.011898  1.000000   1.000000  1.000000  1.000000   1.000000
# 263  0.014912  1.000000   1.000000  1.000000  1.000000   1.000000
# 409  0.019889  1.000000   1.000000  1.000000  1.000000   1.000000
# 586  0.006042  0.997917   0.997436  1.000000  0.998693   1.000000
# 518  0.012925  0.997917   0.996491  1.000000  0.998198   1.000000
# 572  0.013439  0.997917   0.996078  1.000000  0.997980   0.999941
# 574  0.016545  0.997917   0.996970  1.000000  0.998450   1.000000
# 588  0.011305  0.997917   0.995833  1.000000  0.997849   0.999941
# 490  0.010916  0.997917   1.000000  0.996491  0.998198   1.000000
# 526  0.009838  0.997917   1.000000  0.997101  0.998519   0.999959
# 488  0.011160  0.997917   0.996296  1.000000  0.998095   0.999980
# 422  0.012043  0.997917   1.000000  0.997101  0.998519   0.999939
# 396  0.019243  0.997917   1.000000  0.996491  0.998198   1.000000
# 525  0.015288  0.997917   0.996970  1.000000  0.998450   1.000000
# 420  0.014318  0.997917   0.996667  1.000000  0.998291   0.999941
# 479  0.011556  0.997917   1.000000  0.996667  0.998291   0.999980
# 384  0.010176  0.997917   0.995833  1.000000  0.997849   0.999980
# 445  0.019618  0.997917   0.996667  1.000000  0.998291   1.000000
# 585  0.012634  0.997917   0.996667  1.000000  0.998291   1.000000
# 584  0.006737  0.997917   0.996825  1.000000  0.998374   0.999980
# 592  0.009376  0.997917   0.996825  1.000000  0.998374   0.999980
# 594  0.007558  0.997917   1.000000  0.997333  0.998639   0.999980
# 382  0.011915  0.997917   0.996667  1.000000  0.998291   0.999918
# 573  0.014410  0.995833   1.000000  0.992803  0.996299   0.999858

# %%
val_metrics_df = pd.DataFrame(val_metrics_df)
display(val_metrics_df.sort_values(by='Accuracy', ascending=False)[:25])
# Out:
#        Loss  Accuracy  Precision    Recall  F1 Score  AUC Score
# 8  0.037500  1.000000   1.000000  1.000000  1.000000   1.000000
# 7  0.061978  0.984375   0.989130  0.986111  0.987302   0.999359
# 6  0.086807  0.976562   0.975242  0.986111  0.980556   0.996795
# 5  0.127355  0.953125   0.966063  0.941628  0.953527   0.989744
# 4  0.239747  0.914982   0.951389  0.890200  0.919448   0.969231
# 3  0.302384  0.867188   0.928571  0.818570  0.864461   0.947756
# 2  0.364483  0.843750   0.851389  0.857712  0.853175   0.914744
# 1  0.478632  0.729320   0.695040  0.905692  0.784420   0.869231
# 0  0.535081  0.698989   0.718155  0.834645  0.758268   0.805449

# %%
model_name = f"MobileNetV2"#, {get_model_size(model)}"
plot_metrics(train_metrics_df, "Training", model_name)
plot_metrics(val_metrics_df, "Validation", model_name)
